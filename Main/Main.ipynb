# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from imblearn.combine import SMOTETomek
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, ExtraTreesClassifier, StackingClassifier, VotingClassifier,BaggingClassifier
from imblearn.ensemble import BalancedRandomForestClassifier
from sklearn. neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix, classification_report, roc_curve, ConfusionMatrixDisplay
from prettytable import PrettyTable
import time
# Out:
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\dask\dataframe\utils.py:367: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   _numeric_index_types = (pd.Int64Index, pd.Float64Index, pd.UInt64Index)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\dask\dataframe\utils.py:367: FutureWarning: pandas.Float64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   _numeric_index_types = (pd.Int64Index, pd.Float64Index, pd.UInt64Index)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\dask\dataframe\utils.py:367: FutureWarning: pandas.UInt64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   _numeric_index_types = (pd.Int64Index, pd.Float64Index, pd.UInt64Index)

# %%
df = pd.read_csv("healthcare-dataset-stroke-data.csv")
df.tail(20)
# Out:
#          id  gender    age  hypertension  heart_disease ever_married  \
# 5090   4211    Male  26.00             0              0           No
# 5091   6369    Male  59.00             1              0          Yes
# 5092  56799    Male  76.00             0              0          Yes
# 5093  32235  Female  45.00             1              0          Yes
# 5094  28048    Male  13.00             0              0           No
# 5095  68598    Male   1.08             0              0           No
# 5096  41512    Male  57.00             0              0          Yes
# 5097  64520    Male  68.00             0              0          Yes
# 5098    579    Male   9.00             0              0           No
# 5099   7293    Male  40.00             0              0          Yes
# 5100  68398    Male  82.00             1              0          Yes
# 5101  36901  Female  45.00             0              0          Yes
# 5102  45010  Female  57.00             0              0          Yes
# 5103  22127  Female  18.00             0              0           No
# 5104  14180  Female  13.00             0              0           No
# 5105  18234  Female  80.00             1              0          Yes
# 5106  44873  Female  81.00             0              0          Yes
# 5107  19723  Female  35.00             0              0          Yes
# 5108  37544    Male  51.00             0              0          Yes
# 5109  44679  Female  44.00             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 5090       Govt_job          Rural             100.85  21.0           smokes
# 5091        Private          Rural              95.05  30.9     never smoked
# 5092       Govt_job          Urban              82.35  38.9     never smoked
# 5093       Govt_job          Rural              95.02   NaN           smokes
# 5094       children          Urban              82.38  24.3          Unknown
# 5095       children          Rural              79.15  17.4          Unknown
# 5096       Govt_job          Rural              76.62  28.2     never smoked
# 5097  Self-employed          Urban              91.68  40.8          Unknown
# 5098       children          Urban              71.88  17.5          Unknown
# 5099        Private          Rural              83.94   NaN           smokes
# 5100  Self-employed          Rural              71.97  28.3     never smoked
# 5101        Private          Urban              97.95  24.5          Unknown
# 5102        Private          Rural              77.93  21.7     never smoked
# 5103        Private          Urban              82.85  46.9          Unknown
# 5104       children          Rural             103.08  18.6          Unknown
# 5105        Private          Urban              83.75   NaN     never smoked
# 5106  Self-employed          Urban             125.20  40.0     never smoked
# 5107  Self-employed          Rural              82.99  30.6     never smoked
# 5108        Private          Rural             166.29  25.6  formerly smoked
# 5109       Govt_job          Urban              85.28  26.2          Unknown
#
#       stroke
# 5090       0
# 5091       0
# 5092       0
# 5093       0
# 5094       0
# 5095       0
# 5096       0
# 5097       0
# 5098       0
# 5099       0
# 5100       0
# 5101       0
# 5102       0
# 5103       0
# 5104       0
# 5105       0
# 5106       0
# 5107       0
# 5108       0
# 5109       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %%
df.describe()
# Out:
#                  id          age  hypertension  heart_disease  \
# count   5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354    43.226614      0.097456       0.054012
# std    21161.721625    22.612647      0.296607       0.226063
# min       67.000000     0.080000      0.000000       0.000000
# 25%    17741.250000    25.000000      0.000000       0.000000
# 50%    36932.000000    45.000000      0.000000       0.000000
# 75%    54682.000000    61.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        5110.000000  4909.000000  5110.000000
# mean          106.147677    28.893237     0.048728
# std            45.283560     7.854067     0.215320
# min            55.120000    10.300000     0.000000
# 25%            77.245000    23.500000     0.000000
# 50%            91.885000    28.100000     0.000000
# 75%           114.090000    33.100000     0.000000
# max           271.740000    97.600000     1.000000

# %%
print("Missing values:")
print(df.isnull().sum())
# Out:
# Missing values:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %%
df[df.isnull().any(axis=1)]
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 1     51676  Female  61.0             0              0          Yes
# 8     27419  Female  59.0             0              0          Yes
# 13     8213    Male  78.0             0              1          Yes
# 19    25226    Male  57.0             0              1           No
# 27    61843    Male  58.0             0              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5039  42007    Male  41.0             0              0           No
# 5048  28788    Male  40.0             0              0          Yes
# 5093  32235  Female  45.0             1              0          Yes
# 5099   7293    Male  40.0             0              0          Yes
# 5105  18234  Female  80.0             1              0          Yes
#
#           work_type Residence_type  avg_glucose_level  bmi   smoking_status  \
# 1     Self-employed          Rural             202.21  NaN     never smoked
# 8           Private          Rural              76.15  NaN          Unknown
# 13          Private          Urban             219.84  NaN          Unknown
# 19         Govt_job          Urban             217.08  NaN          Unknown
# 27          Private          Rural             189.84  NaN          Unknown
# ...             ...            ...                ...  ...              ...
# 5039        Private          Rural              70.15  NaN  formerly smoked
# 5048        Private          Urban             191.15  NaN           smokes
# 5093       Govt_job          Rural              95.02  NaN           smokes
# 5099        Private          Rural              83.94  NaN           smokes
# 5105        Private          Urban              83.75  NaN     never smoked
#
#       stroke
# 1          1
# 8          1
# 13         1
# 19         1
# 27         1
# ...      ...
# 5039       0
# 5048       0
# 5093       0
# 5099       0
# 5105       0
#
# [201 rows x 12 columns]

# %% [markdown]
# ## Visualine

# %% [markdown]
# Biểu đồ đếm số lượng ca đột quỵ

# %%
sns.countplot(x='stroke', data=df)
plt.title("Stroke")
plt.show()

# %% [markdown]
# Biểu đồ phân bố tuổi theo đột quỵ

# %%
plt.figure(figsize=(12, 6))
sns.histplot(data=df, x="age", hue="stroke", bins=30, kde=True)
plt.title("Phân bố tuổi theo đột quỵ")
plt.show()

# %% [markdown]
# Biểu đồ đếm tăng huyết áp và đột quỵ

# %%
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x="hypertension", hue="stroke")
plt.title("Tăng huyết áp và đột quỵ")
plt.show()

# %% [markdown]
# Biểu đồ phân bố mức đường huyết trung bình theo đột quỵ

# %%
plt.figure(figsize=(12, 6))
sns.histplot(data=df, x="avg_glucose_level", hue="stroke", bins=30, kde=True)
plt.title("Mức đường huyết trung bình theo đột quỵ")
plt.show()

# %% [markdown]
# Biểu đồ phân bố BMI theo đột quỵ

# %%
plt.figure(figsize=(12, 6))
sns.histplot(data=df, x="bmi", hue="stroke", bins=30, kde=True)
plt.title("Phân bố BMI theo đột quỵ")
plt.show()

# %% [markdown]
# Biểu đồ scatter giữa tuổi và mức đường huyết trung bình

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x="age", y="avg_glucose_level", hue="stroke", alpha=0.5)
plt.title("Mối quan hệ giữa tuổi và mức đường huyết trung bình")
plt.show()

# %% [markdown]
# Biểu đồ scatter giữa tuổi và BMI

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x="age", y="bmi", hue="stroke", alpha=0.5)
plt.title("Mối quan hệ giữa tuổi và BMI")
plt.show()

# %% [markdown]
# Biểu đồ scatter giữa mức đường huyết trung bình và BMI

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x="avg_glucose_level", y="bmi", hue="stroke", alpha=0.5)
plt.title("Mối quan hệ giữa mức đường huyết trung bình và BMI")
plt.show()

# %% [markdown]
# Biểu đồ boxplot tuổi theo tình trạng đột quỵ

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x="stroke", y="age")
plt.title("Phân bố tuổi theo tình trạng đột quỵ")
plt.show()

# %% [markdown]
# Biểu đồ boxplot mức đường huyết trung bình theo đột quỵ

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x="stroke", y="avg_glucose_level")
plt.title("Phân bố mức đường huyết trung bình theo tình trạng đột quỵ")
plt.show()

# %% [markdown]
# Biểu đồ đếm đột quỵ theo giới tính

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x="gender", hue="stroke")
plt.title("Tỷ lệ đột quỵ theo giới tính")
plt.show()

# %% [markdown]
# Biểu đồ đếm đột quỵ theo loại nghề nghiệp

# %%
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x="work_type", hue="stroke")
plt.title("Tỷ lệ đột quỵ theo loại nghề nghiệp")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Biểu đồ violin của tuổi theo tình trạng hút thuốc

# %%
sns.violinplot(x='smoking_status', y='age', data=df, order=['formerly smoked', 'smokes', 'never smoked', 'Unknown'])
# Out:
# <Axes: xlabel='smoking_status', ylabel='age'>

# %% [markdown]
# Biểu đồ đếm bệnh tim và đột quỵ

# %%
plt.figure(figsize=(8,5))
sns.countplot(data=df, x="heart_disease", hue="stroke")
plt.title("Bệnh Tim và Đột Quỵ")
plt.show()

# %% [markdown]
# Biểu đồ đếm tình trạng kết hôn và đột quỵ

# %%
plt.figure(figsize=(8,5))
sns.countplot(data=df, x="ever_married", hue="stroke")
plt.title("Tình trạng Kết Hôn và Đột Quỵ")
plt.show()

# %% [markdown]
# Biểu đồ đếm loại nơi cư trú và đột quỵ

# %%
plt.figure(figsize=(8,5))
sns.countplot(data=df, x="Residence_type", hue="stroke")
plt.title("Loại Nơi Cư Trú và Đột Quỵ")
plt.show()

# %% [markdown]
# phân bố các nhóm tình trạng hút thuốc theo tình trạng đột quỵ

# %%
sns.histplot(x='smoking_status',data=df,hue='stroke',multiple='dodge')
# Out:
# <Axes: xlabel='smoking_status', ylabel='Count'>

# %% [markdown]
# ## Age

# %%
def age_number(age):
    if age <= 10:
        return '0'
    elif 10 < age <= 20:
        return '1'
    elif 20 < age <= 30:
        return '2'    
    elif 30 < age <= 40:
        return '3'
    elif 40 < age <= 50:
        return '4'
    elif 50 < age <= 60:
        return '5'
    elif 60 < age <= 70:
        return '6'
    elif 70 < age <= 80:
        return '7'
    elif 80 < age <= 90:
        return '8'
    else:
        return '9'

df['age_number'] = df['age'].apply(age_number)
age_pro = df.groupby(['age_number', 'stroke']).size().reset_index(name='count')
total_counts = df.groupby('age_number')['id'].count().reset_index(name='total_count')
age_pro = age_pro.merge(total_counts, on='age_number', how='left')
age_pro['proportion'] = round((age_pro['count'] / age_pro['total_count']), 2)
age_pro
# Out:
#    age_number  stroke  count  total_count  proportion
# 0           0       0    506          507        1.00
# 1           0       1      1          507        0.00
# 2           1       0    517          518        1.00
# 3           1       1      1          518        0.00
# 4           2       0    545          545        1.00
# 5           3       0    668          674        0.99
# 6           3       1      6          674        0.01
# 7           4       0    724          739        0.98
# 8           4       1     15          739        0.02
# 9           5       0    774          823        0.94
# 10          5       1     49          823        0.06
# 11          6       0    545          594        0.92
# 12          6       1     49          594        0.08
# 13          7       0    489          594        0.82
# 14          7       1    105          594        0.18
# 15          8       0     93          116        0.80
# 16          8       1     23          116        0.20

# %%
filtered_data = age_pro[(age_pro['stroke'] == 1) & (age_pro['age_number'] != '1')]
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])
ax.plot(filtered_data['age_number'], filtered_data['proportion'], marker='x')
plt.xlabel('Age number')
plt.ylabel('Tỷ lệ đột quỵ (%)')
plt.title('Tỷ lệ đột quỵ theo từng độ tuổi')
plt.show()

# %% [markdown]
# ## Smoking

# %%
smoke = df.groupby(['smoking_status', 'stroke']).size().reset_index(name='count')
total_counts = df.groupby('smoking_status')['id'].count().reset_index(name='total_count')
smoke = smoke.merge(total_counts, on='smoking_status', how='left')
smoke['proportion'] = round((smoke['count'] / smoke['total_count']), 6)
smoke = smoke.set_index(['smoking_status', 'stroke'])
smoke
# Out:
#                         count  total_count  proportion
# smoking_status  stroke
# Unknown         0        1497         1544    0.969560
#                 1          47         1544    0.030440
# formerly smoked 0         815          885    0.920904
#                 1          70          885    0.079096
# never smoked    0        1802         1892    0.952431
#                 1          90         1892    0.047569
# smokes          0         747          789    0.946768
#                 1          42          789    0.053232

# %%
stroke_data = smoke.reset_index()
stroke_data = stroke_data[stroke_data['stroke'] == 1]

fig, ax = plt.subplots(figsize=(8, 5))
ax.bar(stroke_data['smoking_status'], stroke_data['proportion'], color='skyblue')
plt.xlabel('Smoking Status', fontsize=12)
plt.ylabel('Tỷ lệ đột quỵ (%)', fontsize=12)
plt.title('Tỷ lệ đột quỵ theo tình trạng hút thuốc', fontsize=14)
plt.xticks(rotation=45, fontsize=10)
plt.ylim(0, max(stroke_data['proportion']) * 1.1)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Relationship

# %%
combined_data = df.groupby(['age_number', 'smoking_status', 'stroke']).size().reset_index(name='count')
total_counts = df.groupby(['age_number', 'smoking_status'])['id'].count().reset_index(name='total_count')
combined_data = combined_data.merge(total_counts, on=['age_number', 'smoking_status'], how='left')
combined_data['proportion'] = round(combined_data['count'] / combined_data['total_count'], 6)
combined_data = combined_data.set_index(['age_number', 'smoking_status', 'stroke'])
combined_data
# Out:
#                                    count  total_count  proportion
# age_number smoking_status  stroke
# 0          Unknown         0         496          497    0.997988
#                            1           1          497    0.002012
#            formerly smoked 0           4            4    1.000000
#            never smoked    0           5            5    1.000000
#            smokes          0           1            1    1.000000
# ...                                  ...          ...         ...
# 8          formerly smoked 1           5           31    0.161290
#            never smoked    0          40           52    0.769231
#                            1          12           52    0.230769
#            smokes          0           8           11    0.727273
#                            1           3           11    0.272727
#
# [61 rows x 3 columns]

# %%
combined_data = combined_data.reset_index()
stroke_data = combined_data[combined_data['stroke'] == 1]
fig, ax = plt.subplots(figsize=(10, 6))
sns.lineplot(data=stroke_data, x='age_number', y='proportion', hue='smoking_status', style='smoking_status', markers=True, ax=ax)
plt.title('Proportion of Strokes per Age Category & Smoking Status', fontsize=14)
plt.xlabel('Age Category', fontsize=12)
plt.ylabel('Proportion of Strokes', fontsize=12)
plt.legend(title='Smoking Status', fontsize=10)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## BMI

# %%
g = sns.FacetGrid(df, col="stroke", height=5, aspect=1)
g.map(sns.scatterplot, 'bmi', 'avg_glucose_level', alpha=0.5)
g.fig.suptitle(' Biểu đồ phân tán giữa BMI và mức đường huyết trung bình theo tình trạng đột quỵ', y=1.02)
g.set_axis_labels("BMI", "Average Glucose Level")
plt.show()

# %% [markdown]
# ## Gender

# %%
stroke_by_gender = df[df['stroke'] == 1]['gender'].value_counts()
stroke_by_gender.plot(kind='pie', autopct='%1.1f%%', figsize=(8, 6), colors=['lightblue', 'pink'])
plt.title('Tỷ lệ phần trăm các ca đột quỵ theo giới tính')
plt.ylabel('')  
plt.show()

# %% [markdown]
# ## Married

# %%
stroke_by_married = df[df['stroke'] == 1]['ever_married'].value_counts()
stroke_by_married.plot(kind='pie', autopct='%1.1f%%', figsize=(8, 6), colors=['lightblue', 'pink'])
plt.title('Tỷ lệ phần trăm các ca đột quỵ theo tình trạng hôn nhân')
plt.ylabel('')  
plt.show()

# %% [markdown]
# # Data Preprocessing

# %%
df = df.drop(['id', 'age_number'], axis=1, errors='ignore')
df
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  67.0             0              1          Yes        Private
# 1     Female  61.0             0              0          Yes  Self-employed
# 2       Male  80.0             0              1          Yes        Private
# 3     Female  49.0             0              0          Yes        Private
# 4     Female  79.0             1              0          Yes  Self-employed
# ...      ...   ...           ...            ...          ...            ...
# 5105  Female  80.0             1              0          Yes        Private
# 5106  Female  81.0             0              0          Yes  Self-employed
# 5107  Female  35.0             0              0          Yes  Self-employed
# 5108    Male  51.0             0              0          Yes        Private
# 5109  Female  44.0             0              0          Yes       Govt_job
#
#      Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0             Urban             228.69  36.6  formerly smoked       1
# 1             Rural             202.21   NaN     never smoked       1
# 2             Rural             105.92  32.5     never smoked       1
# 3             Urban             171.23  34.4           smokes       1
# 4             Rural             174.12  24.0     never smoked       1
# ...             ...                ...   ...              ...     ...
# 5105          Urban              83.75   NaN     never smoked       0
# 5106          Urban             125.20  40.0     never smoked       0
# 5107          Rural              82.99  30.6     never smoked       0
# 5108          Rural             166.29  25.6  formerly smoked       0
# 5109          Urban              85.28  26.2          Unknown       0
#
# [5110 rows x 11 columns]

# %%
df.drop(df[df['gender'] == 'Other'].index, inplace=True)
category_counts = df['gender'].value_counts()
category_counts
# Out:
# Female    2994
# Male      2115
# Name: gender, dtype: int64

# %%
category_counts = df['ever_married'].value_counts()
category_counts
# Out:
# Yes    3353
# No     1756
# Name: ever_married, dtype: int64

# %%
category_counts = df['work_type'].value_counts()
category_counts
# Out:
# Private          2924
# Self-employed     819
# children          687
# Govt_job          657
# Never_worked       22
# Name: work_type, dtype: int64

# %%
category_counts = df['Residence_type'].value_counts()
category_counts
# Out:
# Urban    2596
# Rural    2513
# Name: Residence_type, dtype: int64

# %%
category_counts = df['smoking_status'].value_counts()
category_counts
# Out:
# never smoked       1892
# Unknown            1544
# formerly smoked     884
# smokes              789
# Name: smoking_status, dtype: int64

# %%
def find_missing_groups(df, column):
    missing = df[column].isnull()  
    groups = []
    current_group = []
    
    for idx, is_missing in missing.items():
        if is_missing:
            current_group.append(idx)
        else:
            if current_group:
                groups.append(current_group)
                current_group = []
    
    if current_group:
        groups.append(current_group)
    
    return groups

missing_groups = find_missing_groups(df, 'bmi')
print("Các nhóm giá trị thiếu trong cột bmi:", missing_groups)

total_missing = sum(len(group) for group in missing_groups)
print("Tổng số giá trị bị thiếu:", total_missing)
# Out:
# Các nhóm giá trị thiếu trong cột bmi: [[1], [8], [13], [19], [27], [29], [43], [46], [50, 51], [54], [57], [64], [70], [78], [81], [84], [105], [112], [124], [126], [129], [133], [146], [150], [160, 161, 162], [167], [170, 171], [174], [178], [183], [189], [198], [200], [218], [227], [247], [342], [360], [432], [477], [479], [522], [668], [671], [680], [729], [742], [865], [867], [872], [879], [903], [936], [965], [1102], [1106], [1115], [1183], [1194], [1214], [1235], [1241], [1277], [1293], [1300], [1306], [1324], [1342], [1352], [1427], [1457], [1466], [1468], [1471], [1503], [1528], [1539], [1546], [1596], [1640], [1644], [1646], [1650], [1669, 1670], [1681], [1718, 1719], [1730], [1753], [1756], [1779], [1816], [1836, 1837], [1866], [1894], [1906], [1912], [1981], [1993], [2030], [2103], [2105], [2109], [2192], [2215], [2263], [2285], [2321, 2322], [2339], [2343], [2477], [2494], [2502], [2515], [2529], [2532], [2541], [2582], [2697], [2739], [2752], [2768], [2788], [2816], [2828], [2855], [2867], [2879], [2897], [2914], [2960], [2997], [3007], [3028], [3048], [3059], [3074], [3104], [3111], [3135], [3161, 3162], [3164], [3176], [3197], [3214, 3215, 3216], [3375], [3382], [3425], [3431], [3503], [3562], [3605], [3629], [3681], [3699], [3705], [3726], [3734], [3802], [3808], [3872], [3913], [3940], [3945], [3951], [4046], [4069], [4164], [4202], [4230], [4255], [4283], [4286], [4422], [4451], [4522], [4561], [4616], [4684], [4713], [4750], [4790], [4921], [4934], [4949], [4984], [5039], [5048], [5093], [5099], [5105]]
# Tổng số giá trị bị thiếu: 201

# %%
cols = ['gender', 'ever_married', 'work_type', 'Residence_type', 'smoking_status']
df = pd.get_dummies(df, columns=cols)

# %%
print("Số giá trị missing ban đầu:", df['bmi'].isnull().sum())
df['bmi'] = df['bmi'].interpolate(method='linear')
print("Số giá trị missing sau khi nội suy:", df['bmi'].isnull().sum())
# Out:
# Số giá trị missing ban đầu: 201
# Số giá trị missing sau khi nội suy: 0

# %%
plt.figure(figsize=(12, 8))
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# # Feature selection

# %%
X = df.drop(["stroke"], axis=1)
y = df['stroke']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
smote = SMOTETomek(random_state=42)
X_train, y_train = smote.fit_resample(X_train, y_train)
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

sns.countplot(x = y, ax=axes[0])
axes[0].set(title="Phân bố lớp trước khi áp dụng SMOTETomek", xlabel="stroke", ylabel="Count")

sns.countplot(x = y_train, ax=axes[1])
axes[1].set(title="Phân bố lớp sau khi áp dụng SMOTETomek", xlabel="stroke", ylabel="Count")

plt.tight_layout()
plt.show()

# %%
import joblib
joblib.dump(X_train, 'X_train.pkl')
joblib.dump(X_test, 'X_test.pkl')
joblib.dump(y_train, 'y_train.pkl')
joblib.dump(y_test, 'y_test.pkl')
# Out:
# ['y_test.pkl']

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
# joblib.dump(scaler, "scaler.pkl")

# %%
print("Shape of x_train:", X_train.shape)
print("Shape of x_test:", X_test.shape)
print("Shape of y_train:", y_train.shape)
print("Shape of y_test:", y_test.shape)
# Out:
# Shape of x_train: (6770, 20)
# Shape of x_test: (1533, 20)
# Shape of y_train: (6770,)
# Shape of y_test: (1533,)

# %% [markdown]
# ## Train model ML

# %%
def evaluate_model(y_true, y_pred):
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, zero_division=0)
    recall = recall_score(y_true, y_pred, zero_division=0)
    f1 = f1_score(y_true, y_pred, zero_division=0)
    auc = roc_auc_score(y_true, y_pred)

    table = PrettyTable()
    table.field_names = ["Metric", "Value"]
    table.add_row(["Accuracy", round(accuracy, 3)])
    table.add_row(["Precision", round(precision, 3)])
    table.add_row(["Recall", round(recall, 3)])
    table.add_row(["F1 Score", round(f1, 3)])
    table.add_row(["AUC", round(auc, 3)])
    
    return table

# %% [markdown]
# #### KNN

# %%
knn = KNeighborsClassifier()

start_time = time.time()
knn.fit(X_train, y_train)
training_time = time.time() - start_time
print(f"Training time: {training_time:.3f} seconds")
print("=" * 80)

y_train_pred = knn.predict(X_train)
train_table = evaluate_model(y_train, y_train_pred)

y_test_pred = knn.predict(X_test)
test_table = evaluate_model(y_test, y_test_pred)

table1_str = train_table.get_string(title="KNN Model - Training Metrics")
table2_str = test_table.get_string(title="KNN Model - Testing Metrics")

lines1 = table1_str.split('\n')
lines2 = table2_str.split('\n')

max_lines = max(len(lines1), len(lines2))
lines1 += [""] * (max_lines - len(lines1))
lines2 += [""] * (max_lines - len(lines2))

for l1, l2 in zip(lines1, lines2):
    print(f"{l1:<45} {l2}")
print("=" * 80)

cv_scores = cross_val_score(knn, X_train, y_train, cv=5, scoring='accuracy')
print("KNN Model - Cross-Validation Scores:")
print(f"CV Mean Accuracy: {cv_scores.mean():.3f}")
print(f"CV Standard Deviation: {cv_scores.std():.3f}")
print("=" * 80)
print()

clf_report = classification_report(y_test, y_test_pred)
print("Classification Report:")
print(clf_report)
# Out:
# Training time: 0.002 seconds
# ================================================================================
# +------------------------------+              +-----------------------------+
# | KNN Model - Training Metrics |              | KNN Model - Testing Metrics |
# +------------------+-----------+              +-----------------+-----------+
# |      Metric      |   Value   |              |      Metric     |   Value   |
# +------------------+-----------+              +-----------------+-----------+
# |     Accuracy     |   0.976   |              |     Accuracy    |   0.932   |
# |    Precision     |   0.991   |              |    Precision    |   0.174   |
# |      Recall      |   0.961   |              |      Recall     |   0.045   |
# |     F1 Score     |   0.976   |              |     F1 Score    |   0.071   |
# |       AUC        |   0.976   |              |       AUC       |   0.516   |
# +------------------+-----------+              +-----------------+-----------+
# ================================================================================
# KNN Model - Cross-Validation Scores:
# CV Mean Accuracy: 0.967
# CV Standard Deviation: 0.036
# ================================================================================
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.96      1444
#            1       0.17      0.04      0.07        89
#
#     accuracy                           0.93      1533
#    macro avg       0.56      0.52      0.52      1533
# weighted avg       0.90      0.93      0.91      1533

# %%
disp = ConfusionMatrixDisplay(confusion_matrix(y_test, knn.predict(X_test)), display_labels=[0, 1])
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.show()

# %%
y_prob = knn.predict_proba(X_test)

roc_auc = roc_auc_score(y_test, y_prob[:, 1])

fpr = {}
tpr = {}
thresholds = {}

for i in range(len(knn.classes_)):
	fpr[i], tpr[i], thresholds[i] = roc_curve(y_test, y_prob[:, i], pos_label=i)

plt.figure()
for i in range(len(knn.classes_)):
	plt.plot(fpr[i], tpr[i], lw=2, label=f'Class {i} (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc='lower right')
plt.show()

print(f"AUC: {roc_auc:.2f}")
# Out:
# AUC: 0.62

# %%
knn_param_grid = {
    'n_neighbors': [3, 5, 7, 9, 11],
    'weights': ['uniform', 'distance'],
    'p': [1, 2],
    'metric': ['euclidean', 'manhattan', 'minkowski'],
    'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
    'leaf_size': [10, 20, 30, 40]
}

knn_grid_search = GridSearchCV(knn, knn_param_grid, cv=5, scoring='accuracy', n_jobs=-1)
knn_grid_search.fit(X_train, y_train)
print("Best Hyperparameters for KNN:")
table_hyperparams = PrettyTable()
table_hyperparams.field_names = ["Parameter", "Value"]
for param, value in knn_grid_search.best_params_.items():
    table_hyperparams.add_row([param, value])
print(table_hyperparams)
print("Best Accuracy for KNN: {:.4f}".format(knn_grid_search.best_score_))
# Out:
# Best Hyperparameters for KNN:
# +-------------+-----------+
# |  Parameter  |   Value   |
# +-------------+-----------+
# |  algorithm  |    auto   |
# |  leaf_size  |     10    |
# |    metric   | manhattan |
# | n_neighbors |     5     |
# |      p      |     1     |
# |   weights   |  distance |
# +-------------+-----------+
# Best Accuracy for KNN: 0.9704

# %%
best_knn_model = KNeighborsClassifier(**knn_grid_search.best_params_)
best_knn_model.fit(X_train, y_train)
y_test_pred = best_knn_model.predict(X_test)
test_accuracy = accuracy_score(y_test, y_test_pred)
test_precision = precision_score(y_test, y_test_pred)
test_recall = recall_score(y_test, y_test_pred)
test_f1 = f1_score(y_test, y_test_pred)
test_auc = roc_auc_score(y_test, y_test_pred)
print("Best KNN Model - Testing Metrics:")

table_testing = PrettyTable()
table_testing.field_names = ["Metric", "Value"]
table_testing.add_row(["Accuracy", round(test_accuracy, 3)])
table_testing.add_row(["Precision", round(test_precision, 3)])
table_testing.add_row(["Recall", round(test_recall, 3)])
table_testing.add_row(["F1 Score", round(test_f1, 3)])
table_testing.add_row(["AUC", round(test_auc, 3)])
print(table_testing)
# Out:
# Best KNN Model - Testing Metrics:
# +-----------+-------+
# |   Metric  | Value |
# +-----------+-------+
# |  Accuracy | 0.933 |
# | Precision | 0.217 |
# |   Recall  | 0.056 |
# |  F1 Score | 0.089 |
# |    AUC    | 0.522 |
# +-----------+-------+

# %%
cv_scores = cross_val_score(best_knn_model, X_train, y_train, cv=5, scoring='accuracy')
print("Best KNN Model - Cross-Validation Scores:")
print("CV Mean Accuracy: {:.4f}".format(round(cv_scores.mean(), 3)))
print("CV Standard Deviation: {:.4f}".format(round(cv_scores.std(), 3)))
# Out:
# Best KNN Model - Cross-Validation Scores:
# CV Mean Accuracy: 0.9720
# CV Standard Deviation: 0.0350

# %%
disp = ConfusionMatrixDisplay(confusion_matrix(y_test, y_test_pred), display_labels=[0, 1])
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# #### LogisticRegression

# %%
logis = LogisticRegression(class_weight='balanced', random_state=42)

start_time = time.time()
logis.fit(X_train, y_train)
training_time = time.time() - start_time
print(f"Training time: {training_time:.3f} seconds")
print("=" * 80)

y_train_pred = logis.predict(X_train)
train_table = evaluate_model(y_train, y_train_pred)

y_test_pred = logis.predict(X_test)
test_table = evaluate_model(y_test, y_test_pred)

table1_str = train_table.get_string(title="Logistic Model - Training Metrics")
table2_str = test_table.get_string(title="Logistic Model - Testing Metrics")

lines1 = table1_str.split('\n')
lines2 = table2_str.split('\n')

max_lines = max(len(lines1), len(lines2))
lines1 += [""] * (max_lines - len(lines1))
lines2 += [""] * (max_lines - len(lines2))

for l1, l2 in zip(lines1, lines2):
    print(f"{l1:<45} {l2}")
print("=" * 80)

cv_scores = cross_val_score(logis, X_train, y_train, cv=5, scoring='accuracy')
print("Logistic Model - Cross-Validation Scores:")
print(f"CV Mean Accuracy: {cv_scores.mean():.3f}")
print(f"CV Standard Deviation: {cv_scores.std():.3f}")
print("=" * 80)
print()

clf_report = classification_report(y_test, y_test_pred)
print("Classification Report:")
print(clf_report)
# Out:
# Training time: 0.018 seconds
# ================================================================================
# +-----------------------------------+         +----------------------------------+
# | Logistic Model - Training Metrics |         | Logistic Model - Testing Metrics |
# +---------------------+-------------+         +--------------------+-------------+
# |        Metric       |    Value    |         |       Metric       |    Value    |
# +---------------------+-------------+         +--------------------+-------------+
# |       Accuracy      |     0.96    |         |      Accuracy      |    0.942    |
# |      Precision      |    0.998    |         |     Precision      |     0.5     |
# |        Recall       |    0.922    |         |       Recall       |    0.045    |
# |       F1 Score      |    0.959    |         |      F1 Score      |    0.082    |
# |         AUC         |     0.96    |         |        AUC         |    0.521    |
# +---------------------+-------------+         +--------------------+-------------+
# ================================================================================
# Logistic Model - Cross-Validation Scores:
# CV Mean Accuracy: 0.959
# CV Standard Deviation: 0.043
# ================================================================================
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97      1444
#            1       0.50      0.04      0.08        89
#
#     accuracy                           0.94      1533
#    macro avg       0.72      0.52      0.53      1533
# weighted avg       0.92      0.94      0.92      1533

# %%
disp = ConfusionMatrixDisplay(confusion_matrix(y_test, logis.predict(X_test)), display_labels=[0, 1])
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.show()

# %%
y_prob = logis.predict_proba(X_test)

roc_auc = roc_auc_score(y_test, y_prob[:, 1])

fpr = {}
tpr = {}
thresholds = {}

for i in range(len(logis.classes_)):
	fpr[i], tpr[i], thresholds[i] = roc_curve(y_test, y_prob[:, i], pos_label=i)

plt.figure()
for i in range(len(logis.classes_)):
	plt.plot(fpr[i], tpr[i], lw=2, label=f'Class {i} (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc='lower right')
plt.show()

print(f"AUC: {roc_auc:.2f}")
# Out:
# AUC: 0.82

# %%
logis_param_grid = {
    'C': [0.01, 0.1, 1, 10, 100],
    'penalty': ['l1', 'l2', 'elasticnet'],
    'solver': ['liblinear', 'saga'],
    'max_iter': [100, 200, 500],
    'class_weight': [None, 'balanced'],
    'fit_intercept': [True, False],
    'l1_ratio': [None, 0.1, 0.5, 0.9]
}

logis_grid_search = GridSearchCV(logis, logis_param_grid, cv=5, scoring='f1', n_jobs=-1)
logis_grid_search.fit(X_train, y_train)
print("Best Hyperparameters for Logistic:")
table_hyperparams = PrettyTable()
table_hyperparams.field_names = ["Parameter", "Value"]
for param, value in logis_grid_search.best_params_.items():
    table_hyperparams.add_row([param, value])
print(table_hyperparams)
print("Best Accuracy for Logistic: {:.4f}".format(logis_grid_search.best_score_))
# Out:
# Best Hyperparameters for Logistic:
# +---------------+-------+
# |   Parameter   | Value |
# +---------------+-------+
# |       C       |   1   |
# |  class_weight |  None |
# | fit_intercept |  True |
# |    l1_ratio   |  None |
# |    max_iter   |  100  |
# |    penalty    |   l1  |
# |     solver    |  saga |
# +---------------+-------+
# Best Accuracy for Logistic: 0.9551

# %%
best_logis_model = LogisticRegression(**logis_grid_search.best_params_)
best_logis_model.fit(X_train, y_train)
y_test_pred = best_logis_model.predict(X_test)
test_accuracy = accuracy_score(y_test, y_test_pred)
test_precision = precision_score(y_test, y_test_pred)
test_recall = recall_score(y_test, y_test_pred)
test_f1 = f1_score(y_test, y_test_pred)
test_auc = roc_auc_score(y_test, y_test_pred)
print("Best Logistic Model - Testing Metrics:")

table_testing = PrettyTable()
table_testing.field_names = ["Metric", "Value"]
table_testing.add_row(["Accuracy", round(test_accuracy, 3)])
table_testing.add_row(["Precision", round(test_precision, 3)])
table_testing.add_row(["Recall", round(test_recall, 3)])
table_testing.add_row(["F1 Score", round(test_f1, 3)])
table_testing.add_row(["AUC", round(test_auc, 3)])
print(table_testing)
# Out:
# Best Logistic Model - Testing Metrics:
# +-----------+-------+
# |   Metric  | Value |
# +-----------+-------+
# |  Accuracy | 0.942 |
# | Precision |  0.5  |
# |   Recall  | 0.045 |
# |  F1 Score | 0.082 |
# |    AUC    | 0.521 |
# +-----------+-------+

# %%
cv_scores = cross_val_score(best_logis_model, X_train, y_train, cv=5, scoring='accuracy')
print("Best Logistic Model - Cross-Validation Scores:")
print("CV Mean Accuracy: {:.4f}".format(round(cv_scores.mean(), 3)))
print("CV Standard Deviation: {:.4f}".format(round(cv_scores.std(), 3)))
# Out:
# Best Logistic Model - Cross-Validation Scores:
# CV Mean Accuracy: 0.9590
# CV Standard Deviation: 0.0430

# %%
disp = ConfusionMatrixDisplay(confusion_matrix(y_test, y_test_pred), display_labels=[0, 1])
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# #### DecisionTreeClassifier

# %%
decision = DecisionTreeClassifier(class_weight='balanced', random_state=42)

start_time = time.time()
decision.fit(X_train, y_train)
training_time = time.time() - start_time
print(f"Training time: {training_time:.3f} seconds")
print("=" * 80)

y_train_pred = decision.predict(X_train)
train_table = evaluate_model(y_train, y_train_pred)

y_test_pred = decision.predict(X_test)
test_table = evaluate_model(y_test, y_test_pred)

table1_str = train_table.get_string(title="DecisionTree Model - Training Metrics")
table2_str = test_table.get_string(title="DecisionTree Model - Testing Metrics")

lines1 = table1_str.split('\n')
lines2 = table2_str.split('\n')

max_lines = max(len(lines1), len(lines2))
lines1 += [""] * (max_lines - len(lines1))
lines2 += [""] * (max_lines - len(lines2))

for l1, l2 in zip(lines1, lines2):
    print(f"{l1:<45} {l2}")
print("=" * 80)

cv_scores = cross_val_score(decision, X_train, y_train, cv=5, scoring='accuracy')
print("DecisionTree Model - Cross-Validation Scores:")
print(f"CV Mean Accuracy: {cv_scores.mean():.3f}")
print(f"CV Standard Deviation: {cv_scores.std():.3f}")
print("=" * 80)
print()

clf_report = classification_report(y_test, y_test_pred)
print("Classification Report:")
print(clf_report)
# Out:
# Training time: 0.021 seconds
# ================================================================================
# +---------------------------------------+     +--------------------------------------+
# | DecisionTree Model - Training Metrics |     | DecisionTree Model - Testing Metrics |
# +-----------------------+---------------+     +-----------------------+--------------+
# |         Metric        |     Value     |     |         Metric        |    Value     |
# +-----------------------+---------------+     +-----------------------+--------------+
# |        Accuracy       |      1.0      |     |        Accuracy       |    0.897     |
# |       Precision       |      1.0      |     |       Precision       |    0.152     |
# |         Recall        |      1.0      |     |         Recall        |    0.169     |
# |        F1 Score       |      1.0      |     |        F1 Score       |     0.16     |
# |          AUC          |      1.0      |     |          AUC          |    0.555     |
# +-----------------------+---------------+     +-----------------------+--------------+
# ================================================================================
# DecisionTree Model - Cross-Validation Scores:
# CV Mean Accuracy: 0.946
# CV Standard Deviation: 0.021
# ================================================================================
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.94      0.95      1444
#            1       0.15      0.17      0.16        89
#
#     accuracy                           0.90      1533
#    macro avg       0.55      0.56      0.55      1533
# weighted avg       0.90      0.90      0.90      1533

# %%
disp = ConfusionMatrixDisplay(confusion_matrix(y_test, decision.predict(X_test)), display_labels=[0, 1])
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.show()

# %%
y_prob = decision.predict_proba(X_test)

roc_auc = roc_auc_score(y_test, y_prob[:, 1])

fpr = {}
tpr = {}
thresholds = {}

for i in range(len(decision.classes_)):
	fpr[i], tpr[i], thresholds[i] = roc_curve(y_test, y_prob[:, i], pos_label=i)

plt.figure()
for i in range(len(decision.classes_)):
	plt.plot(fpr[i], tpr[i], lw=2, label=f'Class {i} (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc='lower right')
plt.show()

print(f"AUC: {roc_auc:.2f}")
# Out:
# AUC: 0.56

# %%
decision_param_grid = {
    'criterion': ['gini', 'entropy'],                
    'splitter': ['best', 'random'],                    
    'max_depth': [None, 3, 5, 10, 20],                 
    'min_samples_split': [2, 5, 10],                 
    'min_samples_leaf': [1, 2, 4],                   
    'max_features': [None, 'sqrt', 'log2'],         
    'class_weight': [None, 'balanced'],              
    'min_weight_fraction_leaf': [0.0, 0.1, 0.2],       
    'ccp_alpha': [0.0, 0.01, 0.1]                  
}

decision_grid_search = GridSearchCV(decision, decision_param_grid, cv=5, scoring='accuracy', n_jobs=-1)
decision_grid_search.fit(X_train, y_train)
print("Best Hyperparameters for DecisionTree:")
table_hyperparams = PrettyTable()
table_hyperparams.field_names = ["Parameter", "Value"]
for param, value in decision_grid_search.best_params_.items():
    table_hyperparams.add_row([param, value])
print(table_hyperparams)
print("Best Accuracy for DecisionTree: {:.4f}".format(decision_grid_search.best_score_))
# Out:
# Best Hyperparameters for DecisionTree:
# +--------------------------+----------+
# |        Parameter         |  Value   |
# +--------------------------+----------+
# |        ccp_alpha         |   0.0    |
# |       class_weight       | balanced |
# |        criterion         | entropy  |
# |        max_depth         |   None   |
# |       max_features       |   None   |
# |     min_samples_leaf     |    1     |
# |    min_samples_split     |    10    |
# | min_weight_fraction_leaf |   0.0    |
# |         splitter         |  random  |
# +--------------------------+----------+
# Best Accuracy for DecisionTree: 0.9654

# %%
best_decision_model = DecisionTreeClassifier(**decision_grid_search.best_params_)
best_decision_model.fit(X_train, y_train)
y_test_pred = best_decision_model.predict(X_test)
test_accuracy = accuracy_score(y_test, y_test_pred)
test_precision = precision_score(y_test, y_test_pred)
test_recall = recall_score(y_test, y_test_pred)
test_f1 = f1_score(y_test, y_test_pred)
test_auc = roc_auc_score(y_test, y_test_pred)
print("Best DecisionTree Model - Testing Metrics:")

table_testing = PrettyTable()
table_testing.field_names = ["Metric", "Value"]
table_testing.add_row(["Accuracy", round(test_accuracy, 3)])
table_testing.add_row(["Precision", round(test_precision, 3)])
table_testing.add_row(["Recall", round(test_recall, 3)])
table_testing.add_row(["F1 Score", round(test_f1, 3)])
table_testing.add_row(["AUC", round(test_auc, 3)])
print(table_testing)
# Out:
# Best DecisionTree Model - Testing Metrics:
# +-----------+-------+
# |   Metric  | Value |
# +-----------+-------+
# |  Accuracy | 0.924 |
# | Precision | 0.091 |
# |   Recall  | 0.034 |
# |  F1 Score | 0.049 |
# |    AUC    | 0.506 |
# +-----------+-------+

# %%
cv_scores = cross_val_score(best_decision_model, X_train, y_train, cv=5, scoring='accuracy')
print("Best DecisionTree Model - Cross-Validation Scores:")
print("CV Mean Accuracy: {:.4f}".format(round(cv_scores.mean(), 3)))
print("CV Standard Deviation: {:.4f}".format(round(cv_scores.std(), 3)))
# Out:
# Best DecisionTree Model - Cross-Validation Scores:
# CV Mean Accuracy: 0.9600
# CV Standard Deviation: 0.0360

# %%
disp = ConfusionMatrixDisplay(confusion_matrix(y_test, y_test_pred), display_labels=[0, 1])
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# #### RandomForestClassifier

# %%
rf = RandomForestClassifier(class_weight='balanced', random_state=42)

start_time = time.time()
rf.fit(X_train, y_train)
training_time = time.time() - start_time
print(f"Training time: {training_time:.3f} seconds")
print("=" * 80)

y_train_pred = rf.predict(X_train)
train_table = evaluate_model(y_train, y_train_pred)

y_test_pred = rf.predict(X_test)
test_table = evaluate_model(y_test, y_test_pred)

table1_str = train_table.get_string(title="RandomForest Model - Training Metrics")
table2_str = test_table.get_string(title="RandomForest Model - Testing Metrics")

lines1 = table1_str.split('\n')
lines2 = table2_str.split('\n')

max_lines = max(len(lines1), len(lines2))
lines1 += [""] * (max_lines - len(lines1))
lines2 += [""] * (max_lines - len(lines2))

for l1, l2 in zip(lines1, lines2):
    print(f"{l1:<45} {l2}")
print("=" * 80)

cv_scores = cross_val_score(rf, X_train, y_train, cv=5, scoring='accuracy')
print("RandomForest Model - Cross-Validation Scores:")
print(f"CV Mean Accuracy: {cv_scores.mean():.3f}")
print(f"CV Standard Deviation: {cv_scores.std():.3f}")
print("=" * 80)
print()

clf_report = classification_report(y_test, y_test_pred)
print("Classification Report:")
print(clf_report)
# Out:
# Training time: 0.518 seconds
# ================================================================================
# +---------------------------------------+     +--------------------------------------+
# | RandomForest Model - Training Metrics |     | RandomForest Model - Testing Metrics |
# +-----------------------+---------------+     +-----------------------+--------------+
# |         Metric        |     Value     |     |         Metric        |    Value     |
# +-----------------------+---------------+     +-----------------------+--------------+
# |        Accuracy       |      1.0      |     |        Accuracy       |    0.938     |
# |       Precision       |      1.0      |     |       Precision       |     0.2      |
# |         Recall        |      1.0      |     |         Recall        |    0.022     |
# |        F1 Score       |      1.0      |     |        F1 Score       |     0.04     |
# |          AUC          |      1.0      |     |          AUC          |    0.508     |
# +-----------------------+---------------+     +-----------------------+--------------+
# ================================================================================
# RandomForest Model - Cross-Validation Scores:
# CV Mean Accuracy: 0.974
# CV Standard Deviation: 0.038
# ================================================================================
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.97      1444
#            1       0.20      0.02      0.04        89
#
#     accuracy                           0.94      1533
#    macro avg       0.57      0.51      0.50      1533
# weighted avg       0.90      0.94      0.91      1533

# %%
disp = ConfusionMatrixDisplay(confusion_matrix(y_test, rf.predict(X_test)), display_labels=[0, 1])
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.show()

# %%
y_prob = rf.predict_proba(X_test)

roc_auc = roc_auc_score(y_test, y_prob[:, 1])

fpr = {}
tpr = {}
thresholds = {}

for i in range(len(rf.classes_)):
	fpr[i], tpr[i], thresholds[i] = roc_curve(y_test, y_prob[:, i], pos_label=i)

plt.figure()
for i in range(len(rf.classes_)):
	plt.plot(fpr[i], tpr[i], lw=2, label=f'Class {i} (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc='lower right')
plt.show()

print(f"AUC: {roc_auc:.2f}")
# Out:
# AUC: 0.78

# %%
rf_param_grid = {
    'n_estimators': [100, 200, 300, 500],          
    'max_depth': [10, 20, 30, 50, None],         
    'min_samples_split': [2, 5, 10, 20],          
    'min_samples_leaf': [1, 2, 4, 8],   
    'criterion': ['gini', 'entropy', 'log_loss'],        
    'max_features': ['auto', 'sqrt', 'log2']
}


rf_grid_search = GridSearchCV(rf, rf_param_grid, cv=5, scoring='accuracy', n_jobs=-1)
rf_grid_search.fit(X_train, y_train)
print("Best Hyperparameters for RandomForest:")
table_hyperparams = PrettyTable()
table_hyperparams.field_names = ["Parameter", "Value"]
for param, value in rf_grid_search.best_params_.items():
    table_hyperparams.add_row([param, value])
print(table_hyperparams)
print("Best Accuracy for RandomForest: {:.4f}".format(rf_grid_search.best_score_))
# Out:
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py:540: FitFailedWarning:
# 4800 fits failed out of a total of 14400.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 2992 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 1808 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_search.py:1103: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan ... 0.96602659 0.96632201 0.96706056]
#   warnings.warn(
# Best Hyperparameters for RandomForest:
# +-------------------+---------+
# |     Parameter     |  Value  |
# +-------------------+---------+
# |     criterion     | entropy |
# |     max_depth     |    20   |
# |    max_features   |   sqrt  |
# |  min_samples_leaf |    1    |
# | min_samples_split |    5    |
# |    n_estimators   |   300   |
# +-------------------+---------+
# Best Accuracy for RandomForest: 0.9755

# %%
best_rf_model = RandomForestClassifier(**rf_grid_search.best_params_)
best_rf_model.fit(X_train, y_train)
y_test_pred = best_rf_model.predict(X_test)
test_accuracy = accuracy_score(y_test, y_test_pred)
test_precision = precision_score(y_test, y_test_pred)
test_recall = recall_score(y_test, y_test_pred)
test_f1 = f1_score(y_test, y_test_pred)
test_auc = roc_auc_score(y_test, y_test_pred)
print("Best RandomForest Model - Testing Metrics:")

table_testing = PrettyTable()
table_testing.field_names = ["Metric", "Value"]
table_testing.add_row(["Accuracy", round(test_accuracy, 3)])
table_testing.add_row(["Precision", round(test_precision, 3)])
table_testing.add_row(["Recall", round(test_recall, 3)])
table_testing.add_row(["F1 Score", round(test_f1, 3)])
table_testing.add_row(["AUC", round(test_auc, 3)])
print(table_testing)
# Out:
# Best RandomForest Model - Testing Metrics:
# +-----------+-------+
# |   Metric  | Value |
# +-----------+-------+
# |  Accuracy |  0.94 |
# | Precision |  0.2  |
# |   Recall  | 0.011 |
# |  F1 Score | 0.021 |
# |    AUC    | 0.504 |
# +-----------+-------+

# %%
cv_scores = cross_val_score(best_rf_model, X_train, y_train, cv=5, scoring='accuracy')
print("Best RandomForest Model - Cross-Validation Scores:")
print("CV Mean Accuracy: {:.4f}".format(round(cv_scores.mean(), 3)))
print("CV Standard Deviation: {:.4f}".format(round(cv_scores.std(), 3)))
# Out:
# Best RandomForest Model - Cross-Validation Scores:
# CV Mean Accuracy: 0.9750
# CV Standard Deviation: 0.0390

# %%
disp = ConfusionMatrixDisplay(confusion_matrix(y_test, y_test_pred), display_labels=[0, 1])
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# #### SVM

# %%
svm = SVC(probability=True)

start_time = time.time()
svm.fit(X_train, y_train)
training_time = time.time() - start_time
print(f"Training time: {training_time:.3f} seconds")
print("=" * 80)

y_train_pred = svm.predict(X_train)
train_table = evaluate_model(y_train, y_train_pred)

y_test_pred = svm.predict(X_test)
test_table = evaluate_model(y_test, y_test_pred)

table1_str = train_table.get_string(title="SVC Model - Training Metrics")
table2_str = test_table.get_string(title="SVC Model - Testing Metrics")

lines1 = table1_str.split('\n')
lines2 = table2_str.split('\n')

max_lines = max(len(lines1), len(lines2))
lines1 += [""] * (max_lines - len(lines1))
lines2 += [""] * (max_lines - len(lines2))

for l1, l2 in zip(lines1, lines2):
    print(f"{l1:<45} {l2}")
print("=" * 80)

cv_scores = cross_val_score(svm, X_train, y_train, cv=5, scoring='accuracy')
print("SVC Model - Cross-Validation Scores:")
print(f"CV Mean Accuracy: {cv_scores.mean():.3f}")
print(f"CV Standard Deviation: {cv_scores.std():.3f}")
print("=" * 80)
print()

clf_report = classification_report(y_test, y_test_pred)
print("Classification Report:")
print(clf_report)
# Out:
# Training time: 1.076 seconds
# ================================================================================
# +------------------------------+              +-----------------------------+
# | SVC Model - Training Metrics |              | SVC Model - Testing Metrics |
# +------------------+-----------+              +-----------------+-----------+
# |      Metric      |   Value   |              |      Metric     |   Value   |
# +------------------+-----------+              +-----------------+-----------+
# |     Accuracy     |   0.968   |              |     Accuracy    |   0.938   |
# |    Precision     |   0.997   |              |    Precision    |    0.25   |
# |      Recall      |    0.94   |              |      Recall     |   0.034   |
# |     F1 Score     |   0.967   |              |     F1 Score    |   0.059   |
# |       AUC        |   0.968   |              |       AUC       |   0.514   |
# +------------------+-----------+              +-----------------+-----------+
# ================================================================================
# SVC Model - Cross-Validation Scores:
# CV Mean Accuracy: 0.967
# CV Standard Deviation: 0.044
# ================================================================================
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.97      1444
#            1       0.25      0.03      0.06        89
#
#     accuracy                           0.94      1533
#    macro avg       0.60      0.51      0.51      1533
# weighted avg       0.90      0.94      0.92      1533

# %%
disp = ConfusionMatrixDisplay(confusion_matrix(y_test, svm.predict(X_test)), display_labels=[0, 1])
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.show()

# %%
y_prob = svm.predict_proba(X_test)

roc_auc = roc_auc_score(y_test, y_prob[:, 1])

fpr = {}
tpr = {}
thresholds = {}

for i in range(len(svm.classes_)):
	fpr[i], tpr[i], thresholds[i] = roc_curve(y_test, y_prob[:, i], pos_label=i)

plt.figure()
for i in range(len(svm.classes_)):
	plt.plot(fpr[i], tpr[i], lw=2, label=f'Class {i} (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc='lower right')
plt.show()

print(f"AUC: {roc_auc:.2f}")
# Out:
# AUC: 0.75

# %%
svc_param_grid = {
    'C': [0.1, 1, 10],
    'kernel': ['linear', 'rbf', 'poly'],
    'gamma': ['scale', 'auto', 0.1, 1]
}

svm_grid_search = GridSearchCV(svm, svc_param_grid, cv=5, scoring='accuracy', n_jobs=-1)
svm_grid_search.fit(X_train, y_train)

print("Best Hyperparameters for SVC:")
table_hyperparams = PrettyTable()
table_hyperparams.field_names = ["Parameter", "Value"]
for param, value in svm_grid_search.best_params_.items():
    table_hyperparams.add_row([param, value])
    
print(table_hyperparams)
print("Best Accuracy for SVC: {:.4f}".format(svm_grid_search.best_score_))
# Out:
# Best Hyperparameters for SVC:
# +-----------+-------+
# | Parameter | Value |
# +-----------+-------+
# |     C     |   1   |
# |   gamma   |   1   |
# |   kernel  |  rbf  |
# +-----------+-------+
# Best Accuracy for SVC: 0.9703

# %%
best_svm_model = SVC(**svm_grid_search.best_params_, probability=True)
best_svm_model.fit(X_train, y_train)
y_test_pred = best_svm_model.predict(X_test)
test_accuracy = accuracy_score(y_test, y_test_pred)
test_precision = precision_score(y_test, y_test_pred)
test_recall = recall_score(y_test, y_test_pred)
test_f1 = f1_score(y_test, y_test_pred)
test_auc = roc_auc_score(y_test, y_test_pred)
print("Best SVC Model - Testing Metrics:")

table_testing = PrettyTable()
table_testing.field_names = ["Metric", "Value"]
table_testing.add_row(["Accuracy", round(test_accuracy, 3)])
table_testing.add_row(["Precision", round(test_precision, 3)])
table_testing.add_row(["Recall", round(test_recall, 3)])
table_testing.add_row(["F1 Score", round(test_f1, 3)])
table_testing.add_row(["AUC", round(test_auc, 3)])
print(table_testing)
# Out:
# Best SVC Model - Testing Metrics:
# +-----------+-------+
# |   Metric  | Value |
# +-----------+-------+
# |  Accuracy | 0.933 |
# | Precision | 0.111 |
# |   Recall  | 0.022 |
# |  F1 Score | 0.037 |
# |    AUC    | 0.506 |
# +-----------+-------+

# %%
cv_scores = cross_val_score(best_svm_model, X_train, y_train, cv=5, scoring='accuracy')
print("Best SVC Model - Cross-Validation Scores:")
print("CV Mean Accuracy: {:.4f}".format(round(cv_scores.mean(), 3)))
print("CV Standard Deviation: {:.4f}".format(round(cv_scores.std(), 3)))
# Out:
# Best SVC Model - Cross-Validation Scores:
# CV Mean Accuracy: 0.9700
# CV Standard Deviation: 0.0410

# %%
disp = ConfusionMatrixDisplay(confusion_matrix(y_test, y_test_pred), display_labels=[0, 1])
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# #### LGBMClassifier

# %%
lgbm = LGBMClassifier()

start_time = time.time()
lgbm.fit(X_train, y_train)
training_time = time.time() - start_time
print(f"Training time: {training_time:.3f} seconds")
print("=" * 80)

y_train_pred = lgbm.predict(X_train)
train_table = evaluate_model(y_train, y_train_pred)

y_test_pred = lgbm.predict(X_test)
test_table = evaluate_model(y_test, y_test_pred)

table1_str = train_table.get_string(title="LGBM Model - Training Metrics")
table2_str = test_table.get_string(title="LGBM Model - Testing Metrics")

lines1 = table1_str.split('\n')
lines2 = table2_str.split('\n')

max_lines = max(len(lines1), len(lines2))
lines1 += [""] * (max_lines - len(lines1))
lines2 += [""] * (max_lines - len(lines2))

for l1, l2 in zip(lines1, lines2):
    print(f"{l1:<45} {l2}")
print("=" * 80)

cv_scores = cross_val_score(lgbm, X_train, y_train, cv=5, scoring='accuracy')
print("LGBM Model - Cross-Validation Scores:")
print(f"CV Mean Accuracy: {cv_scores.mean():.3f}")
print(f"CV Standard Deviation: {cv_scores.std():.3f}")
print("=" * 80)
print()

clf_report = classification_report(y_test, y_test_pred)
print("Classification Report:")
print(clf_report)
# Out:
# [LightGBM] [Info] Number of positive: 3385, number of negative: 3385
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001196 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 813
# [LightGBM] [Info] Number of data points in the train set: 6770, number of used features: 19
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# Training time: 0.122 seconds
# ================================================================================
# +-------------------------------+             +------------------------------+
# | LGBM Model - Training Metrics |             | LGBM Model - Testing Metrics |
# +------------------+------------+             +------------------+-----------+
# |      Metric      |   Value    |             |      Metric      |   Value   |
# +------------------+------------+             +------------------+-----------+
# |     Accuracy     |   0.996    |             |     Accuracy     |   0.936   |
# |    Precision     |    1.0     |             |    Precision     |   0.091   |
# |      Recall      |   0.991    |             |      Recall      |   0.011   |
# |     F1 Score     |   0.996    |             |     F1 Score     |    0.02   |
# |       AUC        |   0.996    |             |       AUC        |   0.502   |
# +------------------+------------+             +------------------+-----------+
# ================================================================================
# [LightGBM] [Info] Number of positive: 2708, number of negative: 2708
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000335 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 813
# [LightGBM] [Info] Number of data points in the train set: 5416, number of used features: 19
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] Number of positive: 2708, number of negative: 2708
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000757 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 813
# [LightGBM] [Info] Number of data points in the train set: 5416, number of used features: 19
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] Number of positive: 2708, number of negative: 2708
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000697 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 813
# [LightGBM] [Info] Number of data points in the train set: 5416, number of used features: 19
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] Number of positive: 2708, number of negative: 2708
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000665 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 813
# [LightGBM] [Info] Number of data points in the train set: 5416, number of used features: 19
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] Number of positive: 2708, number of negative: 2708
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000349 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 813
# [LightGBM] [Info] Number of data points in the train set: 5416, number of used features: 19
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# LGBM Model - Cross-Validation Scores:
# CV Mean Accuracy: 0.971
# CV Standard Deviation: 0.038
# ================================================================================
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.97      1444
#            1       0.09      0.01      0.02        89
#
#     accuracy                           0.94      1533
#    macro avg       0.52      0.50      0.49      1533
# weighted avg       0.89      0.94      0.91      1533

# %%
disp = ConfusionMatrixDisplay(confusion_matrix(y_test, lgbm.predict(X_test)), display_labels=[0, 1])
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.show()

# %%
y_prob = lgbm.predict_proba(X_test)

roc_auc = roc_auc_score(y_test, y_prob[:, 1])

fpr = {}
tpr = {}
thresholds = {}

for i in range(len(lgbm.classes_)):
	fpr[i], tpr[i], thresholds[i] = roc_curve(y_test, y_prob[:, i], pos_label=i)

plt.figure()
for i in range(len(lgbm.classes_)):
	plt.plot(fpr[i], tpr[i], lw=2, label=f'Class {i} (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc='lower right')
plt.show()

print(f"AUC: {roc_auc:.2f}")
# Out:
# AUC: 0.80

# %%
lgbm_param_grid = {
    'num_leaves': [31, 50, 70],
    'max_depth': [-1, 10, 20],
    'learning_rate': [0.01, 0.05, 0.1],
    'n_estimators': [100, 200],
    'min_child_samples': [20, 30] 
}

lgbm_grid_search = GridSearchCV(lgbm, lgbm_param_grid, cv=5, scoring='accuracy', n_jobs=-1)
lgbm_grid_search.fit(X_train, y_train)
print("Best Hyperparameters for LGBM:")
table_hyperparams = PrettyTable()
table_hyperparams.field_names = ["Parameter", "Value"]
for param, value in lgbm_grid_search.best_params_.items():
    table_hyperparams.add_row([param, value])
print(table_hyperparams)
print("Best Accuracy for LGBM: {:.4f}".format(lgbm_grid_search.best_score_))
# Out:
# [LightGBM] [Info] Number of positive: 3385, number of negative: 3385
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000673 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 813
# [LightGBM] [Info] Number of data points in the train set: 6770, number of used features: 19
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# Best Hyperparameters for LGBM:
# +-------------------+-------+
# |     Parameter     | Value |
# +-------------------+-------+
# |   learning_rate   |  0.05 |
# |     max_depth     |   10  |
# | min_child_samples |   20  |
# |    n_estimators   |  200  |
# |     num_leaves    |   31  |
# +-------------------+-------+
# Best Accuracy for LGBM: 0.9719

# %%
best_lgbm_model = LGBMClassifier(**lgbm_grid_search.best_params_)
best_lgbm_model.fit(X_train, y_train)
y_test_pred = best_lgbm_model.predict(X_test)
test_accuracy = accuracy_score(y_test, y_test_pred)
test_precision = precision_score(y_test, y_test_pred)
test_recall = recall_score(y_test, y_test_pred)
test_f1 = f1_score(y_test, y_test_pred)
test_auc = roc_auc_score(y_test, y_test_pred)
print("Best LGBM Model - Testing Metrics:")

table_testing = PrettyTable()
table_testing.field_names = ["Metric", "Value"]
table_testing.add_row(["Accuracy", round(test_accuracy, 3)])
table_testing.add_row(["Precision", round(test_precision, 3)])
table_testing.add_row(["Recall", round(test_recall, 3)])
table_testing.add_row(["F1 Score", round(test_f1, 3)])
table_testing.add_row(["AUC", round(test_auc, 3)])
print(table_testing)
# Out:
# [LightGBM] [Info] Number of positive: 3385, number of negative: 3385
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000634 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 813
# [LightGBM] [Info] Number of data points in the train set: 6770, number of used features: 19
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# Best LGBM Model - Testing Metrics:
# +-----------+-------+
# |   Metric  | Value |
# +-----------+-------+
# |  Accuracy | 0.933 |
# | Precision | 0.118 |
# |   Recall  | 0.022 |
# |  F1 Score | 0.038 |
# |    AUC    | 0.506 |
# +-----------+-------+

# %%
cv_scores = cross_val_score(best_lgbm_model, X_train, y_train, cv=5, scoring='accuracy')
print("Best LGBM Model - Cross-Validation Scores:")
print("CV Mean Accuracy: {:.4f}".format(round(cv_scores.mean(), 3)))
print("CV Standard Deviation: {:.4f}".format(round(cv_scores.std(), 3)))
# Out:
# [LightGBM] [Info] Number of positive: 2708, number of negative: 2708
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000704 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 813
# [LightGBM] [Info] Number of data points in the train set: 5416, number of used features: 19
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] Number of positive: 2708, number of negative: 2708
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000452 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 813
# [LightGBM] [Info] Number of data points in the train set: 5416, number of used features: 19
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] Number of positive: 2708, number of negative: 2708
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000817 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 813
# [LightGBM] [Info] Number of data points in the train set: 5416, number of used features: 19
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] Number of positive: 2708, number of negative: 2708
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000805 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 813
# [LightGBM] [Info] Number of data points in the train set: 5416, number of used features: 19
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] Number of positive: 2708, number of negative: 2708
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000484 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 813
# [LightGBM] [Info] Number of data points in the train set: 5416, number of used features: 19
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# Best LGBM Model - Cross-Validation Scores:
# CV Mean Accuracy: 0.9720
# CV Standard Deviation: 0.0380

# %%
disp = ConfusionMatrixDisplay(confusion_matrix(y_test, y_test_pred), display_labels=[0, 1])
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# #### XGBClassifier

# %%
xgb = XGBClassifier()

start_time = time.time()
xgb.fit(X_train, y_train)
training_time = time.time() - start_time
print(f"Training time: {training_time:.3f} seconds")
print("=" * 80)

y_train_pred = xgb.predict(X_train)
train_table = evaluate_model(y_train, y_train_pred)

y_test_pred = xgb.predict(X_test)
test_table = evaluate_model(y_test, y_test_pred)

table1_str = train_table.get_string(title="XGBClassifier Model - Training Metrics")
table2_str = test_table.get_string(title="XGBClassifier Model - Testing Metrics")

lines1 = table1_str.split('\n')
lines2 = table2_str.split('\n')

max_lines = max(len(lines1), len(lines2))
lines1 += [""] * (max_lines - len(lines1))
lines2 += [""] * (max_lines - len(lines2))

for l1, l2 in zip(lines1, lines2):
    print(f"{l1:<45} {l2}")
print("=" * 80)

cv_scores = cross_val_score(xgb, X_train, y_train, cv=5, scoring='accuracy')
print("XGBClassifier Model - Cross-Validation Scores:")
print(f"CV Mean Accuracy: {cv_scores.mean():.3f}")
print(f"CV Standard Deviation: {cv_scores.std():.3f}")
print("=" * 80)
print()

clf_report = classification_report(y_test, y_test_pred)
print("Classification Report:")
print(clf_report)
# Out:
# Training time: 0.554 seconds
# ================================================================================
# +----------------------------------------+    +---------------------------------------+
# | XGBClassifier Model - Training Metrics |    | XGBClassifier Model - Testing Metrics |
# +------------------------+---------------+    +-----------------------+---------------+
# |         Metric         |     Value     |    |         Metric        |     Value     |
# +------------------------+---------------+    +-----------------------+---------------+
# |        Accuracy        |      1.0      |    |        Accuracy       |     0.933     |
# |       Precision        |      1.0      |    |       Precision       |      0.15     |
# |         Recall         |      1.0      |    |         Recall        |     0.034     |
# |        F1 Score        |      1.0      |    |        F1 Score       |     0.055     |
# |          AUC           |      1.0      |    |          AUC          |     0.511     |
# +------------------------+---------------+    +-----------------------+---------------+
# ================================================================================
# XGBClassifier Model - Cross-Validation Scores:
# CV Mean Accuracy: 0.970
# CV Standard Deviation: 0.038
# ================================================================================
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.97      1444
#            1       0.15      0.03      0.06        89
#
#     accuracy                           0.93      1533
#    macro avg       0.55      0.51      0.51      1533
# weighted avg       0.90      0.93      0.91      1533

# %%
disp = ConfusionMatrixDisplay(confusion_matrix(y_test, xgb.predict(X_test)), display_labels=[0, 1])
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.show()

# %%
y_prob = xgb.predict_proba(X_test)

roc_auc = roc_auc_score(y_test, y_prob[:, 1])

fpr = {}
tpr = {}
thresholds = {}

for i in range(len(xgb.classes_)):
	fpr[i], tpr[i], thresholds[i] = roc_curve(y_test, y_prob[:, i], pos_label=i)

plt.figure()
for i in range(len(xgb.classes_)):
	plt.plot(fpr[i], tpr[i], lw=2, label=f'Class {i} (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc='lower right')
plt.show()

print(f"AUC: {roc_auc:.2f}")
# Out:
# AUC: 0.77

# %%
xgb_param_grid = {
    'learning_rate': [0.01, 0.1, 0.2],  
    'max_depth': [3, 5, 7],           
    'n_estimators': [100, 200, 300], 
    'subsample': [0.8, 1.0],          
    'colsample_bytree': [0.8, 1.0],    
    'gamma': [0, 0.1, 1],             
    'min_child_weight': [1, 5]           
}

xgb_grid_search = GridSearchCV(xgb, xgb_param_grid, cv=5, scoring='accuracy', n_jobs=-1)
xgb_grid_search.fit(X_train, y_train)
print("Best Hyperparameters for XGBClassifier:")
table_hyperparams = PrettyTable()
table_hyperparams.field_names = ["Parameter", "Value"]
for param, value in xgb_grid_search.best_params_.items():
    table_hyperparams.add_row([param, value])
print(table_hyperparams)
print("Best Accuracy for XGBClassifier: {:.4f}".format(xgb_grid_search.best_score_))
# Out:
# Best Hyperparameters for XGBClassifier:
# +------------------+-------+
# |    Parameter     | Value |
# +------------------+-------+
# | colsample_bytree |  0.8  |
# |      gamma       |   0   |
# |  learning_rate   |  0.1  |
# |    max_depth     |   7   |
# | min_child_weight |   1   |
# |   n_estimators   |  100  |
# |    subsample     |  1.0  |
# +------------------+-------+
# Best Accuracy for XGBClassifier: 0.9733

# %%
best_xgb_model = XGBClassifier(**xgb_grid_search.best_params_)
best_xgb_model.fit(X_train, y_train)
y_test_pred = best_xgb_model.predict(X_test)
test_accuracy = accuracy_score(y_test, y_test_pred)
test_precision = precision_score(y_test, y_test_pred)
test_recall = recall_score(y_test, y_test_pred)
test_f1 = f1_score(y_test, y_test_pred)
test_auc = roc_auc_score(y_test, y_test_pred)
print("Best XGBClassifier Model - Testing Metrics:")

table_testing = PrettyTable()
table_testing.field_names = ["Metric", "Value"]
table_testing.add_row(["Accuracy", round(test_accuracy, 3)])
table_testing.add_row(["Precision", round(test_precision, 3)])
table_testing.add_row(["Recall", round(test_recall, 3)])
table_testing.add_row(["F1 Score", round(test_f1, 3)])
table_testing.add_row(["AUC", round(test_auc, 3)])
print(table_testing)
# Out:
# Best XGBClassifier Model - Testing Metrics:
# +-----------+-------+
# |   Metric  | Value |
# +-----------+-------+
# |  Accuracy | 0.934 |
# | Precision |  0.25 |
# |   Recall  | 0.067 |
# |  F1 Score | 0.106 |
# |    AUC    | 0.527 |
# +-----------+-------+

# %%
cv_scores = cross_val_score(best_xgb_model, X_train, y_train, cv=5, scoring='accuracy')
print("Best XGBClassifier Model - Cross-Validation Scores:")
print("CV Mean Accuracy: {:.4f}".format(round(cv_scores.mean(), 3)))
print("CV Standard Deviation: {:.4f}".format(round(cv_scores.std(), 3)))
# Out:
# Best XGBClassifier Model - Cross-Validation Scores:
# CV Mean Accuracy: 0.9730
# CV Standard Deviation: 0.0400

# %%
disp = ConfusionMatrixDisplay(confusion_matrix(y_test, y_test_pred), display_labels=[0, 1])
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# #### GradientBoostingClassifier

# %%
gradient = GradientBoostingClassifier()

start_time = time.time()
gradient.fit(X_train, y_train)
training_time = time.time() - start_time
print(f"Training time: {training_time:.3f} seconds")
print("=" * 80)

y_train_pred = gradient.predict(X_train)
train_table = evaluate_model(y_train, y_train_pred)

y_test_pred = gradient.predict(X_test)
test_table = evaluate_model(y_test, y_test_pred)

table1_str = train_table.get_string(title="GradientBoosting Model - Training Metrics")
table2_str = test_table.get_string(title="GradientBoosting Model - Testing Metrics")

lines1 = table1_str.split('\n')
lines2 = table2_str.split('\n')

max_lines = max(len(lines1), len(lines2))
lines1 += [""] * (max_lines - len(lines1))
lines2 += [""] * (max_lines - len(lines2))

for l1, l2 in zip(lines1, lines2):
    print(f"{l1:<45} {l2}")
print("=" * 80)

cv_scores = cross_val_score(gradient, X_train, y_train, cv=5, scoring='accuracy')
print("GradientBoosting Model - Cross-Validation Scores:")
print(f"CV Mean Accuracy: {cv_scores.mean():.3f}")
print(f"CV Standard Deviation: {cv_scores.std():.3f}")
print("=" * 80)
print()

clf_report = classification_report(y_test, y_test_pred)
print("Classification Report:")
print(clf_report)
# Out:
# Training time: 0.951 seconds
# ================================================================================
# +-------------------------------------------+ +------------------------------------------+
# | GradientBoosting Model - Training Metrics | | GradientBoosting Model - Testing Metrics |
# +--------------------------+----------------+ +-------------------------+----------------+
# |          Metric          |     Value      | |          Metric         |     Value      |
# +--------------------------+----------------+ +-------------------------+----------------+
# |         Accuracy         |     0.969      | |         Accuracy        |     0.936      |
# |        Precision         |     0.995      | |        Precision        |     0.235      |
# |          Recall          |     0.944      | |          Recall         |     0.045      |
# |         F1 Score         |     0.968      | |         F1 Score        |     0.075      |
# |           AUC            |     0.969      | |           AUC           |     0.518      |
# +--------------------------+----------------+ +-------------------------+----------------+
# ================================================================================
# GradientBoosting Model - Cross-Validation Scores:
# CV Mean Accuracy: 0.961
# CV Standard Deviation: 0.040
# ================================================================================
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.97      1444
#            1       0.24      0.04      0.08        89
#
#     accuracy                           0.94      1533
#    macro avg       0.59      0.52      0.52      1533
# weighted avg       0.90      0.94      0.92      1533

# %%
disp = ConfusionMatrixDisplay(confusion_matrix(y_test, gradient.predict(X_test)), display_labels=[0, 1])
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.show()

# %%
y_prob = gradient.predict_proba(X_test)

roc_auc = roc_auc_score(y_test, y_prob[:, 1])

fpr = {}
tpr = {}
thresholds = {}

for i in range(len(gradient.classes_)):
	fpr[i], tpr[i], thresholds[i] = roc_curve(y_test, y_prob[:, i], pos_label=i)

plt.figure()
for i in range(len(gradient.classes_)):
	plt.plot(fpr[i], tpr[i], lw=2, label=f'Class {i} (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc='lower right')
plt.show()

print(f"AUC: {roc_auc:.2f}")
# Out:
# AUC: 0.80

# %%
gradient_param_grid = {
    'n_estimators': [100, 200, 300],        
    'learning_rate': [0.01, 0.1, 0.2],     
    'max_depth': [3, 4, 5],              
    'min_samples_split': [2, 3, 4],       
    'min_samples_leaf': [1, 2, 3]
}

gradient_grid_search = GridSearchCV(gradient, gradient_param_grid, cv=5, scoring='accuracy', n_jobs=-1)
gradient_grid_search.fit(X_train, y_train)
print("Best Hyperparameters for GradientBoosting:")
table_hyperparams = PrettyTable()
table_hyperparams.field_names = ["Parameter", "Value"]
for param, value in gradient_grid_search.best_params_.items():
    table_hyperparams.add_row([param, value])
print(table_hyperparams)
print("Best Accuracy for GradientBoosting: {:.4f}".format(gradient_grid_search.best_score_))
# Out:
# Best Hyperparameters for GradientBoosting:
# +-------------------+-------+
# |     Parameter     | Value |
# +-------------------+-------+
# |   learning_rate   |  0.1  |
# |     max_depth     |   5   |
# |  min_samples_leaf |   1   |
# | min_samples_split |   3   |
# |    n_estimators   |  200  |
# +-------------------+-------+
# Best Accuracy for GradientBoosting: 0.9710

# %%
best_gradient_model = GradientBoostingClassifier(**gradient_grid_search.best_params_)
best_gradient_model.fit(X_train, y_train)
y_test_pred = best_gradient_model.predict(X_test)
test_accuracy = accuracy_score(y_test, y_test_pred)
test_precision = precision_score(y_test, y_test_pred)
test_recall = recall_score(y_test, y_test_pred)
test_f1 = f1_score(y_test, y_test_pred)
test_auc = roc_auc_score(y_test, y_test_pred)
print("Best GradientBoosting Model - Testing Metrics:")

table_testing = PrettyTable()
table_testing.field_names = ["Metric", "Value"]
table_testing.add_row(["Accuracy", round(test_accuracy, 3)])
table_testing.add_row(["Precision", round(test_precision, 3)])
table_testing.add_row(["Recall", round(test_recall, 3)])
table_testing.add_row(["F1 Score", round(test_f1, 3)])
table_testing.add_row(["AUC", round(test_auc, 3)])
print(table_testing)
# Out:
# Best GradientBoosting Model - Testing Metrics:
# +-----------+-------+
# |   Metric  | Value |
# +-----------+-------+
# |  Accuracy | 0.937 |
# | Precision | 0.278 |
# |   Recall  | 0.056 |
# |  F1 Score | 0.093 |
# |    AUC    | 0.524 |
# +-----------+-------+

# %%
cv_scores = cross_val_score(best_gradient_model, X_train, y_train, cv=5, scoring='accuracy')
print("Best GradientBoosting Model - Cross-Validation Scores:")
print("CV Mean Accuracy: {:.4f}".format(round(cv_scores.mean(), 3)))
print("CV Standard Deviation: {:.4f}".format(round(cv_scores.std(), 3)))
# Out:
# Best GradientBoosting Model - Cross-Validation Scores:
# CV Mean Accuracy: 0.9710
# CV Standard Deviation: 0.0380

# %%
disp = ConfusionMatrixDisplay(confusion_matrix(y_test, y_test_pred), display_labels=[0, 1])
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# #### CatBoostClassifier

# %%
cat = CatBoostClassifier()

start_time = time.time()
cat.fit(X_train, y_train)
training_time = time.time() - start_time
print(f"Training time: {training_time:.3f} seconds")
print("=" * 80)

y_train_pred = cat.predict(X_train)
train_table = evaluate_model(y_train, y_train_pred)

y_test_pred = cat.predict(X_test)
test_table = evaluate_model(y_test, y_test_pred)

table1_str = train_table.get_string(title="CatBoost Model - Training Metrics")
table2_str = test_table.get_string(title="CatBoost Model - Testing Metrics")

lines1 = table1_str.split('\n')
lines2 = table2_str.split('\n')

max_lines = max(len(lines1), len(lines2))
lines1 += [""] * (max_lines - len(lines1))
lines2 += [""] * (max_lines - len(lines2))

for l1, l2 in zip(lines1, lines2):
    print(f"{l1:<45} {l2}")
print("=" * 80)

cv_scores = cross_val_score(cat, X_train, y_train, cv=5, scoring='accuracy')
print("CatBoost Model - Cross-Validation Scores:")
print(f"CV Mean Accuracy: {cv_scores.mean():.3f}")
print(f"CV Standard Deviation: {cv_scores.std():.3f}")
print("=" * 80)
print()

clf_report = classification_report(y_test, y_test_pred)
print("Classification Report:")
print(clf_report)
# Out:
# Learning rate set to 0.023313
# 0:	learn: 0.6586237	total: 159ms	remaining: 2m 38s
# 1:	learn: 0.6281450	total: 179ms	remaining: 1m 29s
# 2:	learn: 0.5913113	total: 191ms	remaining: 1m 3s
# 3:	learn: 0.5568672	total: 201ms	remaining: 50s
# 4:	learn: 0.5330850	total: 208ms	remaining: 41.3s
# 5:	learn: 0.5048338	total: 215ms	remaining: 35.6s
# 6:	learn: 0.4795497	total: 219ms	remaining: 31s
# 7:	learn: 0.4634142	total: 228ms	remaining: 28.3s
# 8:	learn: 0.4449630	total: 231ms	remaining: 25.5s
# 9:	learn: 0.4355034	total: 234ms	remaining: 23.2s
# 10:	learn: 0.4179195	total: 240ms	remaining: 21.5s
# 11:	learn: 0.3987712	total: 245ms	remaining: 20.2s
# 12:	learn: 0.3815563	total: 248ms	remaining: 18.8s
# 13:	learn: 0.3710957	total: 251ms	remaining: 17.7s
# 14:	learn: 0.3590155	total: 253ms	remaining: 16.6s
# 15:	learn: 0.3526104	total: 256ms	remaining: 15.7s
# 16:	learn: 0.3429925	total: 259ms	remaining: 15s
# 17:	learn: 0.3336258	total: 261ms	remaining: 14.2s
# 18:	learn: 0.3249202	total: 264ms	remaining: 13.6s
# 19:	learn: 0.3161891	total: 266ms	remaining: 13s
# 20:	learn: 0.3086693	total: 269ms	remaining: 12.5s
# 21:	learn: 0.3045500	total: 274ms	remaining: 12.2s
# 22:	learn: 0.2971589	total: 277ms	remaining: 11.7s
# 23:	learn: 0.2927323	total: 282ms	remaining: 11.5s
# 24:	learn: 0.2873667	total: 286ms	remaining: 11.1s
# 25:	learn: 0.2796107	total: 291ms	remaining: 10.9s
# 26:	learn: 0.2736823	total: 294ms	remaining: 10.6s
# 27:	learn: 0.2687524	total: 298ms	remaining: 10.4s
# 28:	learn: 0.2622587	total: 303ms	remaining: 10.1s
# 29:	learn: 0.2572817	total: 306ms	remaining: 9.91s
# 30:	learn: 0.2487267	total: 312ms	remaining: 9.74s
# 31:	learn: 0.2449834	total: 315ms	remaining: 9.53s
# 32:	learn: 0.2405226	total: 319ms	remaining: 9.34s
# 33:	learn: 0.2334879	total: 322ms	remaining: 9.15s
# 34:	learn: 0.2296331	total: 326ms	remaining: 8.97s
# 35:	learn: 0.2274445	total: 331ms	remaining: 8.85s
# 36:	learn: 0.2243752	total: 336ms	remaining: 8.74s
# 37:	learn: 0.2212857	total: 340ms	remaining: 8.6s
# 38:	learn: 0.2176362	total: 343ms	remaining: 8.45s
# 39:	learn: 0.2129506	total: 350ms	remaining: 8.39s
# 40:	learn: 0.2081734	total: 353ms	remaining: 8.26s
# 41:	learn: 0.2049922	total: 361ms	remaining: 8.23s
# 42:	learn: 0.2015120	total: 364ms	remaining: 8.11s
# 43:	learn: 0.1983097	total: 368ms	remaining: 7.99s
# 44:	learn: 0.1963104	total: 374ms	remaining: 7.95s
# 45:	learn: 0.1924629	total: 378ms	remaining: 7.84s
# 46:	learn: 0.1890461	total: 381ms	remaining: 7.73s
# 47:	learn: 0.1859839	total: 386ms	remaining: 7.65s
# 48:	learn: 0.1833878	total: 393ms	remaining: 7.62s
# 49:	learn: 0.1823182	total: 395ms	remaining: 7.51s
# 50:	learn: 0.1800892	total: 399ms	remaining: 7.43s
# 51:	learn: 0.1774791	total: 405ms	remaining: 7.38s
# 52:	learn: 0.1756499	total: 410ms	remaining: 7.33s
# 53:	learn: 0.1743691	total: 418ms	remaining: 7.33s
# 54:	learn: 0.1714168	total: 422ms	remaining: 7.24s
# 55:	learn: 0.1702564	total: 428ms	remaining: 7.21s
# 56:	learn: 0.1679888	total: 432ms	remaining: 7.15s
# 57:	learn: 0.1655050	total: 436ms	remaining: 7.08s
# 58:	learn: 0.1632884	total: 439ms	remaining: 7s
# 59:	learn: 0.1611749	total: 442ms	remaining: 6.93s
# 60:	learn: 0.1592117	total: 446ms	remaining: 6.86s
# 61:	learn: 0.1577149	total: 449ms	remaining: 6.79s
# 62:	learn: 0.1561957	total: 453ms	remaining: 6.74s
# 63:	learn: 0.1547112	total: 456ms	remaining: 6.67s
# 64:	learn: 0.1536171	total: 460ms	remaining: 6.61s
# 65:	learn: 0.1520891	total: 463ms	remaining: 6.56s
# 66:	learn: 0.1512815	total: 467ms	remaining: 6.5s
# 67:	learn: 0.1490069	total: 470ms	remaining: 6.44s
# 68:	learn: 0.1482167	total: 474ms	remaining: 6.39s
# 69:	learn: 0.1468349	total: 477ms	remaining: 6.33s
# 70:	learn: 0.1460628	total: 480ms	remaining: 6.28s
# 71:	learn: 0.1454151	total: 484ms	remaining: 6.23s
# 72:	learn: 0.1443876	total: 487ms	remaining: 6.18s
# 73:	learn: 0.1437210	total: 490ms	remaining: 6.13s
# 74:	learn: 0.1427499	total: 493ms	remaining: 6.08s
# 75:	learn: 0.1422892	total: 496ms	remaining: 6.03s
# 76:	learn: 0.1417348	total: 499ms	remaining: 5.98s
# 77:	learn: 0.1410845	total: 502ms	remaining: 5.94s
# 78:	learn: 0.1403628	total: 506ms	remaining: 5.89s
# 79:	learn: 0.1392151	total: 509ms	remaining: 5.85s
# 80:	learn: 0.1381205	total: 512ms	remaining: 5.81s
# 81:	learn: 0.1375068	total: 515ms	remaining: 5.77s
# 82:	learn: 0.1362158	total: 519ms	remaining: 5.73s
# 83:	learn: 0.1357754	total: 522ms	remaining: 5.69s
# 84:	learn: 0.1349533	total: 525ms	remaining: 5.65s
# 85:	learn: 0.1342629	total: 528ms	remaining: 5.61s
# 86:	learn: 0.1336665	total: 531ms	remaining: 5.57s
# 87:	learn: 0.1331318	total: 534ms	remaining: 5.53s
# 88:	learn: 0.1325207	total: 537ms	remaining: 5.5s
# 89:	learn: 0.1319791	total: 540ms	remaining: 5.46s
# 90:	learn: 0.1314901	total: 544ms	remaining: 5.43s
# 91:	learn: 0.1310306	total: 547ms	remaining: 5.4s
# 92:	learn: 0.1299234	total: 551ms	remaining: 5.37s
# 93:	learn: 0.1296398	total: 554ms	remaining: 5.34s
# 94:	learn: 0.1292009	total: 557ms	remaining: 5.31s
# 95:	learn: 0.1288067	total: 561ms	remaining: 5.28s
# 96:	learn: 0.1284334	total: 564ms	remaining: 5.25s
# 97:	learn: 0.1278149	total: 567ms	remaining: 5.22s
# 98:	learn: 0.1270134	total: 571ms	remaining: 5.2s
# 99:	learn: 0.1266519	total: 574ms	remaining: 5.17s
# 100:	learn: 0.1262147	total: 577ms	remaining: 5.14s
# 101:	learn: 0.1257891	total: 580ms	remaining: 5.11s
# 102:	learn: 0.1249685	total: 584ms	remaining: 5.08s
# 103:	learn: 0.1246254	total: 587ms	remaining: 5.06s
# 104:	learn: 0.1241894	total: 590ms	remaining: 5.03s
# 105:	learn: 0.1235767	total: 594ms	remaining: 5.01s
# 106:	learn: 0.1231991	total: 597ms	remaining: 4.98s
# 107:	learn: 0.1229119	total: 601ms	remaining: 4.96s
# 108:	learn: 0.1220475	total: 604ms	remaining: 4.94s
# 109:	learn: 0.1217274	total: 608ms	remaining: 4.92s
# 110:	learn: 0.1211588	total: 611ms	remaining: 4.89s
# 111:	learn: 0.1208349	total: 615ms	remaining: 4.87s
# 112:	learn: 0.1204704	total: 619ms	remaining: 4.86s
# 113:	learn: 0.1202002	total: 623ms	remaining: 4.84s
# 114:	learn: 0.1199050	total: 626ms	remaining: 4.82s
# 115:	learn: 0.1195123	total: 630ms	remaining: 4.8s
# 116:	learn: 0.1190919	total: 634ms	remaining: 4.78s
# 117:	learn: 0.1187994	total: 637ms	remaining: 4.76s
# 118:	learn: 0.1181906	total: 641ms	remaining: 4.74s
# 119:	learn: 0.1178653	total: 644ms	remaining: 4.72s
# 120:	learn: 0.1176524	total: 648ms	remaining: 4.71s
# 121:	learn: 0.1174496	total: 651ms	remaining: 4.69s
# 122:	learn: 0.1170744	total: 655ms	remaining: 4.67s
# 123:	learn: 0.1168839	total: 658ms	remaining: 4.65s
# 124:	learn: 0.1166752	total: 662ms	remaining: 4.63s
# 125:	learn: 0.1161309	total: 665ms	remaining: 4.62s
# 126:	learn: 0.1155826	total: 669ms	remaining: 4.59s
# 127:	learn: 0.1153221	total: 672ms	remaining: 4.58s
# 128:	learn: 0.1151254	total: 675ms	remaining: 4.56s
# 129:	learn: 0.1147153	total: 678ms	remaining: 4.54s
# 130:	learn: 0.1143850	total: 681ms	remaining: 4.52s
# 131:	learn: 0.1137363	total: 684ms	remaining: 4.5s
# 132:	learn: 0.1134881	total: 688ms	remaining: 4.48s
# 133:	learn: 0.1129844	total: 691ms	remaining: 4.47s
# 134:	learn: 0.1124890	total: 694ms	remaining: 4.45s
# 135:	learn: 0.1122423	total: 699ms	remaining: 4.44s
# 136:	learn: 0.1120134	total: 702ms	remaining: 4.42s
# 137:	learn: 0.1118672	total: 705ms	remaining: 4.41s
# 138:	learn: 0.1117096	total: 709ms	remaining: 4.39s
# 139:	learn: 0.1114008	total: 712ms	remaining: 4.37s
# 140:	learn: 0.1110402	total: 715ms	remaining: 4.36s
# 141:	learn: 0.1108613	total: 718ms	remaining: 4.34s
# 142:	learn: 0.1104352	total: 722ms	remaining: 4.32s
# 143:	learn: 0.1101089	total: 725ms	remaining: 4.31s
# 144:	learn: 0.1097553	total: 729ms	remaining: 4.3s
# 145:	learn: 0.1095111	total: 732ms	remaining: 4.28s
# 146:	learn: 0.1092323	total: 735ms	remaining: 4.27s
# 147:	learn: 0.1087039	total: 739ms	remaining: 4.25s
# 148:	learn: 0.1083673	total: 742ms	remaining: 4.24s
# 149:	learn: 0.1082128	total: 746ms	remaining: 4.23s
# 150:	learn: 0.1077925	total: 749ms	remaining: 4.21s
# 151:	learn: 0.1074933	total: 753ms	remaining: 4.2s
# 152:	learn: 0.1072252	total: 756ms	remaining: 4.19s
# 153:	learn: 0.1070092	total: 759ms	remaining: 4.17s
# 154:	learn: 0.1065943	total: 762ms	remaining: 4.16s
# 155:	learn: 0.1063589	total: 766ms	remaining: 4.14s
# 156:	learn: 0.1061423	total: 769ms	remaining: 4.13s
# 157:	learn: 0.1057976	total: 773ms	remaining: 4.12s
# 158:	learn: 0.1052523	total: 776ms	remaining: 4.11s
# 159:	learn: 0.1049918	total: 780ms	remaining: 4.09s
# 160:	learn: 0.1047556	total: 783ms	remaining: 4.08s
# 161:	learn: 0.1044059	total: 787ms	remaining: 4.07s
# 162:	learn: 0.1040795	total: 791ms	remaining: 4.06s
# 163:	learn: 0.1038685	total: 794ms	remaining: 4.05s
# 164:	learn: 0.1035043	total: 798ms	remaining: 4.04s
# 165:	learn: 0.1031505	total: 802ms	remaining: 4.03s
# 166:	learn: 0.1029393	total: 805ms	remaining: 4.02s
# 167:	learn: 0.1025620	total: 809ms	remaining: 4.01s
# 168:	learn: 0.1022048	total: 813ms	remaining: 4s
# 169:	learn: 0.1020258	total: 816ms	remaining: 3.99s
# 170:	learn: 0.1017994	total: 820ms	remaining: 3.98s
# 171:	learn: 0.1014921	total: 824ms	remaining: 3.97s
# 172:	learn: 0.1013651	total: 828ms	remaining: 3.96s
# 173:	learn: 0.1011026	total: 831ms	remaining: 3.94s
# 174:	learn: 0.1008942	total: 835ms	remaining: 3.93s
# 175:	learn: 0.1005954	total: 838ms	remaining: 3.92s
# 176:	learn: 0.1004052	total: 842ms	remaining: 3.92s
# 177:	learn: 0.1000820	total: 846ms	remaining: 3.91s
# 178:	learn: 0.0999565	total: 849ms	remaining: 3.9s
# 179:	learn: 0.0998099	total: 853ms	remaining: 3.88s
# 180:	learn: 0.0996409	total: 856ms	remaining: 3.87s
# 181:	learn: 0.0994835	total: 860ms	remaining: 3.87s
# 182:	learn: 0.0991617	total: 863ms	remaining: 3.85s
# 183:	learn: 0.0988958	total: 867ms	remaining: 3.85s
# 184:	learn: 0.0986643	total: 870ms	remaining: 3.83s
# 185:	learn: 0.0984323	total: 874ms	remaining: 3.82s
# 186:	learn: 0.0982648	total: 878ms	remaining: 3.82s
# 187:	learn: 0.0978827	total: 882ms	remaining: 3.81s
# 188:	learn: 0.0977000	total: 885ms	remaining: 3.8s
# 189:	learn: 0.0975385	total: 889ms	remaining: 3.79s
# 190:	learn: 0.0972825	total: 893ms	remaining: 3.78s
# 191:	learn: 0.0969535	total: 897ms	remaining: 3.77s
# 192:	learn: 0.0966185	total: 900ms	remaining: 3.77s
# 193:	learn: 0.0963499	total: 904ms	remaining: 3.76s
# 194:	learn: 0.0960960	total: 908ms	remaining: 3.75s
# 195:	learn: 0.0959037	total: 912ms	remaining: 3.74s
# 196:	learn: 0.0955297	total: 916ms	remaining: 3.73s
# 197:	learn: 0.0952906	total: 919ms	remaining: 3.72s
# 198:	learn: 0.0951242	total: 923ms	remaining: 3.71s
# 199:	learn: 0.0946610	total: 926ms	remaining: 3.7s
# 200:	learn: 0.0943292	total: 930ms	remaining: 3.69s
# 201:	learn: 0.0941984	total: 933ms	remaining: 3.69s
# 202:	learn: 0.0939822	total: 937ms	remaining: 3.68s
# 203:	learn: 0.0937635	total: 940ms	remaining: 3.67s
# 204:	learn: 0.0935424	total: 944ms	remaining: 3.66s
# 205:	learn: 0.0933103	total: 947ms	remaining: 3.65s
# 206:	learn: 0.0930142	total: 951ms	remaining: 3.64s
# 207:	learn: 0.0928199	total: 955ms	remaining: 3.64s
# 208:	learn: 0.0926553	total: 959ms	remaining: 3.63s
# 209:	learn: 0.0924903	total: 962ms	remaining: 3.62s
# 210:	learn: 0.0923578	total: 966ms	remaining: 3.61s
# 211:	learn: 0.0920471	total: 970ms	remaining: 3.6s
# 212:	learn: 0.0918243	total: 974ms	remaining: 3.6s
# 213:	learn: 0.0916064	total: 978ms	remaining: 3.59s
# 214:	learn: 0.0913945	total: 981ms	remaining: 3.58s
# 215:	learn: 0.0911811	total: 984ms	remaining: 3.57s
# 216:	learn: 0.0910445	total: 988ms	remaining: 3.56s
# 217:	learn: 0.0908140	total: 991ms	remaining: 3.56s
# 218:	learn: 0.0905217	total: 995ms	remaining: 3.55s
# 219:	learn: 0.0903762	total: 998ms	remaining: 3.54s
# 220:	learn: 0.0901233	total: 1s	remaining: 3.53s
# 221:	learn: 0.0899801	total: 1s	remaining: 3.52s
# 222:	learn: 0.0897292	total: 1.01s	remaining: 3.51s
# 223:	learn: 0.0894126	total: 1.01s	remaining: 3.5s
# 224:	learn: 0.0892537	total: 1.01s	remaining: 3.5s
# 225:	learn: 0.0891187	total: 1.02s	remaining: 3.49s
# 226:	learn: 0.0889499	total: 1.02s	remaining: 3.48s
# 227:	learn: 0.0886785	total: 1.03s	remaining: 3.48s
# 228:	learn: 0.0884948	total: 1.03s	remaining: 3.47s
# 229:	learn: 0.0883608	total: 1.03s	remaining: 3.46s
# 230:	learn: 0.0881192	total: 1.04s	remaining: 3.46s
# 231:	learn: 0.0879385	total: 1.04s	remaining: 3.45s
# 232:	learn: 0.0876944	total: 1.05s	remaining: 3.44s
# 233:	learn: 0.0874813	total: 1.05s	remaining: 3.44s
# 234:	learn: 0.0873414	total: 1.05s	remaining: 3.43s
# 235:	learn: 0.0872145	total: 1.06s	remaining: 3.42s
# 236:	learn: 0.0870404	total: 1.06s	remaining: 3.42s
# 237:	learn: 0.0869337	total: 1.06s	remaining: 3.41s
# 238:	learn: 0.0867092	total: 1.07s	remaining: 3.4s
# 239:	learn: 0.0865468	total: 1.07s	remaining: 3.4s
# 240:	learn: 0.0863736	total: 1.08s	remaining: 3.39s
# 241:	learn: 0.0858396	total: 1.08s	remaining: 3.39s
# 242:	learn: 0.0856695	total: 1.08s	remaining: 3.38s
# 243:	learn: 0.0855286	total: 1.09s	remaining: 3.37s
# 244:	learn: 0.0853498	total: 1.09s	remaining: 3.37s
# 245:	learn: 0.0852239	total: 1.1s	remaining: 3.36s
# 246:	learn: 0.0850520	total: 1.1s	remaining: 3.35s
# 247:	learn: 0.0849554	total: 1.1s	remaining: 3.35s
# 248:	learn: 0.0848091	total: 1.11s	remaining: 3.34s
# 249:	learn: 0.0844176	total: 1.11s	remaining: 3.34s
# 250:	learn: 0.0842162	total: 1.11s	remaining: 3.33s
# 251:	learn: 0.0839749	total: 1.12s	remaining: 3.32s
# 252:	learn: 0.0838343	total: 1.12s	remaining: 3.32s
# 253:	learn: 0.0836930	total: 1.13s	remaining: 3.31s
# 254:	learn: 0.0836059	total: 1.13s	remaining: 3.3s
# 255:	learn: 0.0834543	total: 1.13s	remaining: 3.29s
# 256:	learn: 0.0832563	total: 1.14s	remaining: 3.29s
# 257:	learn: 0.0829088	total: 1.14s	remaining: 3.28s
# 258:	learn: 0.0825859	total: 1.14s	remaining: 3.27s
# 259:	learn: 0.0823505	total: 1.15s	remaining: 3.27s
# 260:	learn: 0.0822216	total: 1.15s	remaining: 3.26s
# 261:	learn: 0.0819905	total: 1.16s	remaining: 3.25s
# 262:	learn: 0.0817796	total: 1.16s	remaining: 3.25s
# 263:	learn: 0.0816332	total: 1.16s	remaining: 3.24s
# 264:	learn: 0.0815348	total: 1.17s	remaining: 3.23s
# 265:	learn: 0.0814184	total: 1.17s	remaining: 3.23s
# 266:	learn: 0.0812993	total: 1.17s	remaining: 3.22s
# 267:	learn: 0.0811264	total: 1.18s	remaining: 3.21s
# 268:	learn: 0.0809006	total: 1.18s	remaining: 3.21s
# 269:	learn: 0.0807791	total: 1.19s	remaining: 3.21s
# 270:	learn: 0.0805464	total: 1.19s	remaining: 3.2s
# 271:	learn: 0.0804002	total: 1.19s	remaining: 3.19s
# 272:	learn: 0.0801806	total: 1.2s	remaining: 3.18s
# 273:	learn: 0.0800193	total: 1.2s	remaining: 3.18s
# 274:	learn: 0.0797837	total: 1.2s	remaining: 3.17s
# 275:	learn: 0.0796287	total: 1.21s	remaining: 3.17s
# 276:	learn: 0.0794865	total: 1.21s	remaining: 3.16s
# 277:	learn: 0.0793673	total: 1.21s	remaining: 3.15s
# 278:	learn: 0.0791934	total: 1.22s	remaining: 3.15s
# 279:	learn: 0.0790416	total: 1.22s	remaining: 3.14s
# 280:	learn: 0.0789022	total: 1.23s	remaining: 3.13s
# 281:	learn: 0.0787721	total: 1.23s	remaining: 3.14s
# 282:	learn: 0.0786868	total: 1.24s	remaining: 3.13s
# 283:	learn: 0.0785217	total: 1.24s	remaining: 3.13s
# 284:	learn: 0.0783064	total: 1.25s	remaining: 3.13s
# 285:	learn: 0.0781688	total: 1.25s	remaining: 3.13s
# 286:	learn: 0.0779960	total: 1.26s	remaining: 3.13s
# 287:	learn: 0.0778892	total: 1.26s	remaining: 3.12s
# 288:	learn: 0.0777497	total: 1.26s	remaining: 3.11s
# 289:	learn: 0.0776063	total: 1.27s	remaining: 3.11s
# 290:	learn: 0.0775403	total: 1.27s	remaining: 3.1s
# 291:	learn: 0.0774210	total: 1.28s	remaining: 3.1s
# 292:	learn: 0.0772086	total: 1.28s	remaining: 3.1s
# 293:	learn: 0.0769937	total: 1.29s	remaining: 3.09s
# 294:	learn: 0.0768721	total: 1.29s	remaining: 3.1s
# 295:	learn: 0.0767267	total: 1.3s	remaining: 3.09s
# 296:	learn: 0.0766220	total: 1.3s	remaining: 3.08s
# 297:	learn: 0.0764782	total: 1.3s	remaining: 3.08s
# 298:	learn: 0.0763525	total: 1.31s	remaining: 3.07s
# 299:	learn: 0.0762569	total: 1.32s	remaining: 3.08s
# 300:	learn: 0.0761047	total: 1.32s	remaining: 3.07s
# 301:	learn: 0.0759728	total: 1.33s	remaining: 3.07s
# 302:	learn: 0.0756714	total: 1.33s	remaining: 3.07s
# 303:	learn: 0.0755168	total: 1.34s	remaining: 3.06s
# 304:	learn: 0.0753023	total: 1.34s	remaining: 3.05s
# 305:	learn: 0.0750656	total: 1.34s	remaining: 3.05s
# 306:	learn: 0.0749226	total: 1.35s	remaining: 3.04s
# 307:	learn: 0.0747563	total: 1.35s	remaining: 3.04s
# 308:	learn: 0.0745959	total: 1.36s	remaining: 3.04s
# 309:	learn: 0.0743416	total: 1.37s	remaining: 3.04s
# 310:	learn: 0.0742086	total: 1.37s	remaining: 3.04s
# 311:	learn: 0.0740014	total: 1.37s	remaining: 3.03s
# 312:	learn: 0.0737971	total: 1.38s	remaining: 3.02s
# 313:	learn: 0.0737141	total: 1.38s	remaining: 3.02s
# 314:	learn: 0.0735578	total: 1.38s	remaining: 3.01s
# 315:	learn: 0.0734878	total: 1.39s	remaining: 3s
# 316:	learn: 0.0733693	total: 1.39s	remaining: 3s
# 317:	learn: 0.0732556	total: 1.39s	remaining: 2.99s
# 318:	learn: 0.0731294	total: 1.4s	remaining: 2.98s
# 319:	learn: 0.0730606	total: 1.4s	remaining: 2.98s
# 320:	learn: 0.0729354	total: 1.4s	remaining: 2.97s
# 321:	learn: 0.0728119	total: 1.41s	remaining: 2.97s
# 322:	learn: 0.0727450	total: 1.42s	remaining: 2.96s
# 323:	learn: 0.0726828	total: 1.42s	remaining: 2.97s
# 324:	learn: 0.0725584	total: 1.43s	remaining: 2.96s
# 325:	learn: 0.0724359	total: 1.43s	remaining: 2.96s
# 326:	learn: 0.0723130	total: 1.44s	remaining: 2.96s
# 327:	learn: 0.0721327	total: 1.44s	remaining: 2.95s
# 328:	learn: 0.0720581	total: 1.45s	remaining: 2.95s
# 329:	learn: 0.0718817	total: 1.45s	remaining: 2.95s
# 330:	learn: 0.0717702	total: 1.46s	remaining: 2.94s
# 331:	learn: 0.0716150	total: 1.46s	remaining: 2.94s
# 332:	learn: 0.0714595	total: 1.46s	remaining: 2.93s
# 333:	learn: 0.0713480	total: 1.47s	remaining: 2.93s
# 334:	learn: 0.0712156	total: 1.47s	remaining: 2.93s
# 335:	learn: 0.0710529	total: 1.48s	remaining: 2.92s
# 336:	learn: 0.0709031	total: 1.48s	remaining: 2.92s
# 337:	learn: 0.0707852	total: 1.49s	remaining: 2.91s
# 338:	learn: 0.0706717	total: 1.49s	remaining: 2.91s
# 339:	learn: 0.0705280	total: 1.5s	remaining: 2.9s
# 340:	learn: 0.0703842	total: 1.5s	remaining: 2.9s
# 341:	learn: 0.0702577	total: 1.51s	remaining: 2.9s
# 342:	learn: 0.0702022	total: 1.51s	remaining: 2.89s
# 343:	learn: 0.0701430	total: 1.52s	remaining: 2.9s
# 344:	learn: 0.0700513	total: 1.52s	remaining: 2.89s
# 345:	learn: 0.0698971	total: 1.53s	remaining: 2.89s
# 346:	learn: 0.0698000	total: 1.53s	remaining: 2.89s
# 347:	learn: 0.0697384	total: 1.54s	remaining: 2.89s
# 348:	learn: 0.0695984	total: 1.54s	remaining: 2.88s
# 349:	learn: 0.0694678	total: 1.55s	remaining: 2.88s
# 350:	learn: 0.0693834	total: 1.55s	remaining: 2.87s
# 351:	learn: 0.0692490	total: 1.56s	remaining: 2.87s
# 352:	learn: 0.0691619	total: 1.56s	remaining: 2.87s
# 353:	learn: 0.0690209	total: 1.57s	remaining: 2.86s
# 354:	learn: 0.0688645	total: 1.57s	remaining: 2.85s
# 355:	learn: 0.0687700	total: 1.57s	remaining: 2.85s
# 356:	learn: 0.0687189	total: 1.58s	remaining: 2.84s
# 357:	learn: 0.0686162	total: 1.58s	remaining: 2.84s
# 358:	learn: 0.0685212	total: 1.58s	remaining: 2.83s
# 359:	learn: 0.0684005	total: 1.59s	remaining: 2.82s
# 360:	learn: 0.0682701	total: 1.59s	remaining: 2.82s
# 361:	learn: 0.0681904	total: 1.6s	remaining: 2.81s
# 362:	learn: 0.0680654	total: 1.6s	remaining: 2.81s
# 363:	learn: 0.0679503	total: 1.6s	remaining: 2.8s
# 364:	learn: 0.0678239	total: 1.61s	remaining: 2.79s
# 365:	learn: 0.0677574	total: 1.61s	remaining: 2.79s
# 366:	learn: 0.0675956	total: 1.61s	remaining: 2.78s
# 367:	learn: 0.0674473	total: 1.62s	remaining: 2.77s
# 368:	learn: 0.0673248	total: 1.62s	remaining: 2.77s
# 369:	learn: 0.0671396	total: 1.62s	remaining: 2.76s
# 370:	learn: 0.0670719	total: 1.63s	remaining: 2.76s
# 371:	learn: 0.0669268	total: 1.63s	remaining: 2.75s
# 372:	learn: 0.0667856	total: 1.63s	remaining: 2.74s
# 373:	learn: 0.0666231	total: 1.64s	remaining: 2.74s
# 374:	learn: 0.0664538	total: 1.64s	remaining: 2.73s
# 375:	learn: 0.0663615	total: 1.64s	remaining: 2.73s
# 376:	learn: 0.0662199	total: 1.65s	remaining: 2.72s
# 377:	learn: 0.0661384	total: 1.65s	remaining: 2.71s
# 378:	learn: 0.0660505	total: 1.65s	remaining: 2.71s
# 379:	learn: 0.0658514	total: 1.66s	remaining: 2.7s
# 380:	learn: 0.0656893	total: 1.66s	remaining: 2.69s
# 381:	learn: 0.0655923	total: 1.66s	remaining: 2.69s
# 382:	learn: 0.0655036	total: 1.67s	remaining: 2.68s
# 383:	learn: 0.0653740	total: 1.67s	remaining: 2.68s
# 384:	learn: 0.0652496	total: 1.67s	remaining: 2.67s
# 385:	learn: 0.0651458	total: 1.68s	remaining: 2.67s
# 386:	learn: 0.0650285	total: 1.68s	remaining: 2.66s
# 387:	learn: 0.0649242	total: 1.68s	remaining: 2.65s
# 388:	learn: 0.0648163	total: 1.69s	remaining: 2.65s
# 389:	learn: 0.0647467	total: 1.69s	remaining: 2.64s
# 390:	learn: 0.0646089	total: 1.69s	remaining: 2.64s
# 391:	learn: 0.0645039	total: 1.7s	remaining: 2.63s
# 392:	learn: 0.0644445	total: 1.7s	remaining: 2.63s
# 393:	learn: 0.0643219	total: 1.7s	remaining: 2.62s
# 394:	learn: 0.0641813	total: 1.71s	remaining: 2.62s
# 395:	learn: 0.0641084	total: 1.71s	remaining: 2.61s
# 396:	learn: 0.0639983	total: 1.72s	remaining: 2.61s
# 397:	learn: 0.0639336	total: 1.72s	remaining: 2.6s
# 398:	learn: 0.0638673	total: 1.72s	remaining: 2.6s
# 399:	learn: 0.0637788	total: 1.73s	remaining: 2.59s
# 400:	learn: 0.0636660	total: 1.73s	remaining: 2.59s
# 401:	learn: 0.0635692	total: 1.74s	remaining: 2.58s
# 402:	learn: 0.0634991	total: 1.74s	remaining: 2.58s
# 403:	learn: 0.0633822	total: 1.74s	remaining: 2.57s
# 404:	learn: 0.0632772	total: 1.75s	remaining: 2.57s
# 405:	learn: 0.0631785	total: 1.75s	remaining: 2.56s
# 406:	learn: 0.0630386	total: 1.75s	remaining: 2.56s
# 407:	learn: 0.0629109	total: 1.76s	remaining: 2.55s
# 408:	learn: 0.0628508	total: 1.76s	remaining: 2.55s
# 409:	learn: 0.0627112	total: 1.77s	remaining: 2.54s
# 410:	learn: 0.0626111	total: 1.77s	remaining: 2.54s
# 411:	learn: 0.0625138	total: 1.77s	remaining: 2.53s
# 412:	learn: 0.0624050	total: 1.78s	remaining: 2.53s
# 413:	learn: 0.0622982	total: 1.78s	remaining: 2.52s
# 414:	learn: 0.0621260	total: 1.78s	remaining: 2.52s
# 415:	learn: 0.0620793	total: 1.79s	remaining: 2.51s
# 416:	learn: 0.0620296	total: 1.79s	remaining: 2.51s
# 417:	learn: 0.0619094	total: 1.8s	remaining: 2.5s
# 418:	learn: 0.0618283	total: 1.8s	remaining: 2.5s
# 419:	learn: 0.0616760	total: 1.8s	remaining: 2.49s
# 420:	learn: 0.0615571	total: 1.81s	remaining: 2.48s
# 421:	learn: 0.0614463	total: 1.81s	remaining: 2.48s
# 422:	learn: 0.0613066	total: 1.81s	remaining: 2.47s
# 423:	learn: 0.0611799	total: 1.82s	remaining: 2.47s
# 424:	learn: 0.0610577	total: 1.82s	remaining: 2.46s
# 425:	learn: 0.0609515	total: 1.82s	remaining: 2.46s
# 426:	learn: 0.0608818	total: 1.83s	remaining: 2.45s
# 427:	learn: 0.0607975	total: 1.83s	remaining: 2.45s
# 428:	learn: 0.0607485	total: 1.83s	remaining: 2.44s
# 429:	learn: 0.0606833	total: 1.84s	remaining: 2.44s
# 430:	learn: 0.0605932	total: 1.84s	remaining: 2.43s
# 431:	learn: 0.0604607	total: 1.84s	remaining: 2.42s
# 432:	learn: 0.0603348	total: 1.85s	remaining: 2.42s
# 433:	learn: 0.0602522	total: 1.85s	remaining: 2.41s
# 434:	learn: 0.0601885	total: 1.85s	remaining: 2.41s
# 435:	learn: 0.0600755	total: 1.86s	remaining: 2.4s
# 436:	learn: 0.0600359	total: 1.86s	remaining: 2.4s
# 437:	learn: 0.0598944	total: 1.86s	remaining: 2.39s
# 438:	learn: 0.0598112	total: 1.87s	remaining: 2.39s
# 439:	learn: 0.0597078	total: 1.87s	remaining: 2.38s
# 440:	learn: 0.0596072	total: 1.88s	remaining: 2.38s
# 441:	learn: 0.0595241	total: 1.88s	remaining: 2.37s
# 442:	learn: 0.0594755	total: 1.88s	remaining: 2.37s
# 443:	learn: 0.0593593	total: 1.89s	remaining: 2.36s
# 444:	learn: 0.0592271	total: 1.89s	remaining: 2.35s
# 445:	learn: 0.0591578	total: 1.89s	remaining: 2.35s
# 446:	learn: 0.0590857	total: 1.9s	remaining: 2.35s
# 447:	learn: 0.0590038	total: 1.9s	remaining: 2.34s
# 448:	learn: 0.0589571	total: 1.9s	remaining: 2.33s
# 449:	learn: 0.0588645	total: 1.91s	remaining: 2.33s
# 450:	learn: 0.0587256	total: 1.91s	remaining: 2.32s
# 451:	learn: 0.0586051	total: 1.91s	remaining: 2.32s
# 452:	learn: 0.0585489	total: 1.92s	remaining: 2.31s
# 453:	learn: 0.0584482	total: 1.92s	remaining: 2.31s
# 454:	learn: 0.0584057	total: 1.92s	remaining: 2.3s
# 455:	learn: 0.0583328	total: 1.93s	remaining: 2.3s
# 456:	learn: 0.0582679	total: 1.93s	remaining: 2.29s
# 457:	learn: 0.0581710	total: 1.93s	remaining: 2.29s
# 458:	learn: 0.0580751	total: 1.94s	remaining: 2.28s
# 459:	learn: 0.0579840	total: 1.94s	remaining: 2.28s
# 460:	learn: 0.0578840	total: 1.94s	remaining: 2.27s
# 461:	learn: 0.0578396	total: 1.95s	remaining: 2.27s
# 462:	learn: 0.0577836	total: 1.95s	remaining: 2.26s
# 463:	learn: 0.0576957	total: 1.95s	remaining: 2.25s
# 464:	learn: 0.0576390	total: 1.96s	remaining: 2.25s
# 465:	learn: 0.0575559	total: 1.96s	remaining: 2.24s
# 466:	learn: 0.0574638	total: 1.96s	remaining: 2.24s
# 467:	learn: 0.0573655	total: 1.97s	remaining: 2.23s
# 468:	learn: 0.0572984	total: 1.97s	remaining: 2.23s
# 469:	learn: 0.0572456	total: 1.97s	remaining: 2.22s
# 470:	learn: 0.0571997	total: 1.97s	remaining: 2.22s
# 471:	learn: 0.0571257	total: 1.98s	remaining: 2.21s
# 472:	learn: 0.0570250	total: 1.98s	remaining: 2.21s
# 473:	learn: 0.0569244	total: 1.98s	remaining: 2.2s
# 474:	learn: 0.0568442	total: 1.99s	remaining: 2.2s
# 475:	learn: 0.0567846	total: 1.99s	remaining: 2.19s
# 476:	learn: 0.0566795	total: 2s	remaining: 2.19s
# 477:	learn: 0.0566226	total: 2s	remaining: 2.18s
# 478:	learn: 0.0565728	total: 2s	remaining: 2.18s
# 479:	learn: 0.0565014	total: 2.01s	remaining: 2.17s
# 480:	learn: 0.0563863	total: 2.01s	remaining: 2.17s
# 481:	learn: 0.0563121	total: 2.01s	remaining: 2.16s
# 482:	learn: 0.0562570	total: 2.02s	remaining: 2.16s
# 483:	learn: 0.0561970	total: 2.02s	remaining: 2.15s
# 484:	learn: 0.0560433	total: 2.02s	remaining: 2.15s
# 485:	learn: 0.0559738	total: 2.03s	remaining: 2.14s
# 486:	learn: 0.0558749	total: 2.03s	remaining: 2.14s
# 487:	learn: 0.0557857	total: 2.03s	remaining: 2.13s
# 488:	learn: 0.0556912	total: 2.04s	remaining: 2.13s
# 489:	learn: 0.0556299	total: 2.04s	remaining: 2.12s
# 490:	learn: 0.0555912	total: 2.04s	remaining: 2.12s
# 491:	learn: 0.0555175	total: 2.05s	remaining: 2.11s
# 492:	learn: 0.0554369	total: 2.05s	remaining: 2.11s
# 493:	learn: 0.0552935	total: 2.05s	remaining: 2.1s
# 494:	learn: 0.0552068	total: 2.06s	remaining: 2.1s
# 495:	learn: 0.0551709	total: 2.06s	remaining: 2.1s
# 496:	learn: 0.0550727	total: 2.06s	remaining: 2.09s
# 497:	learn: 0.0549633	total: 2.07s	remaining: 2.08s
# 498:	learn: 0.0548967	total: 2.07s	remaining: 2.08s
# 499:	learn: 0.0548603	total: 2.08s	remaining: 2.08s
# 500:	learn: 0.0548191	total: 2.08s	remaining: 2.07s
# 501:	learn: 0.0547147	total: 2.08s	remaining: 2.06s
# 502:	learn: 0.0546156	total: 2.08s	remaining: 2.06s
# 503:	learn: 0.0545832	total: 2.09s	remaining: 2.06s
# 504:	learn: 0.0545334	total: 2.09s	remaining: 2.05s
# 505:	learn: 0.0544493	total: 2.1s	remaining: 2.05s
# 506:	learn: 0.0543929	total: 2.1s	remaining: 2.04s
# 507:	learn: 0.0543586	total: 2.1s	remaining: 2.04s
# 508:	learn: 0.0542936	total: 2.11s	remaining: 2.03s
# 509:	learn: 0.0542230	total: 2.11s	remaining: 2.03s
# 510:	learn: 0.0541194	total: 2.11s	remaining: 2.02s
# 511:	learn: 0.0540640	total: 2.12s	remaining: 2.02s
# 512:	learn: 0.0539969	total: 2.12s	remaining: 2.01s
# 513:	learn: 0.0539199	total: 2.13s	remaining: 2.01s
# 514:	learn: 0.0538633	total: 2.13s	remaining: 2s
# 515:	learn: 0.0537902	total: 2.13s	remaining: 2s
# 516:	learn: 0.0537429	total: 2.13s	remaining: 1.99s
# 517:	learn: 0.0536762	total: 2.14s	remaining: 1.99s
# 518:	learn: 0.0535987	total: 2.14s	remaining: 1.99s
# 519:	learn: 0.0535698	total: 2.15s	remaining: 1.98s
# 520:	learn: 0.0534770	total: 2.15s	remaining: 1.98s
# 521:	learn: 0.0534152	total: 2.15s	remaining: 1.97s
# 522:	learn: 0.0533421	total: 2.16s	remaining: 1.97s
# 523:	learn: 0.0532887	total: 2.16s	remaining: 1.96s
# 524:	learn: 0.0532287	total: 2.16s	remaining: 1.96s
# 525:	learn: 0.0531326	total: 2.17s	remaining: 1.95s
# 526:	learn: 0.0530275	total: 2.17s	remaining: 1.95s
# 527:	learn: 0.0529440	total: 2.17s	remaining: 1.94s
# 528:	learn: 0.0528986	total: 2.18s	remaining: 1.94s
# 529:	learn: 0.0528502	total: 2.18s	remaining: 1.93s
# 530:	learn: 0.0527866	total: 2.18s	remaining: 1.93s
# 531:	learn: 0.0527218	total: 2.19s	remaining: 1.92s
# 532:	learn: 0.0526614	total: 2.19s	remaining: 1.92s
# 533:	learn: 0.0526025	total: 2.19s	remaining: 1.92s
# 534:	learn: 0.0525245	total: 2.2s	remaining: 1.91s
# 535:	learn: 0.0524909	total: 2.2s	remaining: 1.91s
# 536:	learn: 0.0523604	total: 2.2s	remaining: 1.9s
# 537:	learn: 0.0523242	total: 2.21s	remaining: 1.9s
# 538:	learn: 0.0522371	total: 2.21s	remaining: 1.89s
# 539:	learn: 0.0521273	total: 2.21s	remaining: 1.89s
# 540:	learn: 0.0520635	total: 2.22s	remaining: 1.88s
# 541:	learn: 0.0520011	total: 2.22s	remaining: 1.88s
# 542:	learn: 0.0519265	total: 2.23s	remaining: 1.87s
# 543:	learn: 0.0518372	total: 2.23s	remaining: 1.87s
# 544:	learn: 0.0517671	total: 2.23s	remaining: 1.86s
# 545:	learn: 0.0517251	total: 2.24s	remaining: 1.86s
# 546:	learn: 0.0516866	total: 2.24s	remaining: 1.85s
# 547:	learn: 0.0516371	total: 2.24s	remaining: 1.85s
# 548:	learn: 0.0515774	total: 2.25s	remaining: 1.84s
# 549:	learn: 0.0515133	total: 2.25s	remaining: 1.84s
# 550:	learn: 0.0514711	total: 2.25s	remaining: 1.84s
# 551:	learn: 0.0514048	total: 2.26s	remaining: 1.83s
# 552:	learn: 0.0513386	total: 2.26s	remaining: 1.83s
# 553:	learn: 0.0512559	total: 2.26s	remaining: 1.82s
# 554:	learn: 0.0511803	total: 2.27s	remaining: 1.82s
# 555:	learn: 0.0511527	total: 2.27s	remaining: 1.81s
# 556:	learn: 0.0511160	total: 2.27s	remaining: 1.81s
# 557:	learn: 0.0510762	total: 2.28s	remaining: 1.8s
# 558:	learn: 0.0510459	total: 2.28s	remaining: 1.8s
# 559:	learn: 0.0509988	total: 2.29s	remaining: 1.79s
# 560:	learn: 0.0509129	total: 2.29s	remaining: 1.79s
# 561:	learn: 0.0508114	total: 2.29s	remaining: 1.79s
# 562:	learn: 0.0507518	total: 2.3s	remaining: 1.78s
# 563:	learn: 0.0507268	total: 2.3s	remaining: 1.78s
# 564:	learn: 0.0506875	total: 2.3s	remaining: 1.77s
# 565:	learn: 0.0506349	total: 2.31s	remaining: 1.77s
# 566:	learn: 0.0505849	total: 2.31s	remaining: 1.76s
# 567:	learn: 0.0504872	total: 2.31s	remaining: 1.76s
# 568:	learn: 0.0504364	total: 2.32s	remaining: 1.75s
# 569:	learn: 0.0503548	total: 2.32s	remaining: 1.75s
# 570:	learn: 0.0502926	total: 2.32s	remaining: 1.75s
# 571:	learn: 0.0502054	total: 2.33s	remaining: 1.74s
# 572:	learn: 0.0501480	total: 2.33s	remaining: 1.74s
# 573:	learn: 0.0500797	total: 2.34s	remaining: 1.73s
# 574:	learn: 0.0500419	total: 2.34s	remaining: 1.73s
# 575:	learn: 0.0500045	total: 2.34s	remaining: 1.73s
# 576:	learn: 0.0499646	total: 2.35s	remaining: 1.72s
# 577:	learn: 0.0499203	total: 2.35s	remaining: 1.72s
# 578:	learn: 0.0498736	total: 2.36s	remaining: 1.71s
# 579:	learn: 0.0497919	total: 2.36s	remaining: 1.71s
# 580:	learn: 0.0497004	total: 2.37s	remaining: 1.71s
# 581:	learn: 0.0496358	total: 2.37s	remaining: 1.7s
# 582:	learn: 0.0495958	total: 2.38s	remaining: 1.7s
# 583:	learn: 0.0495686	total: 2.38s	remaining: 1.7s
# 584:	learn: 0.0494995	total: 2.39s	remaining: 1.7s
# 585:	learn: 0.0494735	total: 2.4s	remaining: 1.69s
# 586:	learn: 0.0494012	total: 2.4s	remaining: 1.69s
# 587:	learn: 0.0493259	total: 2.4s	remaining: 1.68s
# 588:	learn: 0.0492683	total: 2.41s	remaining: 1.68s
# 589:	learn: 0.0492131	total: 2.41s	remaining: 1.67s
# 590:	learn: 0.0491705	total: 2.41s	remaining: 1.67s
# 591:	learn: 0.0491076	total: 2.42s	remaining: 1.67s
# 592:	learn: 0.0490728	total: 2.42s	remaining: 1.66s
# 593:	learn: 0.0490192	total: 2.43s	remaining: 1.66s
# 594:	learn: 0.0489766	total: 2.43s	remaining: 1.66s
# 595:	learn: 0.0489011	total: 2.44s	remaining: 1.65s
# 596:	learn: 0.0488081	total: 2.44s	remaining: 1.65s
# 597:	learn: 0.0487085	total: 2.45s	remaining: 1.64s
# 598:	learn: 0.0486681	total: 2.45s	remaining: 1.64s
# 599:	learn: 0.0486018	total: 2.45s	remaining: 1.64s
# 600:	learn: 0.0485764	total: 2.46s	remaining: 1.63s
# 601:	learn: 0.0484909	total: 2.46s	remaining: 1.63s
# 602:	learn: 0.0484461	total: 2.46s	remaining: 1.62s
# 603:	learn: 0.0484095	total: 2.47s	remaining: 1.62s
# 604:	learn: 0.0483414	total: 2.47s	remaining: 1.61s
# 605:	learn: 0.0483109	total: 2.48s	remaining: 1.61s
# 606:	learn: 0.0482887	total: 2.48s	remaining: 1.61s
# 607:	learn: 0.0482417	total: 2.49s	remaining: 1.6s
# 608:	learn: 0.0481920	total: 2.49s	remaining: 1.6s
# 609:	learn: 0.0481478	total: 2.5s	remaining: 1.6s
# 610:	learn: 0.0480868	total: 2.5s	remaining: 1.59s
# 611:	learn: 0.0480133	total: 2.5s	remaining: 1.59s
# 612:	learn: 0.0479449	total: 2.51s	remaining: 1.58s
# 613:	learn: 0.0479204	total: 2.51s	remaining: 1.58s
# 614:	learn: 0.0478875	total: 2.52s	remaining: 1.57s
# 615:	learn: 0.0478339	total: 2.52s	remaining: 1.57s
# 616:	learn: 0.0477803	total: 2.52s	remaining: 1.57s
# 617:	learn: 0.0477451	total: 2.53s	remaining: 1.56s
# 618:	learn: 0.0476633	total: 2.54s	remaining: 1.56s
# 619:	learn: 0.0475934	total: 2.54s	remaining: 1.56s
# 620:	learn: 0.0475588	total: 2.54s	remaining: 1.55s
# 621:	learn: 0.0474995	total: 2.55s	remaining: 1.55s
# 622:	learn: 0.0474039	total: 2.56s	remaining: 1.55s
# 623:	learn: 0.0473414	total: 2.56s	remaining: 1.54s
# 624:	learn: 0.0473173	total: 2.56s	remaining: 1.54s
# 625:	learn: 0.0472835	total: 2.57s	remaining: 1.53s
# 626:	learn: 0.0472628	total: 2.57s	remaining: 1.53s
# 627:	learn: 0.0471815	total: 2.58s	remaining: 1.53s
# 628:	learn: 0.0471463	total: 2.58s	remaining: 1.52s
# 629:	learn: 0.0470962	total: 2.59s	remaining: 1.52s
# 630:	learn: 0.0470588	total: 2.59s	remaining: 1.52s
# 631:	learn: 0.0470254	total: 2.6s	remaining: 1.51s
# 632:	learn: 0.0469668	total: 2.6s	remaining: 1.51s
# 633:	learn: 0.0468920	total: 2.61s	remaining: 1.51s
# 634:	learn: 0.0468353	total: 2.61s	remaining: 1.5s
# 635:	learn: 0.0467580	total: 2.62s	remaining: 1.5s
# 636:	learn: 0.0466945	total: 2.62s	remaining: 1.5s
# 637:	learn: 0.0466625	total: 2.63s	remaining: 1.49s
# 638:	learn: 0.0466031	total: 2.63s	remaining: 1.49s
# 639:	learn: 0.0465368	total: 2.64s	remaining: 1.49s
# 640:	learn: 0.0464739	total: 2.65s	remaining: 1.48s
# 641:	learn: 0.0464300	total: 2.65s	remaining: 1.48s
# 642:	learn: 0.0463700	total: 2.66s	remaining: 1.48s
# 643:	learn: 0.0463317	total: 2.66s	remaining: 1.47s
# 644:	learn: 0.0462736	total: 2.67s	remaining: 1.47s
# 645:	learn: 0.0462257	total: 2.67s	remaining: 1.47s
# 646:	learn: 0.0461544	total: 2.68s	remaining: 1.46s
# 647:	learn: 0.0461071	total: 2.68s	remaining: 1.46s
# 648:	learn: 0.0460816	total: 2.69s	remaining: 1.45s
# 649:	learn: 0.0460135	total: 2.69s	remaining: 1.45s
# 650:	learn: 0.0459593	total: 2.69s	remaining: 1.44s
# 651:	learn: 0.0459259	total: 2.7s	remaining: 1.44s
# 652:	learn: 0.0458685	total: 2.7s	remaining: 1.44s
# 653:	learn: 0.0458095	total: 2.71s	remaining: 1.43s
# 654:	learn: 0.0457462	total: 2.71s	remaining: 1.43s
# 655:	learn: 0.0457197	total: 2.72s	remaining: 1.42s
# 656:	learn: 0.0456625	total: 2.72s	remaining: 1.42s
# 657:	learn: 0.0456242	total: 2.72s	remaining: 1.42s
# 658:	learn: 0.0456022	total: 2.73s	remaining: 1.41s
# 659:	learn: 0.0455645	total: 2.73s	remaining: 1.41s
# 660:	learn: 0.0455042	total: 2.73s	remaining: 1.4s
# 661:	learn: 0.0454286	total: 2.74s	remaining: 1.4s
# 662:	learn: 0.0453843	total: 2.74s	remaining: 1.39s
# 663:	learn: 0.0453080	total: 2.74s	remaining: 1.39s
# 664:	learn: 0.0452603	total: 2.75s	remaining: 1.38s
# 665:	learn: 0.0451935	total: 2.75s	remaining: 1.38s
# 666:	learn: 0.0451521	total: 2.75s	remaining: 1.37s
# 667:	learn: 0.0450967	total: 2.76s	remaining: 1.37s
# 668:	learn: 0.0450417	total: 2.76s	remaining: 1.36s
# 669:	learn: 0.0449968	total: 2.76s	remaining: 1.36s
# 670:	learn: 0.0449154	total: 2.77s	remaining: 1.36s
# 671:	learn: 0.0448627	total: 2.77s	remaining: 1.35s
# 672:	learn: 0.0448056	total: 2.77s	remaining: 1.35s
# 673:	learn: 0.0447812	total: 2.78s	remaining: 1.34s
# 674:	learn: 0.0447042	total: 2.78s	remaining: 1.34s
# 675:	learn: 0.0446755	total: 2.78s	remaining: 1.33s
# 676:	learn: 0.0446496	total: 2.79s	remaining: 1.33s
# 677:	learn: 0.0445859	total: 2.79s	remaining: 1.32s
# 678:	learn: 0.0445640	total: 2.79s	remaining: 1.32s
# 679:	learn: 0.0445310	total: 2.8s	remaining: 1.32s
# 680:	learn: 0.0444952	total: 2.8s	remaining: 1.31s
# 681:	learn: 0.0444554	total: 2.8s	remaining: 1.31s
# 682:	learn: 0.0443793	total: 2.81s	remaining: 1.3s
# 683:	learn: 0.0443371	total: 2.81s	remaining: 1.3s
# 684:	learn: 0.0443070	total: 2.81s	remaining: 1.29s
# 685:	learn: 0.0442547	total: 2.82s	remaining: 1.29s
# 686:	learn: 0.0441826	total: 2.82s	remaining: 1.28s
# 687:	learn: 0.0441614	total: 2.82s	remaining: 1.28s
# 688:	learn: 0.0441299	total: 2.83s	remaining: 1.28s
# 689:	learn: 0.0441057	total: 2.83s	remaining: 1.27s
# 690:	learn: 0.0440481	total: 2.83s	remaining: 1.27s
# 691:	learn: 0.0440041	total: 2.84s	remaining: 1.26s
# 692:	learn: 0.0439655	total: 2.84s	remaining: 1.26s
# 693:	learn: 0.0438948	total: 2.84s	remaining: 1.25s
# 694:	learn: 0.0438417	total: 2.85s	remaining: 1.25s
# 695:	learn: 0.0438109	total: 2.85s	remaining: 1.25s
# 696:	learn: 0.0437717	total: 2.85s	remaining: 1.24s
# 697:	learn: 0.0436999	total: 2.86s	remaining: 1.24s
# 698:	learn: 0.0436300	total: 2.86s	remaining: 1.23s
# 699:	learn: 0.0435607	total: 2.87s	remaining: 1.23s
# 700:	learn: 0.0435161	total: 2.87s	remaining: 1.22s
# 701:	learn: 0.0434440	total: 2.87s	remaining: 1.22s
# 702:	learn: 0.0434075	total: 2.88s	remaining: 1.22s
# 703:	learn: 0.0433547	total: 2.88s	remaining: 1.21s
# 704:	learn: 0.0433343	total: 2.88s	remaining: 1.21s
# 705:	learn: 0.0432831	total: 2.89s	remaining: 1.2s
# 706:	learn: 0.0432473	total: 2.89s	remaining: 1.2s
# 707:	learn: 0.0432276	total: 2.89s	remaining: 1.19s
# 708:	learn: 0.0431994	total: 2.9s	remaining: 1.19s
# 709:	learn: 0.0431282	total: 2.9s	remaining: 1.19s
# 710:	learn: 0.0430868	total: 2.9s	remaining: 1.18s
# 711:	learn: 0.0430310	total: 2.91s	remaining: 1.18s
# 712:	learn: 0.0430118	total: 2.91s	remaining: 1.17s
# 713:	learn: 0.0429732	total: 2.92s	remaining: 1.17s
# 714:	learn: 0.0429289	total: 2.92s	remaining: 1.16s
# 715:	learn: 0.0429037	total: 2.92s	remaining: 1.16s
# 716:	learn: 0.0428593	total: 2.93s	remaining: 1.15s
# 717:	learn: 0.0428301	total: 2.93s	remaining: 1.15s
# 718:	learn: 0.0427592	total: 2.93s	remaining: 1.15s
# 719:	learn: 0.0427279	total: 2.94s	remaining: 1.14s
# 720:	learn: 0.0426768	total: 2.94s	remaining: 1.14s
# 721:	learn: 0.0426378	total: 2.94s	remaining: 1.13s
# 722:	learn: 0.0425665	total: 2.95s	remaining: 1.13s
# 723:	learn: 0.0425398	total: 2.95s	remaining: 1.12s
# 724:	learn: 0.0425214	total: 2.95s	remaining: 1.12s
# 725:	learn: 0.0424801	total: 2.96s	remaining: 1.12s
# 726:	learn: 0.0424514	total: 2.96s	remaining: 1.11s
# 727:	learn: 0.0424014	total: 2.96s	remaining: 1.11s
# 728:	learn: 0.0423692	total: 2.97s	remaining: 1.1s
# 729:	learn: 0.0423221	total: 2.97s	remaining: 1.1s
# 730:	learn: 0.0422943	total: 2.97s	remaining: 1.09s
# 731:	learn: 0.0422461	total: 2.98s	remaining: 1.09s
# 732:	learn: 0.0421825	total: 2.98s	remaining: 1.08s
# 733:	learn: 0.0421456	total: 2.98s	remaining: 1.08s
# 734:	learn: 0.0421063	total: 2.99s	remaining: 1.08s
# 735:	learn: 0.0420561	total: 2.99s	remaining: 1.07s
# 736:	learn: 0.0420375	total: 2.99s	remaining: 1.07s
# 737:	learn: 0.0419712	total: 3s	remaining: 1.06s
# 738:	learn: 0.0419250	total: 3s	remaining: 1.06s
# 739:	learn: 0.0418541	total: 3s	remaining: 1.06s
# 740:	learn: 0.0418188	total: 3.01s	remaining: 1.05s
# 741:	learn: 0.0417693	total: 3.01s	remaining: 1.05s
# 742:	learn: 0.0417474	total: 3.02s	remaining: 1.04s
# 743:	learn: 0.0417001	total: 3.02s	remaining: 1.04s
# 744:	learn: 0.0416824	total: 3.02s	remaining: 1.03s
# 745:	learn: 0.0416413	total: 3.03s	remaining: 1.03s
# 746:	learn: 0.0415765	total: 3.03s	remaining: 1.03s
# 747:	learn: 0.0415327	total: 3.03s	remaining: 1.02s
# 748:	learn: 0.0414835	total: 3.04s	remaining: 1.02s
# 749:	learn: 0.0414423	total: 3.04s	remaining: 1.01s
# 750:	learn: 0.0413421	total: 3.04s	remaining: 1.01s
# 751:	learn: 0.0413250	total: 3.05s	remaining: 1s
# 752:	learn: 0.0413005	total: 3.05s	remaining: 1s
# 753:	learn: 0.0412628	total: 3.05s	remaining: 997ms
# 754:	learn: 0.0412308	total: 3.06s	remaining: 992ms
# 755:	learn: 0.0412078	total: 3.06s	remaining: 988ms
# 756:	learn: 0.0411740	total: 3.06s	remaining: 984ms
# 757:	learn: 0.0411433	total: 3.07s	remaining: 980ms
# 758:	learn: 0.0410789	total: 3.07s	remaining: 975ms
# 759:	learn: 0.0410461	total: 3.07s	remaining: 971ms
# 760:	learn: 0.0410160	total: 3.08s	remaining: 966ms
# 761:	learn: 0.0409744	total: 3.08s	remaining: 962ms
# 762:	learn: 0.0409408	total: 3.08s	remaining: 958ms
# 763:	learn: 0.0408987	total: 3.09s	remaining: 954ms
# 764:	learn: 0.0408631	total: 3.09s	remaining: 949ms
# 765:	learn: 0.0408332	total: 3.09s	remaining: 945ms
# 766:	learn: 0.0408108	total: 3.1s	remaining: 941ms
# 767:	learn: 0.0407695	total: 3.1s	remaining: 937ms
# 768:	learn: 0.0407486	total: 3.1s	remaining: 932ms
# 769:	learn: 0.0407320	total: 3.11s	remaining: 928ms
# 770:	learn: 0.0406865	total: 3.11s	remaining: 924ms
# 771:	learn: 0.0406514	total: 3.11s	remaining: 919ms
# 772:	learn: 0.0405927	total: 3.12s	remaining: 915ms
# 773:	learn: 0.0405557	total: 3.12s	remaining: 911ms
# 774:	learn: 0.0404942	total: 3.12s	remaining: 907ms
# 775:	learn: 0.0404347	total: 3.13s	remaining: 903ms
# 776:	learn: 0.0403974	total: 3.13s	remaining: 898ms
# 777:	learn: 0.0403702	total: 3.13s	remaining: 894ms
# 778:	learn: 0.0403206	total: 3.14s	remaining: 890ms
# 779:	learn: 0.0402975	total: 3.14s	remaining: 886ms
# 780:	learn: 0.0402664	total: 3.14s	remaining: 881ms
# 781:	learn: 0.0402320	total: 3.15s	remaining: 877ms
# 782:	learn: 0.0402163	total: 3.15s	remaining: 873ms
# 783:	learn: 0.0401891	total: 3.15s	remaining: 869ms
# 784:	learn: 0.0401712	total: 3.15s	remaining: 864ms
# 785:	learn: 0.0401073	total: 3.16s	remaining: 860ms
# 786:	learn: 0.0400812	total: 3.16s	remaining: 856ms
# 787:	learn: 0.0400600	total: 3.17s	remaining: 852ms
# 788:	learn: 0.0399931	total: 3.17s	remaining: 847ms
# 789:	learn: 0.0399503	total: 3.17s	remaining: 843ms
# 790:	learn: 0.0399105	total: 3.17s	remaining: 839ms
# 791:	learn: 0.0398628	total: 3.18s	remaining: 835ms
# 792:	learn: 0.0397711	total: 3.18s	remaining: 830ms
# 793:	learn: 0.0397253	total: 3.18s	remaining: 826ms
# 794:	learn: 0.0396995	total: 3.19s	remaining: 822ms
# 795:	learn: 0.0396791	total: 3.19s	remaining: 818ms
# 796:	learn: 0.0396512	total: 3.19s	remaining: 814ms
# 797:	learn: 0.0396303	total: 3.2s	remaining: 809ms
# 798:	learn: 0.0395695	total: 3.2s	remaining: 805ms
# 799:	learn: 0.0395403	total: 3.2s	remaining: 801ms
# 800:	learn: 0.0395081	total: 3.21s	remaining: 797ms
# 801:	learn: 0.0394737	total: 3.21s	remaining: 793ms
# 802:	learn: 0.0394152	total: 3.21s	remaining: 788ms
# 803:	learn: 0.0393802	total: 3.22s	remaining: 784ms
# 804:	learn: 0.0393165	total: 3.22s	remaining: 780ms
# 805:	learn: 0.0392855	total: 3.22s	remaining: 776ms
# 806:	learn: 0.0392471	total: 3.23s	remaining: 772ms
# 807:	learn: 0.0392147	total: 3.23s	remaining: 768ms
# 808:	learn: 0.0391570	total: 3.23s	remaining: 764ms
# 809:	learn: 0.0391304	total: 3.24s	remaining: 759ms
# 810:	learn: 0.0391038	total: 3.24s	remaining: 755ms
# 811:	learn: 0.0390734	total: 3.24s	remaining: 751ms
# 812:	learn: 0.0390358	total: 3.25s	remaining: 747ms
# 813:	learn: 0.0390044	total: 3.25s	remaining: 743ms
# 814:	learn: 0.0389615	total: 3.25s	remaining: 739ms
# 815:	learn: 0.0389247	total: 3.26s	remaining: 734ms
# 816:	learn: 0.0388996	total: 3.26s	remaining: 730ms
# 817:	learn: 0.0388380	total: 3.26s	remaining: 726ms
# 818:	learn: 0.0388125	total: 3.27s	remaining: 722ms
# 819:	learn: 0.0387975	total: 3.27s	remaining: 718ms
# 820:	learn: 0.0387796	total: 3.27s	remaining: 714ms
# 821:	learn: 0.0387561	total: 3.28s	remaining: 710ms
# 822:	learn: 0.0387415	total: 3.28s	remaining: 706ms
# 823:	learn: 0.0387149	total: 3.28s	remaining: 702ms
# 824:	learn: 0.0386448	total: 3.29s	remaining: 697ms
# 825:	learn: 0.0386170	total: 3.29s	remaining: 693ms
# 826:	learn: 0.0386027	total: 3.29s	remaining: 689ms
# 827:	learn: 0.0385588	total: 3.3s	remaining: 685ms
# 828:	learn: 0.0385216	total: 3.3s	remaining: 681ms
# 829:	learn: 0.0384729	total: 3.3s	remaining: 677ms
# 830:	learn: 0.0384440	total: 3.31s	remaining: 673ms
# 831:	learn: 0.0383897	total: 3.31s	remaining: 669ms
# 832:	learn: 0.0383328	total: 3.31s	remaining: 665ms
# 833:	learn: 0.0383091	total: 3.32s	remaining: 660ms
# 834:	learn: 0.0382760	total: 3.32s	remaining: 656ms
# 835:	learn: 0.0382368	total: 3.33s	remaining: 652ms
# 836:	learn: 0.0382158	total: 3.33s	remaining: 648ms
# 837:	learn: 0.0381919	total: 3.33s	remaining: 644ms
# 838:	learn: 0.0381357	total: 3.33s	remaining: 640ms
# 839:	learn: 0.0381158	total: 3.34s	remaining: 636ms
# 840:	learn: 0.0380907	total: 3.34s	remaining: 632ms
# 841:	learn: 0.0380155	total: 3.35s	remaining: 628ms
# 842:	learn: 0.0379695	total: 3.35s	remaining: 624ms
# 843:	learn: 0.0379544	total: 3.35s	remaining: 620ms
# 844:	learn: 0.0379302	total: 3.36s	remaining: 616ms
# 845:	learn: 0.0379085	total: 3.36s	remaining: 612ms
# 846:	learn: 0.0378948	total: 3.36s	remaining: 608ms
# 847:	learn: 0.0378351	total: 3.37s	remaining: 604ms
# 848:	learn: 0.0377727	total: 3.37s	remaining: 600ms
# 849:	learn: 0.0377498	total: 3.38s	remaining: 596ms
# 850:	learn: 0.0377105	total: 3.38s	remaining: 592ms
# 851:	learn: 0.0376622	total: 3.38s	remaining: 587ms
# 852:	learn: 0.0376396	total: 3.38s	remaining: 583ms
# 853:	learn: 0.0375933	total: 3.39s	remaining: 579ms
# 854:	learn: 0.0375631	total: 3.39s	remaining: 575ms
# 855:	learn: 0.0375095	total: 3.39s	remaining: 571ms
# 856:	learn: 0.0374558	total: 3.4s	remaining: 567ms
# 857:	learn: 0.0374196	total: 3.4s	remaining: 563ms
# 858:	learn: 0.0373889	total: 3.4s	remaining: 559ms
# 859:	learn: 0.0373493	total: 3.41s	remaining: 555ms
# 860:	learn: 0.0372944	total: 3.41s	remaining: 551ms
# 861:	learn: 0.0372767	total: 3.42s	remaining: 547ms
# 862:	learn: 0.0372514	total: 3.42s	remaining: 543ms
# 863:	learn: 0.0372121	total: 3.42s	remaining: 539ms
# 864:	learn: 0.0371760	total: 3.42s	remaining: 535ms
# 865:	learn: 0.0371448	total: 3.43s	remaining: 531ms
# 866:	learn: 0.0371225	total: 3.43s	remaining: 526ms
# 867:	learn: 0.0370934	total: 3.44s	remaining: 522ms
# 868:	learn: 0.0370698	total: 3.44s	remaining: 518ms
# 869:	learn: 0.0370150	total: 3.44s	remaining: 514ms
# 870:	learn: 0.0369783	total: 3.44s	remaining: 510ms
# 871:	learn: 0.0369659	total: 3.45s	remaining: 506ms
# 872:	learn: 0.0369516	total: 3.45s	remaining: 502ms
# 873:	learn: 0.0369342	total: 3.46s	remaining: 498ms
# 874:	learn: 0.0369066	total: 3.46s	remaining: 494ms
# 875:	learn: 0.0368769	total: 3.46s	remaining: 490ms
# 876:	learn: 0.0368483	total: 3.46s	remaining: 486ms
# 877:	learn: 0.0367922	total: 3.47s	remaining: 482ms
# 878:	learn: 0.0367321	total: 3.47s	remaining: 478ms
# 879:	learn: 0.0367044	total: 3.48s	remaining: 474ms
# 880:	learn: 0.0366831	total: 3.48s	remaining: 470ms
# 881:	learn: 0.0366584	total: 3.48s	remaining: 466ms
# 882:	learn: 0.0366389	total: 3.48s	remaining: 462ms
# 883:	learn: 0.0365990	total: 3.49s	remaining: 458ms
# 884:	learn: 0.0365804	total: 3.49s	remaining: 454ms
# 885:	learn: 0.0365547	total: 3.5s	remaining: 450ms
# 886:	learn: 0.0365210	total: 3.5s	remaining: 446ms
# 887:	learn: 0.0364736	total: 3.5s	remaining: 442ms
# 888:	learn: 0.0364334	total: 3.5s	remaining: 438ms
# 889:	learn: 0.0364052	total: 3.51s	remaining: 434ms
# 890:	learn: 0.0363533	total: 3.51s	remaining: 430ms
# 891:	learn: 0.0363032	total: 3.52s	remaining: 426ms
# 892:	learn: 0.0362817	total: 3.52s	remaining: 422ms
# 893:	learn: 0.0362159	total: 3.53s	remaining: 418ms
# 894:	learn: 0.0361387	total: 3.53s	remaining: 414ms
# 895:	learn: 0.0361056	total: 3.54s	remaining: 411ms
# 896:	learn: 0.0360848	total: 3.54s	remaining: 407ms
# 897:	learn: 0.0360531	total: 3.54s	remaining: 403ms
# 898:	learn: 0.0360153	total: 3.55s	remaining: 399ms
# 899:	learn: 0.0359758	total: 3.55s	remaining: 395ms
# 900:	learn: 0.0359129	total: 3.55s	remaining: 391ms
# 901:	learn: 0.0358562	total: 3.56s	remaining: 387ms
# 902:	learn: 0.0358188	total: 3.56s	remaining: 383ms
# 903:	learn: 0.0357953	total: 3.57s	remaining: 379ms
# 904:	learn: 0.0357642	total: 3.57s	remaining: 375ms
# 905:	learn: 0.0357375	total: 3.57s	remaining: 371ms
# 906:	learn: 0.0357034	total: 3.58s	remaining: 367ms
# 907:	learn: 0.0356846	total: 3.59s	remaining: 363ms
# 908:	learn: 0.0356688	total: 3.59s	remaining: 359ms
# 909:	learn: 0.0356483	total: 3.59s	remaining: 355ms
# 910:	learn: 0.0355873	total: 3.6s	remaining: 351ms
# 911:	learn: 0.0355667	total: 3.6s	remaining: 347ms
# 912:	learn: 0.0355465	total: 3.6s	remaining: 343ms
# 913:	learn: 0.0354737	total: 3.61s	remaining: 340ms
# 914:	learn: 0.0354271	total: 3.61s	remaining: 336ms
# 915:	learn: 0.0354091	total: 3.62s	remaining: 332ms
# 916:	learn: 0.0353884	total: 3.62s	remaining: 328ms
# 917:	learn: 0.0353735	total: 3.63s	remaining: 324ms
# 918:	learn: 0.0353517	total: 3.63s	remaining: 320ms
# 919:	learn: 0.0353325	total: 3.63s	remaining: 316ms
# 920:	learn: 0.0352968	total: 3.64s	remaining: 312ms
# 921:	learn: 0.0352298	total: 3.64s	remaining: 308ms
# 922:	learn: 0.0352036	total: 3.65s	remaining: 304ms
# 923:	learn: 0.0351813	total: 3.65s	remaining: 300ms
# 924:	learn: 0.0351253	total: 3.65s	remaining: 296ms
# 925:	learn: 0.0351001	total: 3.66s	remaining: 292ms
# 926:	learn: 0.0350767	total: 3.66s	remaining: 288ms
# 927:	learn: 0.0350516	total: 3.67s	remaining: 285ms
# ...
# 702:	learn: 0.0520526	total: 2.49s	remaining: 1.05s
# 703:	learn: 0.0519991	total: 2.5s	remaining: 1.05s
# 704:	learn: 0.0519758	total: 2.5s	remaining: 1.04s
# 705:	learn: 0.0519235	total: 2.5s	remaining: 1.04s
# 706:	learn: 0.0518788	total: 2.51s	remaining: 1.04s
# 707:	learn: 0.0517878	total: 2.51s	remaining: 1.03s
# 708:	learn: 0.0517196	total: 2.51s	remaining: 1.03s
# 709:	learn: 0.0516760	total: 2.52s	remaining: 1.03s
# 710:	learn: 0.0515850	total: 2.52s	remaining: 1.02s
# 711:	learn: 0.0515178	total: 2.53s	remaining: 1.02s
# 712:	learn: 0.0514472	total: 2.53s	remaining: 1.02s
# 713:	learn: 0.0513732	total: 2.53s	remaining: 1.01s
# 714:	learn: 0.0513369	total: 2.54s	remaining: 1.01s
# 715:	learn: 0.0513025	total: 2.54s	remaining: 1.01s
# 716:	learn: 0.0512165	total: 2.55s	remaining: 1s
# 717:	learn: 0.0511644	total: 2.55s	remaining: 1s
# 718:	learn: 0.0510693	total: 2.55s	remaining: 998ms
# 719:	learn: 0.0510410	total: 2.56s	remaining: 995ms
# 720:	learn: 0.0509933	total: 2.56s	remaining: 991ms
# 721:	learn: 0.0509241	total: 2.56s	remaining: 987ms
# 722:	learn: 0.0508590	total: 2.57s	remaining: 984ms
# 723:	learn: 0.0507552	total: 2.57s	remaining: 980ms
# 724:	learn: 0.0507169	total: 2.57s	remaining: 977ms
# 725:	learn: 0.0506852	total: 2.58s	remaining: 974ms
# 726:	learn: 0.0506496	total: 2.58s	remaining: 971ms
# 727:	learn: 0.0506071	total: 2.59s	remaining: 967ms
# 728:	learn: 0.0505767	total: 2.59s	remaining: 963ms
# 729:	learn: 0.0504818	total: 2.59s	remaining: 960ms
# 730:	learn: 0.0504140	total: 2.6s	remaining: 958ms
# 731:	learn: 0.0503628	total: 2.6s	remaining: 954ms
# 732:	learn: 0.0502789	total: 2.61s	remaining: 950ms
# 733:	learn: 0.0502348	total: 2.61s	remaining: 947ms
# 734:	learn: 0.0502012	total: 2.62s	remaining: 943ms
# 735:	learn: 0.0501419	total: 2.62s	remaining: 939ms
# 736:	learn: 0.0500458	total: 2.62s	remaining: 936ms
# 737:	learn: 0.0500015	total: 2.63s	remaining: 932ms
# 738:	learn: 0.0499636	total: 2.63s	remaining: 929ms
# 739:	learn: 0.0499374	total: 2.63s	remaining: 925ms
# 740:	learn: 0.0498603	total: 2.64s	remaining: 922ms
# 741:	learn: 0.0497859	total: 2.64s	remaining: 918ms
# 742:	learn: 0.0497441	total: 2.64s	remaining: 914ms
# 743:	learn: 0.0496949	total: 2.65s	remaining: 911ms
# 744:	learn: 0.0496569	total: 2.65s	remaining: 907ms
# 745:	learn: 0.0496130	total: 2.65s	remaining: 904ms
# 746:	learn: 0.0495218	total: 2.66s	remaining: 900ms
# 747:	learn: 0.0494747	total: 2.66s	remaining: 896ms
# 748:	learn: 0.0494043	total: 2.66s	remaining: 893ms
# 749:	learn: 0.0493382	total: 2.67s	remaining: 889ms
# 750:	learn: 0.0493126	total: 2.67s	remaining: 886ms
# 751:	learn: 0.0492642	total: 2.67s	remaining: 882ms
# 752:	learn: 0.0492172	total: 2.68s	remaining: 879ms
# 753:	learn: 0.0491725	total: 2.68s	remaining: 875ms
# 754:	learn: 0.0491089	total: 2.69s	remaining: 871ms
# 755:	learn: 0.0490631	total: 2.69s	remaining: 868ms
# 756:	learn: 0.0490164	total: 2.69s	remaining: 864ms
# 757:	learn: 0.0489556	total: 2.69s	remaining: 861ms
# 758:	learn: 0.0489321	total: 2.7s	remaining: 857ms
# 759:	learn: 0.0488785	total: 2.7s	remaining: 853ms
# 760:	learn: 0.0488336	total: 2.71s	remaining: 850ms
# 761:	learn: 0.0487655	total: 2.71s	remaining: 846ms
# 762:	learn: 0.0486923	total: 2.71s	remaining: 843ms
# 763:	learn: 0.0486302	total: 2.71s	remaining: 839ms
# 764:	learn: 0.0485988	total: 2.72s	remaining: 835ms
# 765:	learn: 0.0485283	total: 2.72s	remaining: 832ms
# 766:	learn: 0.0484725	total: 2.73s	remaining: 828ms
# 767:	learn: 0.0484320	total: 2.73s	remaining: 824ms
# 768:	learn: 0.0483901	total: 2.73s	remaining: 821ms
# 769:	learn: 0.0483537	total: 2.73s	remaining: 817ms
# 770:	learn: 0.0483060	total: 2.74s	remaining: 813ms
# 771:	learn: 0.0482819	total: 2.74s	remaining: 810ms
# 772:	learn: 0.0482116	total: 2.74s	remaining: 806ms
# 773:	learn: 0.0481197	total: 2.75s	remaining: 802ms
# 774:	learn: 0.0480505	total: 2.75s	remaining: 799ms
# 775:	learn: 0.0479626	total: 2.75s	remaining: 795ms
# 776:	learn: 0.0479014	total: 2.76s	remaining: 792ms
# 777:	learn: 0.0478674	total: 2.76s	remaining: 788ms
# 778:	learn: 0.0477801	total: 2.76s	remaining: 784ms
# 779:	learn: 0.0477441	total: 2.77s	remaining: 781ms
# 780:	learn: 0.0477000	total: 2.77s	remaining: 777ms
# 781:	learn: 0.0476075	total: 2.77s	remaining: 773ms
# 782:	learn: 0.0475548	total: 2.78s	remaining: 770ms
# 783:	learn: 0.0474972	total: 2.78s	remaining: 766ms
# 784:	learn: 0.0474764	total: 2.78s	remaining: 762ms
# 785:	learn: 0.0474261	total: 2.79s	remaining: 759ms
# 786:	learn: 0.0473715	total: 2.79s	remaining: 755ms
# 787:	learn: 0.0473029	total: 2.79s	remaining: 752ms
# 788:	learn: 0.0472663	total: 2.8s	remaining: 748ms
# 789:	learn: 0.0471992	total: 2.8s	remaining: 744ms
# 790:	learn: 0.0471689	total: 2.8s	remaining: 741ms
# 791:	learn: 0.0471016	total: 2.81s	remaining: 737ms
# 792:	learn: 0.0470512	total: 2.81s	remaining: 734ms
# 793:	learn: 0.0470174	total: 2.81s	remaining: 730ms
# 794:	learn: 0.0469471	total: 2.82s	remaining: 727ms
# 795:	learn: 0.0469110	total: 2.82s	remaining: 723ms
# 796:	learn: 0.0468583	total: 2.82s	remaining: 719ms
# 797:	learn: 0.0467724	total: 2.83s	remaining: 716ms
# 798:	learn: 0.0467335	total: 2.83s	remaining: 712ms
# 799:	learn: 0.0466484	total: 2.83s	remaining: 708ms
# 800:	learn: 0.0465899	total: 2.84s	remaining: 705ms
# 801:	learn: 0.0465031	total: 2.84s	remaining: 701ms
# 802:	learn: 0.0464490	total: 2.84s	remaining: 697ms
# 803:	learn: 0.0464276	total: 2.85s	remaining: 694ms
# 804:	learn: 0.0463502	total: 2.85s	remaining: 690ms
# 805:	learn: 0.0462987	total: 2.85s	remaining: 687ms
# 806:	learn: 0.0462636	total: 2.85s	remaining: 683ms
# 807:	learn: 0.0462426	total: 2.86s	remaining: 679ms
# 808:	learn: 0.0461604	total: 2.86s	remaining: 676ms
# 809:	learn: 0.0461188	total: 2.87s	remaining: 672ms
# 810:	learn: 0.0460808	total: 2.87s	remaining: 669ms
# 811:	learn: 0.0460263	total: 2.87s	remaining: 665ms
# 812:	learn: 0.0459856	total: 2.87s	remaining: 661ms
# 813:	learn: 0.0459639	total: 2.88s	remaining: 658ms
# 814:	learn: 0.0459272	total: 2.88s	remaining: 654ms
# 815:	learn: 0.0459074	total: 2.88s	remaining: 650ms
# 816:	learn: 0.0458370	total: 2.89s	remaining: 647ms
# 817:	learn: 0.0458161	total: 2.89s	remaining: 643ms
# 818:	learn: 0.0457403	total: 2.89s	remaining: 639ms
# 819:	learn: 0.0457192	total: 2.9s	remaining: 636ms
# 820:	learn: 0.0456869	total: 2.9s	remaining: 632ms
# 821:	learn: 0.0456311	total: 2.9s	remaining: 629ms
# 822:	learn: 0.0455958	total: 2.9s	remaining: 625ms
# 823:	learn: 0.0455137	total: 2.91s	remaining: 621ms
# 824:	learn: 0.0454650	total: 2.91s	remaining: 618ms
# 825:	learn: 0.0454449	total: 2.92s	remaining: 614ms
# 826:	learn: 0.0454236	total: 2.92s	remaining: 610ms
# 827:	learn: 0.0453501	total: 2.92s	remaining: 607ms
# 828:	learn: 0.0453063	total: 2.92s	remaining: 603ms
# 829:	learn: 0.0452580	total: 2.93s	remaining: 600ms
# 830:	learn: 0.0452038	total: 2.93s	remaining: 596ms
# 831:	learn: 0.0451606	total: 2.93s	remaining: 593ms
# 832:	learn: 0.0451210	total: 2.94s	remaining: 589ms
# 833:	learn: 0.0450823	total: 2.94s	remaining: 585ms
# 834:	learn: 0.0450418	total: 2.94s	remaining: 582ms
# 835:	learn: 0.0449809	total: 2.95s	remaining: 578ms
# 836:	learn: 0.0449493	total: 2.95s	remaining: 574ms
# 837:	learn: 0.0449172	total: 2.95s	remaining: 571ms
# 838:	learn: 0.0448588	total: 2.96s	remaining: 567ms
# 839:	learn: 0.0448324	total: 2.96s	remaining: 564ms
# 840:	learn: 0.0447911	total: 2.96s	remaining: 560ms
# 841:	learn: 0.0447578	total: 2.96s	remaining: 556ms
# 842:	learn: 0.0446992	total: 2.97s	remaining: 553ms
# 843:	learn: 0.0446512	total: 2.97s	remaining: 549ms
# 844:	learn: 0.0446250	total: 2.97s	remaining: 545ms
# 845:	learn: 0.0445912	total: 2.98s	remaining: 542ms
# 846:	learn: 0.0445667	total: 2.98s	remaining: 538ms
# 847:	learn: 0.0445295	total: 2.98s	remaining: 535ms
# 848:	learn: 0.0444969	total: 2.98s	remaining: 531ms
# 849:	learn: 0.0444700	total: 2.99s	remaining: 527ms
# 850:	learn: 0.0444025	total: 2.99s	remaining: 524ms
# 851:	learn: 0.0443247	total: 3s	remaining: 520ms
# 852:	learn: 0.0443062	total: 3s	remaining: 517ms
# 853:	learn: 0.0442673	total: 3s	remaining: 513ms
# 854:	learn: 0.0442289	total: 3s	remaining: 510ms
# 855:	learn: 0.0441721	total: 3.01s	remaining: 506ms
# 856:	learn: 0.0441346	total: 3.01s	remaining: 502ms
# 857:	learn: 0.0440820	total: 3.01s	remaining: 499ms
# 858:	learn: 0.0440276	total: 3.02s	remaining: 495ms
# 859:	learn: 0.0439769	total: 3.02s	remaining: 492ms
# 860:	learn: 0.0439453	total: 3.02s	remaining: 488ms
# 861:	learn: 0.0438985	total: 3.03s	remaining: 485ms
# 862:	learn: 0.0438647	total: 3.03s	remaining: 481ms
# 863:	learn: 0.0438160	total: 3.03s	remaining: 478ms
# 864:	learn: 0.0437372	total: 3.04s	remaining: 474ms
# 865:	learn: 0.0436859	total: 3.04s	remaining: 471ms
# 866:	learn: 0.0436588	total: 3.04s	remaining: 467ms
# 867:	learn: 0.0436118	total: 3.05s	remaining: 464ms
# 868:	learn: 0.0435739	total: 3.05s	remaining: 460ms
# 869:	learn: 0.0434989	total: 3.06s	remaining: 457ms
# 870:	learn: 0.0434290	total: 3.06s	remaining: 453ms
# 871:	learn: 0.0433476	total: 3.06s	remaining: 450ms
# 872:	learn: 0.0433031	total: 3.07s	remaining: 446ms
# 873:	learn: 0.0432278	total: 3.07s	remaining: 443ms
# 874:	learn: 0.0432098	total: 3.07s	remaining: 439ms
# 875:	learn: 0.0431574	total: 3.08s	remaining: 436ms
# 876:	learn: 0.0431215	total: 3.08s	remaining: 432ms
# 877:	learn: 0.0430696	total: 3.08s	remaining: 429ms
# 878:	learn: 0.0430266	total: 3.09s	remaining: 425ms
# 879:	learn: 0.0429554	total: 3.09s	remaining: 422ms
# 880:	learn: 0.0429213	total: 3.1s	remaining: 419ms
# 881:	learn: 0.0428890	total: 3.1s	remaining: 415ms
# 882:	learn: 0.0428603	total: 3.11s	remaining: 412ms
# 883:	learn: 0.0428114	total: 3.11s	remaining: 408ms
# 884:	learn: 0.0427560	total: 3.11s	remaining: 405ms
# 885:	learn: 0.0427147	total: 3.12s	remaining: 401ms
# 886:	learn: 0.0426415	total: 3.12s	remaining: 398ms
# 887:	learn: 0.0426244	total: 3.13s	remaining: 394ms
# 888:	learn: 0.0425850	total: 3.13s	remaining: 391ms
# 889:	learn: 0.0425493	total: 3.13s	remaining: 387ms
# 890:	learn: 0.0425242	total: 3.14s	remaining: 384ms
# 891:	learn: 0.0424586	total: 3.14s	remaining: 380ms
# 892:	learn: 0.0423983	total: 3.14s	remaining: 377ms
# 893:	learn: 0.0423504	total: 3.15s	remaining: 373ms
# 894:	learn: 0.0423046	total: 3.15s	remaining: 370ms
# 895:	learn: 0.0422878	total: 3.15s	remaining: 366ms
# 896:	learn: 0.0422644	total: 3.16s	remaining: 362ms
# 897:	learn: 0.0422181	total: 3.16s	remaining: 359ms
# 898:	learn: 0.0421856	total: 3.16s	remaining: 355ms
# 899:	learn: 0.0421435	total: 3.17s	remaining: 352ms
# 900:	learn: 0.0421008	total: 3.17s	remaining: 348ms
# 901:	learn: 0.0420638	total: 3.17s	remaining: 345ms
# 902:	learn: 0.0420475	total: 3.18s	remaining: 341ms
# 903:	learn: 0.0419935	total: 3.18s	remaining: 338ms
# 904:	learn: 0.0419322	total: 3.18s	remaining: 334ms
# 905:	learn: 0.0418947	total: 3.19s	remaining: 331ms
# 906:	learn: 0.0418392	total: 3.19s	remaining: 327ms
# 907:	learn: 0.0418036	total: 3.19s	remaining: 324ms
# 908:	learn: 0.0417736	total: 3.2s	remaining: 320ms
# 909:	learn: 0.0417558	total: 3.2s	remaining: 316ms
# 910:	learn: 0.0417081	total: 3.2s	remaining: 313ms
# 911:	learn: 0.0416743	total: 3.21s	remaining: 309ms
# 912:	learn: 0.0416228	total: 3.21s	remaining: 306ms
# 913:	learn: 0.0415686	total: 3.21s	remaining: 302ms
# 914:	learn: 0.0415194	total: 3.22s	remaining: 299ms
# 915:	learn: 0.0414904	total: 3.22s	remaining: 295ms
# 916:	learn: 0.0414346	total: 3.22s	remaining: 292ms
# 917:	learn: 0.0413816	total: 3.23s	remaining: 288ms
# 918:	learn: 0.0413152	total: 3.23s	remaining: 285ms
# 919:	learn: 0.0412788	total: 3.23s	remaining: 281ms
# 920:	learn: 0.0412640	total: 3.23s	remaining: 277ms
# 921:	learn: 0.0412457	total: 3.24s	remaining: 274ms
# 922:	learn: 0.0412074	total: 3.24s	remaining: 270ms
# 923:	learn: 0.0411782	total: 3.24s	remaining: 267ms
# 924:	learn: 0.0411440	total: 3.25s	remaining: 263ms
# 925:	learn: 0.0410790	total: 3.25s	remaining: 260ms
# 926:	learn: 0.0410566	total: 3.25s	remaining: 256ms
# 927:	learn: 0.0410239	total: 3.26s	remaining: 253ms
# 928:	learn: 0.0409913	total: 3.26s	remaining: 249ms
# 929:	learn: 0.0409608	total: 3.26s	remaining: 246ms
# 930:	learn: 0.0409101	total: 3.27s	remaining: 242ms
# 931:	learn: 0.0408354	total: 3.27s	remaining: 239ms
# 932:	learn: 0.0407847	total: 3.27s	remaining: 235ms
# 933:	learn: 0.0407334	total: 3.28s	remaining: 232ms
# 934:	learn: 0.0407058	total: 3.28s	remaining: 228ms
# 935:	learn: 0.0406839	total: 3.28s	remaining: 224ms
# 936:	learn: 0.0406671	total: 3.29s	remaining: 221ms
# 937:	learn: 0.0406469	total: 3.29s	remaining: 217ms
# 938:	learn: 0.0405962	total: 3.29s	remaining: 214ms
# 939:	learn: 0.0405412	total: 3.29s	remaining: 210ms
# 940:	learn: 0.0405009	total: 3.3s	remaining: 207ms
# 941:	learn: 0.0404513	total: 3.3s	remaining: 203ms
# 942:	learn: 0.0403988	total: 3.31s	remaining: 200ms
# 943:	learn: 0.0403758	total: 3.31s	remaining: 196ms
# 944:	learn: 0.0403557	total: 3.31s	remaining: 193ms
# 945:	learn: 0.0403007	total: 3.32s	remaining: 189ms
# 946:	learn: 0.0402335	total: 3.32s	remaining: 186ms
# 947:	learn: 0.0401871	total: 3.32s	remaining: 182ms
# 948:	learn: 0.0401661	total: 3.33s	remaining: 179ms
# 949:	learn: 0.0401279	total: 3.33s	remaining: 175ms
# 950:	learn: 0.0401027	total: 3.33s	remaining: 172ms
# 951:	learn: 0.0400691	total: 3.34s	remaining: 168ms
# 952:	learn: 0.0400297	total: 3.34s	remaining: 165ms
# 953:	learn: 0.0400134	total: 3.34s	remaining: 161ms
# 954:	learn: 0.0399969	total: 3.35s	remaining: 158ms
# 955:	learn: 0.0399726	total: 3.35s	remaining: 154ms
# 956:	learn: 0.0399508	total: 3.35s	remaining: 151ms
# 957:	learn: 0.0399183	total: 3.36s	remaining: 147ms
# 958:	learn: 0.0398515	total: 3.36s	remaining: 144ms
# 959:	learn: 0.0398140	total: 3.36s	remaining: 140ms
# 960:	learn: 0.0397765	total: 3.37s	remaining: 137ms
# 961:	learn: 0.0397341	total: 3.37s	remaining: 133ms
# 962:	learn: 0.0396860	total: 3.38s	remaining: 130ms
# 963:	learn: 0.0396484	total: 3.38s	remaining: 126ms
# 964:	learn: 0.0396225	total: 3.38s	remaining: 123ms
# 965:	learn: 0.0396070	total: 3.38s	remaining: 119ms
# 966:	learn: 0.0395743	total: 3.39s	remaining: 116ms
# 967:	learn: 0.0395608	total: 3.4s	remaining: 112ms
# 968:	learn: 0.0395256	total: 3.4s	remaining: 109ms
# 969:	learn: 0.0394893	total: 3.41s	remaining: 105ms
# 970:	learn: 0.0394294	total: 3.41s	remaining: 102ms
# 971:	learn: 0.0393967	total: 3.42s	remaining: 98.4ms
# 972:	learn: 0.0393817	total: 3.42s	remaining: 94.9ms
# 973:	learn: 0.0393494	total: 3.42s	remaining: 91.4ms
# 974:	learn: 0.0393084	total: 3.43s	remaining: 87.9ms
# 975:	learn: 0.0392839	total: 3.43s	remaining: 84.4ms
# 976:	learn: 0.0392530	total: 3.44s	remaining: 81ms
# 977:	learn: 0.0392366	total: 3.44s	remaining: 77.5ms
# 978:	learn: 0.0392050	total: 3.45s	remaining: 73.9ms
# 979:	learn: 0.0391793	total: 3.46s	remaining: 70.5ms
# 980:	learn: 0.0391167	total: 3.46s	remaining: 67ms
# 981:	learn: 0.0390869	total: 3.46s	remaining: 63.5ms
# 982:	learn: 0.0390498	total: 3.47s	remaining: 60ms
# 983:	learn: 0.0390200	total: 3.47s	remaining: 56.5ms
# 984:	learn: 0.0389964	total: 3.48s	remaining: 53ms
# 985:	learn: 0.0389089	total: 3.48s	remaining: 49.5ms
# 986:	learn: 0.0388631	total: 3.49s	remaining: 45.9ms
# 987:	learn: 0.0388174	total: 3.5s	remaining: 42.5ms
# 988:	learn: 0.0387733	total: 3.5s	remaining: 38.9ms
# 989:	learn: 0.0387536	total: 3.51s	remaining: 35.4ms
# 990:	learn: 0.0387311	total: 3.51s	remaining: 31.9ms
# 991:	learn: 0.0386649	total: 3.51s	remaining: 28.3ms
# 992:	learn: 0.0386520	total: 3.52s	remaining: 24.8ms
# 993:	learn: 0.0386084	total: 3.52s	remaining: 21.3ms
# 994:	learn: 0.0385773	total: 3.53s	remaining: 17.7ms
# 995:	learn: 0.0384755	total: 3.53s	remaining: 14.2ms
# 996:	learn: 0.0384516	total: 3.54s	remaining: 10.6ms
# 997:	learn: 0.0384103	total: 3.54s	remaining: 7.1ms
# 998:	learn: 0.0383887	total: 3.55s	remaining: 3.55ms
# 999:	learn: 0.0383587	total: 3.55s	remaining: 0us
# CatBoost Model - Cross-Validation Scores:
# CV Mean Accuracy: 0.973
# CV Standard Deviation: 0.039
# ================================================================================
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97      1444
#            1       0.29      0.08      0.12        89
#
#     accuracy                           0.94      1533
#    macro avg       0.62      0.53      0.55      1533
# weighted avg       0.91      0.94      0.92      1533

# %%
disp = ConfusionMatrixDisplay(confusion_matrix(y_test, cat.predict(X_test)), display_labels=[0, 1])
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.show()

# %%
y_prob = cat.predict_proba(X_test)

roc_auc = roc_auc_score(y_test, y_prob[:, 1])

fpr = {}
tpr = {}
thresholds = {}

for i in range(len(cat.classes_)):
	fpr[i], tpr[i], thresholds[i] = roc_curve(y_test, y_prob[:, i], pos_label=i)

plt.figure()
for i in range(len(cat.classes_)):
	plt.plot(fpr[i], tpr[i], lw=2, label=f'Class {i} (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc='lower right')
plt.show()

print(f"AUC: {roc_auc:.2f}")
# Out:
# AUC: 0.79

# %%
cat_param_grid = {
    'learning_rate': [0.01, 0.03, 0.1],
    'depth': [4, 6, 8],
    'l2_leaf_reg': [1, 3, 5],
    'iterations': [100, 200, 300]
}

cat_grid_search = GridSearchCV(cat, cat_param_grid, cv=5, scoring='accuracy', n_jobs=-1)
cat_grid_search.fit(X_train, y_train)
print("Best Hyperparameters for CatBoost:")
table_hyperparams = PrettyTable()
table_hyperparams.field_names = ["Parameter", "Value"]
for param, value in cat_grid_search.best_params_.items():
    table_hyperparams.add_row([param, value])
print(table_hyperparams)
print("Best Accuracy for CatBoost: {:.4f}".format(cat_grid_search.best_score_))
# Out:
# 0:	learn: 0.6249861	total: 4.44ms	remaining: 884ms
# 1:	learn: 0.5859397	total: 9.62ms	remaining: 953ms
# 2:	learn: 0.5436326	total: 14.5ms	remaining: 950ms
# 3:	learn: 0.5017750	total: 19.5ms	remaining: 955ms
# 4:	learn: 0.4756945	total: 25.4ms	remaining: 991ms
# 5:	learn: 0.4407662	total: 31.2ms	remaining: 1.01s
# 6:	learn: 0.4161421	total: 36.8ms	remaining: 1.01s
# 7:	learn: 0.3883000	total: 42.2ms	remaining: 1.01s
# 8:	learn: 0.3585659	total: 47.9ms	remaining: 1.01s
# 9:	learn: 0.3373506	total: 53.6ms	remaining: 1.02s
# 10:	learn: 0.3223723	total: 59.5ms	remaining: 1.02s
# 11:	learn: 0.3033354	total: 65.8ms	remaining: 1.03s
# 12:	learn: 0.2870536	total: 71.9ms	remaining: 1.03s
# 13:	learn: 0.2752637	total: 78.2ms	remaining: 1.04s
# 14:	learn: 0.2592085	total: 84ms	remaining: 1.03s
# 15:	learn: 0.2483368	total: 90ms	remaining: 1.03s
# 16:	learn: 0.2357944	total: 95.7ms	remaining: 1.03s
# 17:	learn: 0.2272054	total: 102ms	remaining: 1.03s
# 18:	learn: 0.2192921	total: 108ms	remaining: 1.03s
# 19:	learn: 0.2133236	total: 114ms	remaining: 1.03s
# 20:	learn: 0.2060607	total: 120ms	remaining: 1.02s
# 21:	learn: 0.1998754	total: 126ms	remaining: 1.02s
# 22:	learn: 0.1919343	total: 133ms	remaining: 1.02s
# 23:	learn: 0.1868055	total: 139ms	remaining: 1.02s
# 24:	learn: 0.1811604	total: 146ms	remaining: 1.02s
# 25:	learn: 0.1767446	total: 152ms	remaining: 1.01s
# 26:	learn: 0.1724274	total: 157ms	remaining: 1.01s
# 27:	learn: 0.1693653	total: 163ms	remaining: 1s
# 28:	learn: 0.1637759	total: 169ms	remaining: 996ms
# 29:	learn: 0.1607749	total: 175ms	remaining: 992ms
# 30:	learn: 0.1571443	total: 181ms	remaining: 989ms
# 31:	learn: 0.1556428	total: 187ms	remaining: 983ms
# 32:	learn: 0.1524808	total: 193ms	remaining: 976ms
# 33:	learn: 0.1496824	total: 199ms	remaining: 972ms
# 34:	learn: 0.1452769	total: 205ms	remaining: 968ms
# 35:	learn: 0.1424357	total: 212ms	remaining: 965ms
# 36:	learn: 0.1398846	total: 219ms	remaining: 963ms
# 37:	learn: 0.1371773	total: 225ms	remaining: 961ms
# 38:	learn: 0.1344864	total: 232ms	remaining: 956ms
# 39:	learn: 0.1327540	total: 238ms	remaining: 953ms
# 40:	learn: 0.1311765	total: 245ms	remaining: 950ms
# 41:	learn: 0.1284806	total: 251ms	remaining: 945ms
# 42:	learn: 0.1270643	total: 258ms	remaining: 943ms
# 43:	learn: 0.1253114	total: 266ms	remaining: 942ms
# 44:	learn: 0.1242416	total: 272ms	remaining: 937ms
# 45:	learn: 0.1230749	total: 278ms	remaining: 931ms
# 46:	learn: 0.1216725	total: 284ms	remaining: 925ms
# 47:	learn: 0.1193383	total: 291ms	remaining: 922ms
# 48:	learn: 0.1176451	total: 297ms	remaining: 916ms
# 49:	learn: 0.1161470	total: 303ms	remaining: 910ms
# 50:	learn: 0.1151486	total: 309ms	remaining: 903ms
# 51:	learn: 0.1140345	total: 315ms	remaining: 897ms
# 52:	learn: 0.1125279	total: 321ms	remaining: 891ms
# 53:	learn: 0.1109214	total: 328ms	remaining: 886ms
# 54:	learn: 0.1103881	total: 334ms	remaining: 881ms
# 55:	learn: 0.1094737	total: 340ms	remaining: 874ms
# 56:	learn: 0.1087355	total: 346ms	remaining: 868ms
# 57:	learn: 0.1075537	total: 352ms	remaining: 862ms
# 58:	learn: 0.1069105	total: 358ms	remaining: 856ms
# 59:	learn: 0.1055677	total: 364ms	remaining: 848ms
# 60:	learn: 0.1044330	total: 369ms	remaining: 841ms
# 61:	learn: 0.1034934	total: 375ms	remaining: 835ms
# 62:	learn: 0.1025751	total: 381ms	remaining: 828ms
# 63:	learn: 0.1020532	total: 387ms	remaining: 822ms
# 64:	learn: 0.1014431	total: 393ms	remaining: 817ms
# 65:	learn: 0.1007178	total: 400ms	remaining: 812ms
# 66:	learn: 0.0999794	total: 407ms	remaining: 807ms
# 67:	learn: 0.0992379	total: 413ms	remaining: 802ms
# 68:	learn: 0.0979743	total: 419ms	remaining: 796ms
# 69:	learn: 0.0969758	total: 426ms	remaining: 791ms
# 70:	learn: 0.0961107	total: 432ms	remaining: 785ms
# 71:	learn: 0.0953574	total: 438ms	remaining: 779ms
# 72:	learn: 0.0946069	total: 445ms	remaining: 774ms
# 73:	learn: 0.0940243	total: 451ms	remaining: 768ms
# 74:	learn: 0.0933533	total: 457ms	remaining: 762ms
# 75:	learn: 0.0926157	total: 463ms	remaining: 756ms
# 76:	learn: 0.0917329	total: 469ms	remaining: 749ms
# 77:	learn: 0.0906583	total: 475ms	remaining: 744ms
# 78:	learn: 0.0899010	total: 482ms	remaining: 738ms
# 79:	learn: 0.0892595	total: 487ms	remaining: 731ms
# 80:	learn: 0.0887620	total: 494ms	remaining: 725ms
# 81:	learn: 0.0883506	total: 500ms	remaining: 720ms
# 82:	learn: 0.0875770	total: 507ms	remaining: 714ms
# 83:	learn: 0.0868844	total: 513ms	remaining: 709ms
# 84:	learn: 0.0861591	total: 520ms	remaining: 703ms
# 85:	learn: 0.0857406	total: 526ms	remaining: 698ms
# 86:	learn: 0.0849806	total: 533ms	remaining: 692ms
# 87:	learn: 0.0845547	total: 540ms	remaining: 687ms
# 88:	learn: 0.0841921	total: 546ms	remaining: 681ms
# 89:	learn: 0.0841542	total: 549ms	remaining: 671ms
# 90:	learn: 0.0834875	total: 555ms	remaining: 665ms
# 91:	learn: 0.0828522	total: 562ms	remaining: 659ms
# 92:	learn: 0.0824229	total: 568ms	remaining: 654ms
# 93:	learn: 0.0820539	total: 575ms	remaining: 648ms
# 94:	learn: 0.0813074	total: 581ms	remaining: 642ms
# 95:	learn: 0.0809522	total: 588ms	remaining: 637ms
# 96:	learn: 0.0803401	total: 594ms	remaining: 631ms
# 97:	learn: 0.0796234	total: 601ms	remaining: 625ms
# 98:	learn: 0.0791130	total: 607ms	remaining: 619ms
# 99:	learn: 0.0786866	total: 613ms	remaining: 613ms
# 100:	learn: 0.0783062	total: 620ms	remaining: 607ms
# 101:	learn: 0.0779872	total: 626ms	remaining: 601ms
# 102:	learn: 0.0773986	total: 632ms	remaining: 596ms
# 103:	learn: 0.0769561	total: 638ms	remaining: 589ms
# 104:	learn: 0.0764972	total: 644ms	remaining: 583ms
# 105:	learn: 0.0760253	total: 651ms	remaining: 577ms
# 106:	learn: 0.0755111	total: 657ms	remaining: 571ms
# 107:	learn: 0.0751458	total: 664ms	remaining: 565ms
# 108:	learn: 0.0748552	total: 670ms	remaining: 559ms
# 109:	learn: 0.0743164	total: 676ms	remaining: 553ms
# 110:	learn: 0.0740277	total: 683ms	remaining: 548ms
# 111:	learn: 0.0738686	total: 689ms	remaining: 541ms
# 112:	learn: 0.0734800	total: 696ms	remaining: 536ms
# 113:	learn: 0.0732073	total: 702ms	remaining: 530ms
# 114:	learn: 0.0726969	total: 709ms	remaining: 524ms
# 115:	learn: 0.0723272	total: 715ms	remaining: 517ms
# 116:	learn: 0.0719555	total: 721ms	remaining: 511ms
# 117:	learn: 0.0714760	total: 727ms	remaining: 505ms
# 118:	learn: 0.0709154	total: 733ms	remaining: 499ms
# 119:	learn: 0.0705680	total: 739ms	remaining: 493ms
# 120:	learn: 0.0701905	total: 746ms	remaining: 487ms
# 121:	learn: 0.0698172	total: 752ms	remaining: 481ms
# 122:	learn: 0.0694792	total: 758ms	remaining: 475ms
# 123:	learn: 0.0689860	total: 764ms	remaining: 468ms
# 124:	learn: 0.0685494	total: 770ms	remaining: 462ms
# 125:	learn: 0.0679547	total: 776ms	remaining: 456ms
# 126:	learn: 0.0676415	total: 782ms	remaining: 450ms
# 127:	learn: 0.0673863	total: 788ms	remaining: 443ms
# 128:	learn: 0.0670354	total: 794ms	remaining: 437ms
# 129:	learn: 0.0665996	total: 800ms	remaining: 431ms
# 130:	learn: 0.0661954	total: 806ms	remaining: 424ms
# 131:	learn: 0.0660623	total: 811ms	remaining: 418ms
# 132:	learn: 0.0656939	total: 817ms	remaining: 412ms
# 133:	learn: 0.0653901	total: 823ms	remaining: 405ms
# 134:	learn: 0.0652021	total: 828ms	remaining: 399ms
# 135:	learn: 0.0647884	total: 834ms	remaining: 392ms
# 136:	learn: 0.0645133	total: 840ms	remaining: 386ms
# 137:	learn: 0.0642220	total: 846ms	remaining: 380ms
# 138:	learn: 0.0639144	total: 852ms	remaining: 374ms
# 139:	learn: 0.0636036	total: 858ms	remaining: 368ms
# 140:	learn: 0.0632466	total: 864ms	remaining: 361ms
# 141:	learn: 0.0627001	total: 870ms	remaining: 355ms
# 142:	learn: 0.0624404	total: 876ms	remaining: 349ms
# 143:	learn: 0.0620806	total: 881ms	remaining: 343ms
# 144:	learn: 0.0617897	total: 887ms	remaining: 336ms
# 145:	learn: 0.0615872	total: 893ms	remaining: 330ms
# 146:	learn: 0.0610810	total: 899ms	remaining: 324ms
# 147:	learn: 0.0606111	total: 905ms	remaining: 318ms
# 148:	learn: 0.0603899	total: 910ms	remaining: 312ms
# 149:	learn: 0.0601611	total: 916ms	remaining: 305ms
# 150:	learn: 0.0599940	total: 922ms	remaining: 299ms
# 151:	learn: 0.0597230	total: 928ms	remaining: 293ms
# 152:	learn: 0.0594490	total: 933ms	remaining: 287ms
# 153:	learn: 0.0591920	total: 939ms	remaining: 281ms
# 154:	learn: 0.0589347	total: 948ms	remaining: 275ms
# 155:	learn: 0.0586486	total: 954ms	remaining: 269ms
# 156:	learn: 0.0584018	total: 964ms	remaining: 264ms
# 157:	learn: 0.0580593	total: 971ms	remaining: 258ms
# 158:	learn: 0.0578172	total: 978ms	remaining: 252ms
# 159:	learn: 0.0575606	total: 985ms	remaining: 246ms
# 160:	learn: 0.0572557	total: 996ms	remaining: 241ms
# 161:	learn: 0.0570641	total: 1s	remaining: 235ms
# 162:	learn: 0.0568337	total: 1.01s	remaining: 230ms
# 163:	learn: 0.0566303	total: 1.02s	remaining: 224ms
# 164:	learn: 0.0563666	total: 1.03s	remaining: 218ms
# 165:	learn: 0.0560885	total: 1.03s	remaining: 212ms
# 166:	learn: 0.0559568	total: 1.04s	remaining: 207ms
# 167:	learn: 0.0556659	total: 1.06s	remaining: 202ms
# 168:	learn: 0.0554550	total: 1.07s	remaining: 196ms
# 169:	learn: 0.0551975	total: 1.08s	remaining: 190ms
# 170:	learn: 0.0549081	total: 1.09s	remaining: 184ms
# 171:	learn: 0.0547774	total: 1.1s	remaining: 179ms
# 172:	learn: 0.0544067	total: 1.11s	remaining: 173ms
# 173:	learn: 0.0541466	total: 1.12s	remaining: 167ms
# 174:	learn: 0.0538124	total: 1.13s	remaining: 161ms
# 175:	learn: 0.0535658	total: 1.13s	remaining: 155ms
# 176:	learn: 0.0532283	total: 1.14s	remaining: 148ms
# 177:	learn: 0.0529736	total: 1.15s	remaining: 142ms
# 178:	learn: 0.0527051	total: 1.15s	remaining: 135ms
# 179:	learn: 0.0524804	total: 1.16s	remaining: 129ms
# 180:	learn: 0.0522802	total: 1.16s	remaining: 122ms
# 181:	learn: 0.0519634	total: 1.17s	remaining: 116ms
# 182:	learn: 0.0516115	total: 1.18s	remaining: 109ms
# 183:	learn: 0.0514337	total: 1.18s	remaining: 103ms
# 184:	learn: 0.0510213	total: 1.19s	remaining: 96.3ms
# 185:	learn: 0.0507925	total: 1.19s	remaining: 89.9ms
# 186:	learn: 0.0506293	total: 1.2s	remaining: 83.4ms
# 187:	learn: 0.0504526	total: 1.2s	remaining: 76.9ms
# 188:	learn: 0.0502671	total: 1.21s	remaining: 70.5ms
# 189:	learn: 0.0500859	total: 1.22s	remaining: 64ms
# 190:	learn: 0.0497550	total: 1.22s	remaining: 57.6ms
# 191:	learn: 0.0495427	total: 1.23s	remaining: 51.1ms
# 192:	learn: 0.0493681	total: 1.23s	remaining: 44.7ms
# 193:	learn: 0.0491779	total: 1.24s	remaining: 38.3ms
# 194:	learn: 0.0490201	total: 1.25s	remaining: 31.9ms
# 195:	learn: 0.0487761	total: 1.25s	remaining: 25.5ms
# 196:	learn: 0.0485867	total: 1.26s	remaining: 19.2ms
# 197:	learn: 0.0483951	total: 1.26s	remaining: 12.8ms
# 198:	learn: 0.0481015	total: 1.27s	remaining: 6.38ms
# 199:	learn: 0.0478362	total: 1.28s	remaining: 0us
# Best Hyperparameters for CatBoost:
# +---------------+-------+
# |   Parameter   | Value |
# +---------------+-------+
# |     depth     |   8   |
# |   iterations  |  200  |
# |  l2_leaf_reg  |   1   |
# | learning_rate |  0.03 |
# +---------------+-------+
# Best Accuracy for CatBoost: 0.9737

# %%
best_cat_model = CatBoostClassifier(**cat_grid_search.best_params_)
best_cat_model.fit(X_train, y_train)
y_test_pred = best_cat_model.predict(X_test)
test_accuracy = accuracy_score(y_test, y_test_pred)
test_precision = precision_score(y_test, y_test_pred)
test_recall = recall_score(y_test, y_test_pred)
test_f1 = f1_score(y_test, y_test_pred)
test_auc = roc_auc_score(y_test, y_test_pred)
print("Best CatBoost Model - Testing Metrics:")

table_testing = PrettyTable()
table_testing.field_names = ["Metric", "Value"]
table_testing.add_row(["Accuracy", round(test_accuracy, 3)])
table_testing.add_row(["Precision", round(test_precision, 3)])
table_testing.add_row(["Recall", round(test_recall, 3)])
table_testing.add_row(["F1 Score", round(test_f1, 3)])
table_testing.add_row(["AUC", round(test_auc, 3)])
print(table_testing)
# Out:
# 0:	learn: 0.6249861	total: 5.32ms	remaining: 1.06s
# 1:	learn: 0.5859397	total: 11ms	remaining: 1.09s
# 2:	learn: 0.5436326	total: 17.8ms	remaining: 1.17s
# 3:	learn: 0.5017750	total: 23.6ms	remaining: 1.16s
# 4:	learn: 0.4756945	total: 29.6ms	remaining: 1.15s
# 5:	learn: 0.4407662	total: 35.9ms	remaining: 1.16s
# 6:	learn: 0.4161421	total: 42.7ms	remaining: 1.18s
# 7:	learn: 0.3883000	total: 50.5ms	remaining: 1.21s
# 8:	learn: 0.3585659	total: 57.4ms	remaining: 1.22s
# 9:	learn: 0.3373506	total: 64.2ms	remaining: 1.22s
# 10:	learn: 0.3223723	total: 70.8ms	remaining: 1.22s
# 11:	learn: 0.3033354	total: 77.4ms	remaining: 1.21s
# 12:	learn: 0.2870536	total: 83.5ms	remaining: 1.2s
# 13:	learn: 0.2752637	total: 89.7ms	remaining: 1.19s
# 14:	learn: 0.2592085	total: 95.6ms	remaining: 1.18s
# 15:	learn: 0.2483368	total: 102ms	remaining: 1.17s
# 16:	learn: 0.2357944	total: 108ms	remaining: 1.17s
# 17:	learn: 0.2272054	total: 114ms	remaining: 1.16s
# 18:	learn: 0.2192921	total: 120ms	remaining: 1.14s
# 19:	learn: 0.2133236	total: 126ms	remaining: 1.14s
# 20:	learn: 0.2060607	total: 132ms	remaining: 1.12s
# 21:	learn: 0.1998754	total: 138ms	remaining: 1.11s
# 22:	learn: 0.1919343	total: 144ms	remaining: 1.1s
# 23:	learn: 0.1868055	total: 149ms	remaining: 1.09s
# 24:	learn: 0.1811604	total: 155ms	remaining: 1.08s
# 25:	learn: 0.1767446	total: 160ms	remaining: 1.07s
# 26:	learn: 0.1724274	total: 167ms	remaining: 1.07s
# 27:	learn: 0.1693653	total: 172ms	remaining: 1.06s
# 28:	learn: 0.1637759	total: 178ms	remaining: 1.05s
# 29:	learn: 0.1607749	total: 184ms	remaining: 1.04s
# 30:	learn: 0.1571443	total: 190ms	remaining: 1.03s
# 31:	learn: 0.1556428	total: 195ms	remaining: 1.02s
# 32:	learn: 0.1524808	total: 201ms	remaining: 1.01s
# 33:	learn: 0.1496824	total: 206ms	remaining: 1s
# 34:	learn: 0.1452769	total: 212ms	remaining: 998ms
# 35:	learn: 0.1424357	total: 218ms	remaining: 994ms
# 36:	learn: 0.1398846	total: 224ms	remaining: 986ms
# 37:	learn: 0.1371773	total: 230ms	remaining: 980ms
# 38:	learn: 0.1344864	total: 236ms	remaining: 973ms
# 39:	learn: 0.1327540	total: 241ms	remaining: 965ms
# 40:	learn: 0.1311765	total: 247ms	remaining: 960ms
# 41:	learn: 0.1284806	total: 253ms	remaining: 953ms
# 42:	learn: 0.1270643	total: 259ms	remaining: 947ms
# 43:	learn: 0.1253114	total: 265ms	remaining: 939ms
# 44:	learn: 0.1242416	total: 271ms	remaining: 932ms
# 45:	learn: 0.1230749	total: 276ms	remaining: 924ms
# 46:	learn: 0.1216725	total: 282ms	remaining: 917ms
# 47:	learn: 0.1193383	total: 288ms	remaining: 911ms
# 48:	learn: 0.1176451	total: 293ms	remaining: 904ms
# 49:	learn: 0.1161470	total: 299ms	remaining: 898ms
# 50:	learn: 0.1151486	total: 305ms	remaining: 892ms
# 51:	learn: 0.1140345	total: 311ms	remaining: 885ms
# 52:	learn: 0.1125279	total: 317ms	remaining: 879ms
# 53:	learn: 0.1109214	total: 323ms	remaining: 874ms
# 54:	learn: 0.1103881	total: 329ms	remaining: 868ms
# 55:	learn: 0.1094737	total: 335ms	remaining: 861ms
# 56:	learn: 0.1087355	total: 341ms	remaining: 855ms
# 57:	learn: 0.1075537	total: 346ms	remaining: 848ms
# 58:	learn: 0.1069105	total: 352ms	remaining: 841ms
# 59:	learn: 0.1055677	total: 358ms	remaining: 836ms
# 60:	learn: 0.1044330	total: 365ms	remaining: 831ms
# 61:	learn: 0.1034934	total: 371ms	remaining: 826ms
# 62:	learn: 0.1025751	total: 377ms	remaining: 820ms
# 63:	learn: 0.1020532	total: 383ms	remaining: 815ms
# 64:	learn: 0.1014431	total: 390ms	remaining: 809ms
# 65:	learn: 0.1007178	total: 396ms	remaining: 804ms
# 66:	learn: 0.0999794	total: 402ms	remaining: 798ms
# 67:	learn: 0.0992379	total: 408ms	remaining: 792ms
# 68:	learn: 0.0979743	total: 415ms	remaining: 787ms
# 69:	learn: 0.0969758	total: 421ms	remaining: 782ms
# 70:	learn: 0.0961107	total: 427ms	remaining: 777ms
# 71:	learn: 0.0953574	total: 434ms	remaining: 772ms
# 72:	learn: 0.0946069	total: 441ms	remaining: 767ms
# 73:	learn: 0.0940243	total: 447ms	remaining: 762ms
# 74:	learn: 0.0933533	total: 454ms	remaining: 756ms
# 75:	learn: 0.0926157	total: 460ms	remaining: 751ms
# 76:	learn: 0.0917329	total: 466ms	remaining: 745ms
# 77:	learn: 0.0906583	total: 472ms	remaining: 739ms
# 78:	learn: 0.0899010	total: 478ms	remaining: 733ms
# 79:	learn: 0.0892595	total: 485ms	remaining: 727ms
# 80:	learn: 0.0887620	total: 491ms	remaining: 721ms
# 81:	learn: 0.0883506	total: 497ms	remaining: 715ms
# 82:	learn: 0.0875770	total: 503ms	remaining: 710ms
# 83:	learn: 0.0868844	total: 510ms	remaining: 704ms
# 84:	learn: 0.0861591	total: 517ms	remaining: 699ms
# 85:	learn: 0.0857406	total: 523ms	remaining: 693ms
# 86:	learn: 0.0849806	total: 529ms	remaining: 687ms
# 87:	learn: 0.0845547	total: 536ms	remaining: 682ms
# 88:	learn: 0.0841921	total: 542ms	remaining: 675ms
# 89:	learn: 0.0841542	total: 545ms	remaining: 666ms
# 90:	learn: 0.0834875	total: 551ms	remaining: 660ms
# 91:	learn: 0.0828522	total: 558ms	remaining: 655ms
# 92:	learn: 0.0824229	total: 564ms	remaining: 649ms
# 93:	learn: 0.0820539	total: 570ms	remaining: 643ms
# 94:	learn: 0.0813074	total: 577ms	remaining: 637ms
# 95:	learn: 0.0809522	total: 583ms	remaining: 632ms
# 96:	learn: 0.0803401	total: 590ms	remaining: 627ms
# 97:	learn: 0.0796234	total: 598ms	remaining: 622ms
# 98:	learn: 0.0791130	total: 605ms	remaining: 617ms
# 99:	learn: 0.0786866	total: 613ms	remaining: 613ms
# 100:	learn: 0.0783062	total: 619ms	remaining: 607ms
# 101:	learn: 0.0779872	total: 626ms	remaining: 601ms
# 102:	learn: 0.0773986	total: 634ms	remaining: 597ms
# 103:	learn: 0.0769561	total: 641ms	remaining: 591ms
# 104:	learn: 0.0764972	total: 648ms	remaining: 586ms
# 105:	learn: 0.0760253	total: 654ms	remaining: 580ms
# 106:	learn: 0.0755111	total: 661ms	remaining: 574ms
# 107:	learn: 0.0751458	total: 668ms	remaining: 569ms
# 108:	learn: 0.0748552	total: 675ms	remaining: 564ms
# 109:	learn: 0.0743164	total: 682ms	remaining: 558ms
# 110:	learn: 0.0740277	total: 688ms	remaining: 552ms
# 111:	learn: 0.0738686	total: 694ms	remaining: 546ms
# 112:	learn: 0.0734800	total: 701ms	remaining: 540ms
# 113:	learn: 0.0732073	total: 709ms	remaining: 535ms
# 114:	learn: 0.0726969	total: 716ms	remaining: 529ms
# 115:	learn: 0.0723272	total: 722ms	remaining: 523ms
# 116:	learn: 0.0719555	total: 729ms	remaining: 517ms
# 117:	learn: 0.0714760	total: 737ms	remaining: 512ms
# 118:	learn: 0.0709154	total: 743ms	remaining: 506ms
# 119:	learn: 0.0705680	total: 751ms	remaining: 500ms
# 120:	learn: 0.0701905	total: 759ms	remaining: 495ms
# 121:	learn: 0.0698172	total: 770ms	remaining: 493ms
# 122:	learn: 0.0694792	total: 782ms	remaining: 490ms
# 123:	learn: 0.0689860	total: 792ms	remaining: 485ms
# 124:	learn: 0.0685494	total: 800ms	remaining: 480ms
# 125:	learn: 0.0679547	total: 816ms	remaining: 479ms
# 126:	learn: 0.0676415	total: 832ms	remaining: 478ms
# 127:	learn: 0.0673863	total: 839ms	remaining: 472ms
# 128:	learn: 0.0670354	total: 853ms	remaining: 470ms
# 129:	learn: 0.0665996	total: 860ms	remaining: 463ms
# 130:	learn: 0.0661954	total: 876ms	remaining: 462ms
# 131:	learn: 0.0660623	total: 884ms	remaining: 455ms
# 132:	learn: 0.0656939	total: 890ms	remaining: 448ms
# 133:	learn: 0.0653901	total: 898ms	remaining: 442ms
# 134:	learn: 0.0652021	total: 905ms	remaining: 436ms
# 135:	learn: 0.0647884	total: 914ms	remaining: 430ms
# 136:	learn: 0.0645133	total: 921ms	remaining: 424ms
# 137:	learn: 0.0642220	total: 931ms	remaining: 418ms
# 138:	learn: 0.0639144	total: 939ms	remaining: 412ms
# 139:	learn: 0.0636036	total: 945ms	remaining: 405ms
# 140:	learn: 0.0632466	total: 951ms	remaining: 398ms
# 141:	learn: 0.0627001	total: 957ms	remaining: 391ms
# 142:	learn: 0.0624404	total: 963ms	remaining: 384ms
# 143:	learn: 0.0620806	total: 970ms	remaining: 377ms
# 144:	learn: 0.0617897	total: 976ms	remaining: 370ms
# 145:	learn: 0.0615872	total: 982ms	remaining: 363ms
# 146:	learn: 0.0610810	total: 988ms	remaining: 356ms
# 147:	learn: 0.0606111	total: 995ms	remaining: 349ms
# 148:	learn: 0.0603899	total: 1s	remaining: 343ms
# 149:	learn: 0.0601611	total: 1.01s	remaining: 336ms
# 150:	learn: 0.0599940	total: 1.01s	remaining: 329ms
# 151:	learn: 0.0597230	total: 1.02s	remaining: 322ms
# 152:	learn: 0.0594490	total: 1.02s	remaining: 315ms
# 153:	learn: 0.0591920	total: 1.03s	remaining: 308ms
# 154:	learn: 0.0589347	total: 1.04s	remaining: 301ms
# 155:	learn: 0.0586486	total: 1.04s	remaining: 295ms
# 156:	learn: 0.0584018	total: 1.05s	remaining: 288ms
# 157:	learn: 0.0580593	total: 1.06s	remaining: 281ms
# 158:	learn: 0.0578172	total: 1.06s	remaining: 274ms
# 159:	learn: 0.0575606	total: 1.07s	remaining: 267ms
# 160:	learn: 0.0572557	total: 1.07s	remaining: 260ms
# 161:	learn: 0.0570641	total: 1.08s	remaining: 253ms
# 162:	learn: 0.0568337	total: 1.09s	remaining: 247ms
# 163:	learn: 0.0566303	total: 1.09s	remaining: 240ms
# 164:	learn: 0.0563666	total: 1.1s	remaining: 233ms
# 165:	learn: 0.0560885	total: 1.1s	remaining: 226ms
# 166:	learn: 0.0559568	total: 1.11s	remaining: 219ms
# 167:	learn: 0.0556659	total: 1.12s	remaining: 213ms
# 168:	learn: 0.0554550	total: 1.12s	remaining: 206ms
# 169:	learn: 0.0551975	total: 1.13s	remaining: 199ms
# 170:	learn: 0.0549081	total: 1.14s	remaining: 193ms
# 171:	learn: 0.0547774	total: 1.14s	remaining: 186ms
# 172:	learn: 0.0544067	total: 1.15s	remaining: 179ms
# 173:	learn: 0.0541466	total: 1.15s	remaining: 172ms
# 174:	learn: 0.0538124	total: 1.16s	remaining: 166ms
# 175:	learn: 0.0535658	total: 1.17s	remaining: 159ms
# 176:	learn: 0.0532283	total: 1.17s	remaining: 152ms
# 177:	learn: 0.0529736	total: 1.18s	remaining: 146ms
# 178:	learn: 0.0527051	total: 1.18s	remaining: 139ms
# 179:	learn: 0.0524804	total: 1.19s	remaining: 132ms
# 180:	learn: 0.0522802	total: 1.2s	remaining: 126ms
# 181:	learn: 0.0519634	total: 1.2s	remaining: 119ms
# 182:	learn: 0.0516115	total: 1.21s	remaining: 112ms
# 183:	learn: 0.0514337	total: 1.21s	remaining: 106ms
# 184:	learn: 0.0510213	total: 1.22s	remaining: 99ms
# 185:	learn: 0.0507925	total: 1.23s	remaining: 92.4ms
# 186:	learn: 0.0506293	total: 1.23s	remaining: 85.7ms
# 187:	learn: 0.0504526	total: 1.24s	remaining: 79.1ms
# 188:	learn: 0.0502671	total: 1.24s	remaining: 72.5ms
# 189:	learn: 0.0500859	total: 1.25s	remaining: 65.8ms
# 190:	learn: 0.0497550	total: 1.26s	remaining: 59.2ms
# 191:	learn: 0.0495427	total: 1.26s	remaining: 52.6ms
# 192:	learn: 0.0493681	total: 1.27s	remaining: 46ms
# 193:	learn: 0.0491779	total: 1.27s	remaining: 39.4ms
# 194:	learn: 0.0490201	total: 1.28s	remaining: 32.8ms
# 195:	learn: 0.0487761	total: 1.28s	remaining: 26.2ms
# 196:	learn: 0.0485867	total: 1.29s	remaining: 19.7ms
# 197:	learn: 0.0483951	total: 1.3s	remaining: 13.1ms
# 198:	learn: 0.0481015	total: 1.3s	remaining: 6.54ms
# 199:	learn: 0.0478362	total: 1.31s	remaining: 0us
# Best CatBoost Model - Testing Metrics:
# +-----------+-------+
# |   Metric  | Value |
# +-----------+-------+
# |  Accuracy | 0.938 |
# | Precision |  0.2  |
# |   Recall  | 0.022 |
# |  F1 Score |  0.04 |
# |    AUC    | 0.508 |
# +-----------+-------+

# %%
cv_scores = cross_val_score(best_cat_model, X_train, y_train, cv=5, scoring='accuracy')
print("Best CatBoost Model - Cross-Validation Scores:")
print("CV Mean Accuracy: {:.4f}".format(round(cv_scores.mean(), 3)))
print("CV Standard Deviation: {:.4f}".format(round(cv_scores.std(), 3)))
# Out:
# 0:	learn: 0.6461342	total: 4.38ms	remaining: 871ms
# 1:	learn: 0.5973690	total: 9.09ms	remaining: 900ms
# 2:	learn: 0.5339785	total: 14.1ms	remaining: 924ms
# 3:	learn: 0.4858748	total: 18.4ms	remaining: 904ms
# 4:	learn: 0.4558282	total: 26.3ms	remaining: 1.02s
# 5:	learn: 0.4113233	total: 33.6ms	remaining: 1.09s
# 6:	learn: 0.3827275	total: 40.6ms	remaining: 1.12s
# 7:	learn: 0.3610336	total: 46.9ms	remaining: 1.13s
# 8:	learn: 0.3269588	total: 52.3ms	remaining: 1.11s
# 9:	learn: 0.3020302	total: 59ms	remaining: 1.12s
# 10:	learn: 0.2873337	total: 64.6ms	remaining: 1.11s
# 11:	learn: 0.2772881	total: 70.7ms	remaining: 1.11s
# 12:	learn: 0.2596628	total: 75.9ms	remaining: 1.09s
# 13:	learn: 0.2480811	total: 81.5ms	remaining: 1.08s
# 14:	learn: 0.2286503	total: 86.9ms	remaining: 1.07s
# 15:	learn: 0.2167424	total: 92.3ms	remaining: 1.06s
# 16:	learn: 0.2050263	total: 97.7ms	remaining: 1.05s
# 17:	learn: 0.1941110	total: 103ms	remaining: 1.04s
# 18:	learn: 0.1812447	total: 108ms	remaining: 1.03s
# 19:	learn: 0.1736865	total: 114ms	remaining: 1.02s
# 20:	learn: 0.1676806	total: 119ms	remaining: 1.01s
# 21:	learn: 0.1591296	total: 124ms	remaining: 1s
# 22:	learn: 0.1507349	total: 129ms	remaining: 994ms
# 23:	learn: 0.1463178	total: 134ms	remaining: 986ms
# 24:	learn: 0.1420741	total: 140ms	remaining: 979ms
# 25:	learn: 0.1367740	total: 146ms	remaining: 974ms
# 26:	learn: 0.1319175	total: 151ms	remaining: 970ms
# 27:	learn: 0.1267515	total: 157ms	remaining: 966ms
# 28:	learn: 0.1230850	total: 163ms	remaining: 961ms
# 29:	learn: 0.1192400	total: 169ms	remaining: 955ms
# 30:	learn: 0.1163917	total: 175ms	remaining: 952ms
# 31:	learn: 0.1135737	total: 181ms	remaining: 950ms
# 32:	learn: 0.1096438	total: 187ms	remaining: 944ms
# 33:	learn: 0.1051042	total: 193ms	remaining: 940ms
# 34:	learn: 0.1022624	total: 198ms	remaining: 933ms
# 35:	learn: 0.0988955	total: 203ms	remaining: 926ms
# 36:	learn: 0.0969594	total: 209ms	remaining: 921ms
# 37:	learn: 0.0946984	total: 215ms	remaining: 915ms
# 38:	learn: 0.0921116	total: 221ms	remaining: 911ms
# 39:	learn: 0.0897915	total: 226ms	remaining: 904ms
# 40:	learn: 0.0880434	total: 231ms	remaining: 897ms
# 41:	learn: 0.0869224	total: 237ms	remaining: 891ms
# 42:	learn: 0.0850431	total: 243ms	remaining: 886ms
# 43:	learn: 0.0829259	total: 249ms	remaining: 882ms
# 44:	learn: 0.0805175	total: 255ms	remaining: 877ms
# 45:	learn: 0.0795473	total: 260ms	remaining: 871ms
# 46:	learn: 0.0784949	total: 266ms	remaining: 865ms
# 47:	learn: 0.0761349	total: 272ms	remaining: 860ms
# 48:	learn: 0.0750232	total: 277ms	remaining: 855ms
# 49:	learn: 0.0734743	total: 284ms	remaining: 852ms
# 50:	learn: 0.0721794	total: 290ms	remaining: 847ms
# 51:	learn: 0.0711100	total: 296ms	remaining: 842ms
# 52:	learn: 0.0700672	total: 302ms	remaining: 837ms
# 53:	learn: 0.0688122	total: 308ms	remaining: 833ms
# 54:	learn: 0.0675803	total: 314ms	remaining: 827ms
# 55:	learn: 0.0670409	total: 320ms	remaining: 822ms
# 56:	learn: 0.0653699	total: 326ms	remaining: 818ms
# 57:	learn: 0.0637633	total: 332ms	remaining: 812ms
# 58:	learn: 0.0629898	total: 337ms	remaining: 806ms
# 59:	learn: 0.0617208	total: 344ms	remaining: 802ms
# 60:	learn: 0.0609533	total: 350ms	remaining: 797ms
# 61:	learn: 0.0601784	total: 356ms	remaining: 792ms
# 62:	learn: 0.0590322	total: 362ms	remaining: 787ms
# 63:	learn: 0.0580390	total: 367ms	remaining: 781ms
# 64:	learn: 0.0574600	total: 373ms	remaining: 775ms
# 65:	learn: 0.0564897	total: 379ms	remaining: 769ms
# 66:	learn: 0.0559957	total: 385ms	remaining: 764ms
# 67:	learn: 0.0554357	total: 390ms	remaining: 758ms
# 68:	learn: 0.0542838	total: 396ms	remaining: 751ms
# 69:	learn: 0.0534084	total: 401ms	remaining: 745ms
# 70:	learn: 0.0522579	total: 407ms	remaining: 739ms
# 71:	learn: 0.0516972	total: 412ms	remaining: 733ms
# 72:	learn: 0.0508787	total: 418ms	remaining: 727ms
# 73:	learn: 0.0502662	total: 424ms	remaining: 722ms
# 74:	learn: 0.0495121	total: 429ms	remaining: 716ms
# 75:	learn: 0.0488231	total: 440ms	remaining: 718ms
# 76:	learn: 0.0481411	total: 451ms	remaining: 720ms
# 77:	learn: 0.0472438	total: 458ms	remaining: 716ms
# 78:	learn: 0.0464067	total: 468ms	remaining: 717ms
# 79:	learn: 0.0460996	total: 475ms	remaining: 713ms
# 80:	learn: 0.0455813	total: 492ms	remaining: 723ms
# 81:	learn: 0.0450586	total: 508ms	remaining: 731ms
# 82:	learn: 0.0445766	total: 514ms	remaining: 725ms
# 83:	learn: 0.0441134	total: 522ms	remaining: 720ms
# 84:	learn: 0.0436164	total: 532ms	remaining: 720ms
# 85:	learn: 0.0431466	total: 542ms	remaining: 719ms
# 86:	learn: 0.0426153	total: 548ms	remaining: 712ms
# 87:	learn: 0.0420226	total: 560ms	remaining: 713ms
# 88:	learn: 0.0416541	total: 570ms	remaining: 710ms
# 89:	learn: 0.0411098	total: 578ms	remaining: 706ms
# 90:	learn: 0.0406495	total: 589ms	remaining: 706ms
# 91:	learn: 0.0403466	total: 597ms	remaining: 700ms
# 92:	learn: 0.0400347	total: 603ms	remaining: 694ms
# 93:	learn: 0.0396580	total: 611ms	remaining: 689ms
# 94:	learn: 0.0393059	total: 631ms	remaining: 697ms
# 95:	learn: 0.0387674	total: 637ms	remaining: 690ms
# 96:	learn: 0.0383002	total: 643ms	remaining: 683ms
# 97:	learn: 0.0380168	total: 648ms	remaining: 675ms
# 98:	learn: 0.0377778	total: 654ms	remaining: 667ms
# 99:	learn: 0.0373559	total: 660ms	remaining: 660ms
# 100:	learn: 0.0370873	total: 666ms	remaining: 653ms
# 101:	learn: 0.0368102	total: 672ms	remaining: 645ms
# 102:	learn: 0.0365632	total: 677ms	remaining: 638ms
# 103:	learn: 0.0362750	total: 683ms	remaining: 630ms
# 104:	learn: 0.0359124	total: 689ms	remaining: 623ms
# 105:	learn: 0.0355582	total: 694ms	remaining: 616ms
# 106:	learn: 0.0353148	total: 700ms	remaining: 608ms
# 107:	learn: 0.0350744	total: 705ms	remaining: 601ms
# 108:	learn: 0.0347328	total: 711ms	remaining: 594ms
# 109:	learn: 0.0342950	total: 716ms	remaining: 586ms
# 110:	learn: 0.0340035	total: 722ms	remaining: 579ms
# 111:	learn: 0.0335744	total: 728ms	remaining: 572ms
# 112:	learn: 0.0333512	total: 734ms	remaining: 565ms
# 113:	learn: 0.0330723	total: 740ms	remaining: 558ms
# 114:	learn: 0.0326320	total: 746ms	remaining: 551ms
# 115:	learn: 0.0321642	total: 752ms	remaining: 544ms
# 116:	learn: 0.0318770	total: 757ms	remaining: 537ms
# 117:	learn: 0.0316262	total: 763ms	remaining: 530ms
# 118:	learn: 0.0314493	total: 769ms	remaining: 523ms
# 119:	learn: 0.0312319	total: 775ms	remaining: 517ms
# 120:	learn: 0.0309397	total: 781ms	remaining: 510ms
# 121:	learn: 0.0306148	total: 787ms	remaining: 503ms
# 122:	learn: 0.0301596	total: 793ms	remaining: 497ms
# 123:	learn: 0.0299851	total: 799ms	remaining: 490ms
# 124:	learn: 0.0296666	total: 805ms	remaining: 483ms
# 125:	learn: 0.0292872	total: 811ms	remaining: 476ms
# 126:	learn: 0.0291028	total: 817ms	remaining: 470ms
# 127:	learn: 0.0288320	total: 823ms	remaining: 463ms
# 128:	learn: 0.0285466	total: 828ms	remaining: 456ms
# 129:	learn: 0.0280968	total: 834ms	remaining: 449ms
# 130:	learn: 0.0278517	total: 840ms	remaining: 442ms
# 131:	learn: 0.0276069	total: 846ms	remaining: 436ms
# 132:	learn: 0.0274886	total: 852ms	remaining: 429ms
# 133:	learn: 0.0271918	total: 858ms	remaining: 423ms
# 134:	learn: 0.0268653	total: 864ms	remaining: 416ms
# 135:	learn: 0.0266402	total: 870ms	remaining: 409ms
# 136:	learn: 0.0264640	total: 875ms	remaining: 403ms
# 137:	learn: 0.0263392	total: 882ms	remaining: 396ms
# 138:	learn: 0.0260933	total: 888ms	remaining: 390ms
# 139:	learn: 0.0258459	total: 895ms	remaining: 384ms
# 140:	learn: 0.0255256	total: 901ms	remaining: 377ms
# 141:	learn: 0.0252053	total: 907ms	remaining: 370ms
# 142:	learn: 0.0250294	total: 914ms	remaining: 364ms
# 143:	learn: 0.0248593	total: 920ms	remaining: 358ms
# 144:	learn: 0.0246932	total: 926ms	remaining: 351ms
# 145:	learn: 0.0243859	total: 933ms	remaining: 345ms
# 146:	learn: 0.0241258	total: 940ms	remaining: 339ms
# 147:	learn: 0.0240054	total: 947ms	remaining: 333ms
# 148:	learn: 0.0238558	total: 953ms	remaining: 326ms
# 149:	learn: 0.0237169	total: 959ms	remaining: 320ms
# 150:	learn: 0.0235213	total: 965ms	remaining: 313ms
# 151:	learn: 0.0233918	total: 971ms	remaining: 307ms
# 152:	learn: 0.0232608	total: 977ms	remaining: 300ms
# 153:	learn: 0.0227980	total: 983ms	remaining: 294ms
# 154:	learn: 0.0224379	total: 989ms	remaining: 287ms
# 155:	learn: 0.0223422	total: 995ms	remaining: 281ms
# 156:	learn: 0.0221518	total: 1s	remaining: 274ms
# 157:	learn: 0.0220412	total: 1.01s	remaining: 268ms
# 158:	learn: 0.0218547	total: 1.01s	remaining: 261ms
# 159:	learn: 0.0217064	total: 1.02s	remaining: 255ms
# 160:	learn: 0.0215652	total: 1.03s	remaining: 249ms
# 161:	learn: 0.0214534	total: 1.03s	remaining: 242ms
# 162:	learn: 0.0212674	total: 1.04s	remaining: 237ms
# 163:	learn: 0.0210904	total: 1.05s	remaining: 232ms
# 164:	learn: 0.0208410	total: 1.07s	remaining: 226ms
# 165:	learn: 0.0205707	total: 1.08s	remaining: 221ms
# 166:	learn: 0.0204419	total: 1.09s	remaining: 215ms
# 167:	learn: 0.0203226	total: 1.1s	remaining: 209ms
# 168:	learn: 0.0202358	total: 1.11s	remaining: 203ms
# 169:	learn: 0.0199711	total: 1.11s	remaining: 197ms
# 170:	learn: 0.0197791	total: 1.12s	remaining: 190ms
# 171:	learn: 0.0196166	total: 1.13s	remaining: 184ms
# 172:	learn: 0.0194861	total: 1.14s	remaining: 177ms
# 173:	learn: 0.0193262	total: 1.14s	remaining: 171ms
# 174:	learn: 0.0191324	total: 1.15s	remaining: 164ms
# 175:	learn: 0.0189191	total: 1.16s	remaining: 158ms
# 176:	learn: 0.0187348	total: 1.17s	remaining: 152ms
# 177:	learn: 0.0186350	total: 1.18s	remaining: 145ms
# 178:	learn: 0.0185503	total: 1.18s	remaining: 139ms
# 179:	learn: 0.0183992	total: 1.19s	remaining: 132ms
# 180:	learn: 0.0180731	total: 1.2s	remaining: 126ms
# 181:	learn: 0.0179877	total: 1.21s	remaining: 119ms
# 182:	learn: 0.0178832	total: 1.22s	remaining: 113ms
# 183:	learn: 0.0177612	total: 1.22s	remaining: 106ms
# 184:	learn: 0.0176600	total: 1.23s	remaining: 99.7ms
# 185:	learn: 0.0175350	total: 1.24s	remaining: 93ms
# 186:	learn: 0.0173984	total: 1.24s	remaining: 86.4ms
# 187:	learn: 0.0172502	total: 1.25s	remaining: 79.8ms
# 188:	learn: 0.0170617	total: 1.26s	remaining: 73.2ms
# 189:	learn: 0.0169130	total: 1.26s	remaining: 66.6ms
# 190:	learn: 0.0167818	total: 1.27s	remaining: 59.9ms
# 191:	learn: 0.0166781	total: 1.28s	remaining: 53.3ms
# 192:	learn: 0.0165625	total: 1.28s	remaining: 46.6ms
# 193:	learn: 0.0163971	total: 1.29s	remaining: 40ms
# 194:	learn: 0.0163187	total: 1.3s	remaining: 33.3ms
# 195:	learn: 0.0161754	total: 1.31s	remaining: 26.7ms
# 196:	learn: 0.0159781	total: 1.31s	remaining: 20ms
# 197:	learn: 0.0158298	total: 1.32s	remaining: 13.4ms
# 198:	learn: 0.0157630	total: 1.33s	remaining: 6.68ms
# 199:	learn: 0.0156694	total: 1.34s	remaining: 0us
# 0:	learn: 0.6438043	total: 14.1ms	remaining: 2.8s
# 1:	learn: 0.5967946	total: 21.4ms	remaining: 2.12s
# 2:	learn: 0.5445680	total: 28.1ms	remaining: 1.85s
# 3:	learn: 0.4995787	total: 34.3ms	remaining: 1.68s
# 4:	learn: 0.4744796	total: 41.3ms	remaining: 1.61s
# 5:	learn: 0.4414525	total: 47.4ms	remaining: 1.53s
# 6:	learn: 0.4118828	total: 53.3ms	remaining: 1.47s
# 7:	learn: 0.3867629	total: 59ms	remaining: 1.42s
# 8:	learn: 0.3591181	total: 64.5ms	remaining: 1.37s
# 9:	learn: 0.3379248	total: 70.3ms	remaining: 1.33s
# 10:	learn: 0.3248217	total: 75.9ms	remaining: 1.3s
# 11:	learn: 0.3128878	total: 81.5ms	remaining: 1.28s
# 12:	learn: 0.2989382	total: 87.4ms	remaining: 1.26s
# 13:	learn: 0.2862444	total: 93.7ms	remaining: 1.24s
# 14:	learn: 0.2731107	total: 99.7ms	remaining: 1.23s
# 15:	learn: 0.2625947	total: 107ms	remaining: 1.23s
# 16:	learn: 0.2538901	total: 113ms	remaining: 1.22s
# 17:	learn: 0.2439594	total: 120ms	remaining: 1.21s
# 18:	learn: 0.2361103	total: 128ms	remaining: 1.22s
# 19:	learn: 0.2294643	total: 135ms	remaining: 1.22s
# 20:	learn: 0.2226272	total: 144ms	remaining: 1.22s
# 21:	learn: 0.2180845	total: 152ms	remaining: 1.23s
# 22:	learn: 0.2094443	total: 160ms	remaining: 1.23s
# 23:	learn: 0.2035005	total: 167ms	remaining: 1.23s
# 24:	learn: 0.1967069	total: 175ms	remaining: 1.23s
# 25:	learn: 0.1931539	total: 183ms	remaining: 1.22s
# 26:	learn: 0.1886888	total: 190ms	remaining: 1.22s
# 27:	learn: 0.1851380	total: 198ms	remaining: 1.22s
# 28:	learn: 0.1818808	total: 218ms	remaining: 1.28s
# 29:	learn: 0.1775572	total: 233ms	remaining: 1.32s
# 30:	learn: 0.1739272	total: 241ms	remaining: 1.31s
# 31:	learn: 0.1724548	total: 251ms	remaining: 1.32s
# 32:	learn: 0.1690997	total: 267ms	remaining: 1.35s
# 33:	learn: 0.1652719	total: 280ms	remaining: 1.37s
# 34:	learn: 0.1629159	total: 294ms	remaining: 1.39s
# 35:	learn: 0.1590203	total: 308ms	remaining: 1.41s
# 36:	learn: 0.1571575	total: 318ms	remaining: 1.4s
# 37:	learn: 0.1540827	total: 330ms	remaining: 1.41s
# 38:	learn: 0.1516897	total: 338ms	remaining: 1.4s
# 39:	learn: 0.1497222	total: 352ms	remaining: 1.41s
# 40:	learn: 0.1477898	total: 358ms	remaining: 1.39s
# 41:	learn: 0.1446521	total: 363ms	remaining: 1.37s
# 42:	learn: 0.1427743	total: 369ms	remaining: 1.35s
# 43:	learn: 0.1413213	total: 374ms	remaining: 1.33s
# 44:	learn: 0.1392456	total: 380ms	remaining: 1.31s
# 45:	learn: 0.1378483	total: 386ms	remaining: 1.29s
# 46:	learn: 0.1365752	total: 392ms	remaining: 1.28s
# 47:	learn: 0.1340837	total: 398ms	remaining: 1.26s
# 48:	learn: 0.1319753	total: 404ms	remaining: 1.25s
# 49:	learn: 0.1296343	total: 410ms	remaining: 1.23s
# 50:	learn: 0.1275425	total: 416ms	remaining: 1.22s
# 51:	learn: 0.1264309	total: 423ms	remaining: 1.2s
# 52:	learn: 0.1246984	total: 429ms	remaining: 1.19s
# 53:	learn: 0.1225681	total: 435ms	remaining: 1.18s
# 54:	learn: 0.1217875	total: 441ms	remaining: 1.16s
# 55:	learn: 0.1211679	total: 447ms	remaining: 1.15s
# 56:	learn: 0.1204288	total: 453ms	remaining: 1.14s
# 57:	learn: 0.1191675	total: 459ms	remaining: 1.12s
# 58:	learn: 0.1177480	total: 465ms	remaining: 1.11s
# 59:	learn: 0.1163644	total: 470ms	remaining: 1.1s
# 60:	learn: 0.1151184	total: 477ms	remaining: 1.09s
# 61:	learn: 0.1141056	total: 483ms	remaining: 1.07s
# 62:	learn: 0.1132505	total: 489ms	remaining: 1.06s
# 63:	learn: 0.1119794	total: 495ms	remaining: 1.05s
# 64:	learn: 0.1108896	total: 502ms	remaining: 1.04s
# 65:	learn: 0.1092718	total: 509ms	remaining: 1.03s
# 66:	learn: 0.1085099	total: 516ms	remaining: 1.02s
# 67:	learn: 0.1069006	total: 523ms	remaining: 1.01s
# 68:	learn: 0.1061371	total: 530ms	remaining: 1.01s
# 69:	learn: 0.1056245	total: 537ms	remaining: 997ms
# 70:	learn: 0.1046246	total: 544ms	remaining: 988ms
# 71:	learn: 0.1037154	total: 551ms	remaining: 979ms
# 72:	learn: 0.1028160	total: 558ms	remaining: 972ms
# 73:	learn: 0.1020287	total: 565ms	remaining: 962ms
# 74:	learn: 0.1012948	total: 572ms	remaining: 953ms
# 75:	learn: 0.1004238	total: 578ms	remaining: 943ms
# 76:	learn: 0.0993712	total: 585ms	remaining: 935ms
# 77:	learn: 0.0986606	total: 592ms	remaining: 926ms
# 78:	learn: 0.0978149	total: 598ms	remaining: 916ms
# 79:	learn: 0.0972625	total: 602ms	remaining: 902ms
# 80:	learn: 0.0961455	total: 608ms	remaining: 893ms
# 81:	learn: 0.0957228	total: 615ms	remaining: 884ms
# 82:	learn: 0.0949714	total: 621ms	remaining: 875ms
# 83:	learn: 0.0942927	total: 629ms	remaining: 868ms
# 84:	learn: 0.0936493	total: 637ms	remaining: 862ms
# 85:	learn: 0.0929355	total: 646ms	remaining: 856ms
# 86:	learn: 0.0920138	total: 654ms	remaining: 849ms
# 87:	learn: 0.0911827	total: 661ms	remaining: 841ms
# 88:	learn: 0.0904149	total: 669ms	remaining: 834ms
# 89:	learn: 0.0896583	total: 676ms	remaining: 826ms
# 90:	learn: 0.0890178	total: 683ms	remaining: 818ms
# 91:	learn: 0.0882341	total: 692ms	remaining: 812ms
# 92:	learn: 0.0875691	total: 700ms	remaining: 805ms
# 93:	learn: 0.0868693	total: 707ms	remaining: 797ms
# 94:	learn: 0.0862715	total: 713ms	remaining: 789ms
# 95:	learn: 0.0854862	total: 721ms	remaining: 781ms
# 96:	learn: 0.0851953	total: 728ms	remaining: 773ms
# 97:	learn: 0.0846316	total: 735ms	remaining: 765ms
# 98:	learn: 0.0842620	total: 741ms	remaining: 756ms
# 99:	learn: 0.0836646	total: 748ms	remaining: 748ms
# 100:	learn: 0.0833130	total: 754ms	remaining: 739ms
# 101:	learn: 0.0826705	total: 760ms	remaining: 730ms
# 102:	learn: 0.0819565	total: 767ms	remaining: 722ms
# 103:	learn: 0.0812063	total: 774ms	remaining: 714ms
# 104:	learn: 0.0807519	total: 781ms	remaining: 706ms
# 105:	learn: 0.0802175	total: 788ms	remaining: 699ms
# 106:	learn: 0.0799074	total: 794ms	remaining: 690ms
# 107:	learn: 0.0794810	total: 800ms	remaining: 681ms
# 108:	learn: 0.0789402	total: 806ms	remaining: 673ms
# 109:	learn: 0.0785032	total: 813ms	remaining: 665ms
# 110:	learn: 0.0778832	total: 819ms	remaining: 657ms
# 111:	learn: 0.0775466	total: 826ms	remaining: 649ms
# 112:	learn: 0.0770515	total: 833ms	remaining: 641ms
# 113:	learn: 0.0764975	total: 839ms	remaining: 633ms
# 114:	learn: 0.0759672	total: 846ms	remaining: 625ms
# 115:	learn: 0.0756325	total: 853ms	remaining: 618ms
# 116:	learn: 0.0751291	total: 859ms	remaining: 609ms
# 117:	learn: 0.0747839	total: 865ms	remaining: 601ms
# 118:	learn: 0.0744329	total: 873ms	remaining: 594ms
# 119:	learn: 0.0741728	total: 880ms	remaining: 587ms
# 120:	learn: 0.0737486	total: 886ms	remaining: 578ms
# 121:	learn: 0.0733177	total: 893ms	remaining: 571ms
# 122:	learn: 0.0729843	total: 899ms	remaining: 563ms
# 123:	learn: 0.0725400	total: 905ms	remaining: 555ms
# 124:	learn: 0.0721869	total: 913ms	remaining: 548ms
# 125:	learn: 0.0716316	total: 919ms	remaining: 540ms
# 126:	learn: 0.0713915	total: 922ms	remaining: 530ms
# 127:	learn: 0.0710159	total: 928ms	remaining: 522ms
# 128:	learn: 0.0706038	total: 934ms	remaining: 514ms
# 129:	learn: 0.0701159	total: 939ms	remaining: 506ms
# 130:	learn: 0.0697939	total: 946ms	remaining: 498ms
# 131:	learn: 0.0693124	total: 952ms	remaining: 491ms
# 132:	learn: 0.0688822	total: 959ms	remaining: 483ms
# 133:	learn: 0.0684110	total: 965ms	remaining: 475ms
# 134:	learn: 0.0681557	total: 971ms	remaining: 467ms
# 135:	learn: 0.0679472	total: 976ms	remaining: 459ms
# 136:	learn: 0.0675465	total: 982ms	remaining: 452ms
# 137:	learn: 0.0672762	total: 988ms	remaining: 444ms
# 138:	learn: 0.0669272	total: 994ms	remaining: 436ms
# 139:	learn: 0.0667015	total: 1s	remaining: 429ms
# 140:	learn: 0.0663873	total: 1s	remaining: 421ms
# 141:	learn: 0.0661740	total: 1.01s	remaining: 413ms
# 142:	learn: 0.0657298	total: 1.02s	remaining: 406ms
# 143:	learn: 0.0653303	total: 1.02s	remaining: 398ms
# 144:	learn: 0.0648261	total: 1.03s	remaining: 391ms
# 145:	learn: 0.0646079	total: 1.03s	remaining: 383ms
# 146:	learn: 0.0642669	total: 1.04s	remaining: 375ms
# 147:	learn: 0.0638759	total: 1.05s	remaining: 368ms
# 148:	learn: 0.0635799	total: 1.05s	remaining: 361ms
# 149:	learn: 0.0633755	total: 1.06s	remaining: 353ms
# 150:	learn: 0.0630329	total: 1.06s	remaining: 346ms
# 151:	learn: 0.0626191	total: 1.07s	remaining: 339ms
# 152:	learn: 0.0622755	total: 1.08s	remaining: 331ms
# 153:	learn: 0.0617621	total: 1.08s	remaining: 324ms
# 154:	learn: 0.0615803	total: 1.09s	remaining: 317ms
# 155:	learn: 0.0611908	total: 1.1s	remaining: 309ms
# 156:	learn: 0.0609162	total: 1.1s	remaining: 302ms
# 157:	learn: 0.0606483	total: 1.11s	remaining: 295ms
# 158:	learn: 0.0602121	total: 1.11s	remaining: 288ms
# 159:	learn: 0.0598726	total: 1.12s	remaining: 280ms
# 160:	learn: 0.0595045	total: 1.13s	remaining: 273ms
# 161:	learn: 0.0590961	total: 1.13s	remaining: 266ms
# 162:	learn: 0.0588558	total: 1.14s	remaining: 258ms
# 163:	learn: 0.0585864	total: 1.14s	remaining: 251ms
# 164:	learn: 0.0583479	total: 1.15s	remaining: 244ms
# 165:	learn: 0.0581251	total: 1.16s	remaining: 237ms
# 166:	learn: 0.0578134	total: 1.16s	remaining: 230ms
# 167:	learn: 0.0575328	total: 1.17s	remaining: 222ms
# 168:	learn: 0.0572794	total: 1.17s	remaining: 215ms
# 169:	learn: 0.0570215	total: 1.18s	remaining: 208ms
# 170:	learn: 0.0568018	total: 1.19s	remaining: 201ms
# 171:	learn: 0.0564307	total: 1.19s	remaining: 194ms
# 172:	learn: 0.0560719	total: 1.2s	remaining: 187ms
# 173:	learn: 0.0557728	total: 1.21s	remaining: 180ms
# 174:	learn: 0.0555227	total: 1.21s	remaining: 173ms
# 175:	learn: 0.0552787	total: 1.22s	remaining: 166ms
# 176:	learn: 0.0549924	total: 1.22s	remaining: 159ms
# 177:	learn: 0.0546214	total: 1.23s	remaining: 152ms
# 178:	learn: 0.0543972	total: 1.24s	remaining: 145ms
# 179:	learn: 0.0542055	total: 1.24s	remaining: 138ms
# 180:	learn: 0.0539881	total: 1.25s	remaining: 131ms
# 181:	learn: 0.0536857	total: 1.25s	remaining: 124ms
# 182:	learn: 0.0534673	total: 1.26s	remaining: 117ms
# 183:	learn: 0.0532259	total: 1.26s	remaining: 110ms
# 184:	learn: 0.0529830	total: 1.27s	remaining: 103ms
# 185:	learn: 0.0527920	total: 1.28s	remaining: 96.1ms
# 186:	learn: 0.0525949	total: 1.28s	remaining: 89.2ms
# 187:	learn: 0.0522515	total: 1.29s	remaining: 82.3ms
# 188:	learn: 0.0520398	total: 1.29s	remaining: 75.4ms
# 189:	learn: 0.0517891	total: 1.3s	remaining: 68.6ms
# 190:	learn: 0.0515475	total: 1.31s	remaining: 61.7ms
# 191:	learn: 0.0513614	total: 1.31s	remaining: 54.8ms
# 192:	learn: 0.0512121	total: 1.32s	remaining: 47.9ms
# 193:	learn: 0.0509601	total: 1.33s	remaining: 41ms
# 194:	learn: 0.0506096	total: 1.33s	remaining: 34.2ms
# 195:	learn: 0.0504487	total: 1.34s	remaining: 27.3ms
# 196:	learn: 0.0502978	total: 1.35s	remaining: 20.6ms
# 197:	learn: 0.0499900	total: 1.37s	remaining: 13.8ms
# 198:	learn: 0.0497312	total: 1.37s	remaining: 6.91ms
# 199:	learn: 0.0495566	total: 1.38s	remaining: 0us
# 0:	learn: 0.6289188	total: 4.93ms	remaining: 982ms
# 1:	learn: 0.5807270	total: 10.4ms	remaining: 1.03s
# 2:	learn: 0.5287183	total: 23.1ms	remaining: 1.52s
# 3:	learn: 0.4852841	total: 33.7ms	remaining: 1.65s
# 4:	learn: 0.4602822	total: 39.3ms	remaining: 1.53s
# 5:	learn: 0.4346587	total: 44.9ms	remaining: 1.45s
# 6:	learn: 0.4118890	total: 51.2ms	remaining: 1.41s
# 7:	learn: 0.3813689	total: 57.1ms	remaining: 1.37s
# 8:	learn: 0.3536794	total: 63.1ms	remaining: 1.34s
# 9:	learn: 0.3313238	total: 69.1ms	remaining: 1.31s
# 10:	learn: 0.3186836	total: 74.7ms	remaining: 1.28s
# 11:	learn: 0.3024386	total: 80.6ms	remaining: 1.26s
# 12:	learn: 0.2899078	total: 86.7ms	remaining: 1.25s
# 13:	learn: 0.2778215	total: 93.3ms	remaining: 1.24s
# 14:	learn: 0.2644598	total: 99.4ms	remaining: 1.23s
# 15:	learn: 0.2538876	total: 105ms	remaining: 1.21s
# 16:	learn: 0.2446308	total: 111ms	remaining: 1.19s
# 17:	learn: 0.2351956	total: 117ms	remaining: 1.18s
# 18:	learn: 0.2313167	total: 123ms	remaining: 1.17s
# 19:	learn: 0.2259664	total: 128ms	remaining: 1.16s
# 20:	learn: 0.2183640	total: 134ms	remaining: 1.14s
# 21:	learn: 0.2124146	total: 139ms	remaining: 1.13s
# 22:	learn: 0.2044078	total: 145ms	remaining: 1.12s
# 23:	learn: 0.1988957	total: 151ms	remaining: 1.11s
# 24:	learn: 0.1925508	total: 157ms	remaining: 1.1s
# 25:	learn: 0.1880817	total: 163ms	remaining: 1.09s
# 26:	learn: 0.1834978	total: 169ms	remaining: 1.08s
# 27:	learn: 0.1802689	total: 175ms	remaining: 1.08s
# 28:	learn: 0.1768130	total: 182ms	remaining: 1.07s
# 29:	learn: 0.1730209	total: 188ms	remaining: 1.06s
# 30:	learn: 0.1694567	total: 194ms	remaining: 1.06s
# 31:	learn: 0.1679019	total: 200ms	remaining: 1.05s
# 32:	learn: 0.1647322	total: 206ms	remaining: 1.04s
# 33:	learn: 0.1623638	total: 211ms	remaining: 1.03s
# 34:	learn: 0.1587567	total: 218ms	remaining: 1.02s
# 35:	learn: 0.1552518	total: 223ms	remaining: 1.01s
# 36:	learn: 0.1531772	total: 228ms	remaining: 1.01s
# 37:	learn: 0.1496044	total: 235ms	remaining: 1000ms
# 38:	learn: 0.1469382	total: 241ms	remaining: 994ms
# 39:	learn: 0.1450792	total: 246ms	remaining: 986ms
# 40:	learn: 0.1432540	total: 252ms	remaining: 977ms
# 41:	learn: 0.1401194	total: 258ms	remaining: 972ms
# 42:	learn: 0.1386018	total: 264ms	remaining: 965ms
# 43:	learn: 0.1372569	total: 270ms	remaining: 956ms
# 44:	learn: 0.1351346	total: 275ms	remaining: 948ms
# 45:	learn: 0.1333575	total: 281ms	remaining: 940ms
# 46:	learn: 0.1319147	total: 287ms	remaining: 933ms
# 47:	learn: 0.1296833	total: 293ms	remaining: 927ms
# 48:	learn: 0.1275645	total: 299ms	remaining: 921ms
# 49:	learn: 0.1258130	total: 305ms	remaining: 914ms
# 50:	learn: 0.1234913	total: 310ms	remaining: 907ms
# 51:	learn: 0.1224445	total: 316ms	remaining: 900ms
# 52:	learn: 0.1209428	total: 322ms	remaining: 894ms
# 53:	learn: 0.1195173	total: 328ms	remaining: 887ms
# 54:	learn: 0.1186489	total: 334ms	remaining: 882ms
# 55:	learn: 0.1174578	total: 341ms	remaining: 876ms
# 56:	learn: 0.1164012	total: 347ms	remaining: 870ms
# 57:	learn: 0.1151697	total: 353ms	remaining: 864ms
# 58:	learn: 0.1138482	total: 359ms	remaining: 858ms
# 59:	learn: 0.1125649	total: 365ms	remaining: 851ms
# 60:	learn: 0.1116046	total: 371ms	remaining: 844ms
# 61:	learn: 0.1100899	total: 376ms	remaining: 838ms
# 62:	learn: 0.1090537	total: 382ms	remaining: 831ms
# 63:	learn: 0.1081721	total: 388ms	remaining: 825ms
# 64:	learn: 0.1074737	total: 394ms	remaining: 818ms
# 65:	learn: 0.1059587	total: 399ms	remaining: 811ms
# 66:	learn: 0.1049661	total: 405ms	remaining: 804ms
# 67:	learn: 0.1041906	total: 411ms	remaining: 798ms
# 68:	learn: 0.1033570	total: 416ms	remaining: 791ms
# 69:	learn: 0.1022805	total: 422ms	remaining: 784ms
# 70:	learn: 0.1015384	total: 428ms	remaining: 777ms
# 71:	learn: 0.1008522	total: 433ms	remaining: 770ms
# 72:	learn: 0.0999674	total: 439ms	remaining: 764ms
# 73:	learn: 0.0991322	total: 444ms	remaining: 757ms
# 74:	learn: 0.0980243	total: 450ms	remaining: 750ms
# 75:	learn: 0.0972853	total: 456ms	remaining: 744ms
# 76:	learn: 0.0964264	total: 462ms	remaining: 738ms
# 77:	learn: 0.0957594	total: 468ms	remaining: 732ms
# 78:	learn: 0.0949665	total: 474ms	remaining: 725ms
# 79:	learn: 0.0940411	total: 480ms	remaining: 719ms
# 80:	learn: 0.0936158	total: 485ms	remaining: 713ms
# 81:	learn: 0.0929446	total: 491ms	remaining: 706ms
# 82:	learn: 0.0922944	total: 497ms	remaining: 700ms
# 83:	learn: 0.0916127	total: 503ms	remaining: 694ms
# 84:	learn: 0.0910554	total: 508ms	remaining: 688ms
# 85:	learn: 0.0906604	total: 514ms	remaining: 682ms
# 86:	learn: 0.0898209	total: 520ms	remaining: 675ms
# 87:	learn: 0.0892513	total: 525ms	remaining: 669ms
# 88:	learn: 0.0888761	total: 531ms	remaining: 662ms
# 89:	learn: 0.0882068	total: 537ms	remaining: 656ms
# 90:	learn: 0.0877629	total: 543ms	remaining: 650ms
# 91:	learn: 0.0872914	total: 548ms	remaining: 644ms
# 92:	learn: 0.0869300	total: 554ms	remaining: 637ms
# 93:	learn: 0.0865461	total: 560ms	remaining: 631ms
# 94:	learn: 0.0862128	total: 565ms	remaining: 625ms
# 95:	learn: 0.0854951	total: 571ms	remaining: 618ms
# 96:	learn: 0.0849942	total: 576ms	remaining: 612ms
# 97:	learn: 0.0845090	total: 582ms	remaining: 606ms
# 98:	learn: 0.0839854	total: 588ms	remaining: 600ms
# 99:	learn: 0.0836863	total: 593ms	remaining: 593ms
# 100:	learn: 0.0832375	total: 599ms	remaining: 587ms
# 101:	learn: 0.0830481	total: 605ms	remaining: 581ms
# 102:	learn: 0.0826848	total: 611ms	remaining: 575ms
# 103:	learn: 0.0821679	total: 616ms	remaining: 569ms
# 104:	learn: 0.0815816	total: 623ms	remaining: 563ms
# 105:	learn: 0.0811840	total: 629ms	remaining: 558ms
# 106:	learn: 0.0806551	total: 634ms	remaining: 551ms
# 107:	learn: 0.0798160	total: 640ms	remaining: 545ms
# 108:	learn: 0.0790801	total: 645ms	remaining: 539ms
# 109:	learn: 0.0786062	total: 651ms	remaining: 533ms
# 110:	learn: 0.0779567	total: 658ms	remaining: 527ms
# 111:	learn: 0.0771687	total: 664ms	remaining: 521ms
# 112:	learn: 0.0768010	total: 669ms	remaining: 515ms
# 113:	learn: 0.0762394	total: 675ms	remaining: 509ms
# 114:	learn: 0.0756363	total: 681ms	remaining: 503ms
# 115:	learn: 0.0750863	total: 687ms	remaining: 497ms
# 116:	learn: 0.0748817	total: 692ms	remaining: 491ms
# 117:	learn: 0.0745765	total: 698ms	remaining: 485ms
# 118:	learn: 0.0741617	total: 703ms	remaining: 478ms
# 119:	learn: 0.0737822	total: 708ms	remaining: 472ms
# 120:	learn: 0.0731578	total: 714ms	remaining: 466ms
# 121:	learn: 0.0728324	total: 718ms	remaining: 459ms
# 122:	learn: 0.0726154	total: 721ms	remaining: 451ms
# 123:	learn: 0.0721619	total: 725ms	remaining: 445ms
# 124:	learn: 0.0719306	total: 731ms	remaining: 438ms
# 125:	learn: 0.0714188	total: 736ms	remaining: 432ms
# 126:	learn: 0.0710745	total: 742ms	remaining: 427ms
# 127:	learn: 0.0705984	total: 748ms	remaining: 421ms
# 128:	learn: 0.0701791	total: 754ms	remaining: 415ms
# 129:	learn: 0.0698756	total: 759ms	remaining: 409ms
# 130:	learn: 0.0696766	total: 765ms	remaining: 403ms
# 131:	learn: 0.0694001	total: 771ms	remaining: 397ms
# 132:	learn: 0.0689109	total: 776ms	remaining: 391ms
# 133:	learn: 0.0685642	total: 782ms	remaining: 385ms
# 134:	learn: 0.0681313	total: 787ms	remaining: 379ms
# 135:	learn: 0.0677351	total: 793ms	remaining: 373ms
# 136:	learn: 0.0673273	total: 798ms	remaining: 367ms
# 137:	learn: 0.0671132	total: 804ms	remaining: 361ms
# 138:	learn: 0.0669277	total: 809ms	remaining: 355ms
# 139:	learn: 0.0664353	total: 815ms	remaining: 349ms
# 140:	learn: 0.0661494	total: 821ms	remaining: 344ms
# 141:	learn: 0.0658588	total: 826ms	remaining: 338ms
# 142:	learn: 0.0655722	total: 832ms	remaining: 332ms
# 143:	learn: 0.0653726	total: 837ms	remaining: 326ms
# 144:	learn: 0.0650051	total: 842ms	remaining: 319ms
# 145:	learn: 0.0646015	total: 848ms	remaining: 314ms
# 146:	learn: 0.0642213	total: 854ms	remaining: 308ms
# 147:	learn: 0.0638917	total: 860ms	remaining: 302ms
# 148:	learn: 0.0637015	total: 866ms	remaining: 296ms
# 149:	learn: 0.0631581	total: 872ms	remaining: 291ms
# 150:	learn: 0.0630488	total: 878ms	remaining: 285ms
# 151:	learn: 0.0626140	total: 885ms	remaining: 279ms
# 152:	learn: 0.0622733	total: 890ms	remaining: 273ms
# 153:	learn: 0.0619723	total: 896ms	remaining: 268ms
# 154:	learn: 0.0615335	total: 902ms	remaining: 262ms
# 155:	learn: 0.0613125	total: 908ms	remaining: 256ms
# 156:	learn: 0.0609088	total: 914ms	remaining: 250ms
# 157:	learn: 0.0605352	total: 920ms	remaining: 244ms
# 158:	learn: 0.0601865	total: 926ms	remaining: 239ms
# 159:	learn: 0.0598922	total: 932ms	remaining: 233ms
# 160:	learn: 0.0596538	total: 938ms	remaining: 227ms
# 161:	learn: 0.0593810	total: 945ms	remaining: 222ms
# 162:	learn: 0.0591317	total: 951ms	remaining: 216ms
# 163:	learn: 0.0587223	total: 958ms	remaining: 210ms
# 164:	learn: 0.0584370	total: 963ms	remaining: 204ms
# 165:	learn: 0.0582011	total: 970ms	remaining: 199ms
# 166:	learn: 0.0579939	total: 976ms	remaining: 193ms
# 167:	learn: 0.0577314	total: 982ms	remaining: 187ms
# 168:	learn: 0.0574815	total: 988ms	remaining: 181ms
# 169:	learn: 0.0572014	total: 995ms	remaining: 176ms
# 170:	learn: 0.0568451	total: 1s	remaining: 170ms
# 171:	learn: 0.0565507	total: 1.01s	remaining: 165ms
# 172:	learn: 0.0564029	total: 1.03s	remaining: 161ms
# 173:	learn: 0.0561666	total: 1.04s	remaining: 156ms
# 174:	learn: 0.0558995	total: 1.05s	remaining: 150ms
# 175:	learn: 0.0557205	total: 1.06s	remaining: 145ms
# 176:	learn: 0.0553603	total: 1.09s	remaining: 142ms
# 177:	learn: 0.0551196	total: 1.1s	remaining: 136ms
# 178:	learn: 0.0548641	total: 1.1s	remaining: 130ms
# 179:	learn: 0.0546107	total: 1.11s	remaining: 123ms
# 180:	learn: 0.0544837	total: 1.13s	remaining: 119ms
# 181:	learn: 0.0541747	total: 1.15s	remaining: 113ms
# 182:	learn: 0.0539476	total: 1.15s	remaining: 107ms
# 183:	learn: 0.0536203	total: 1.17s	remaining: 102ms
# 184:	learn: 0.0533868	total: 1.18s	remaining: 95.4ms
# 185:	learn: 0.0531749	total: 1.18s	remaining: 89.1ms
# 186:	learn: 0.0529096	total: 1.19s	remaining: 83ms
# 187:	learn: 0.0528004	total: 1.2s	remaining: 76.6ms
# 188:	learn: 0.0525722	total: 1.21s	remaining: 70.2ms
# 189:	learn: 0.0522947	total: 1.21s	remaining: 63.9ms
# 190:	learn: 0.0519500	total: 1.22s	remaining: 57.5ms
# 191:	learn: 0.0516372	total: 1.23s	remaining: 51.1ms
# 192:	learn: 0.0514451	total: 1.23s	remaining: 44.7ms
# 193:	learn: 0.0512711	total: 1.24s	remaining: 38.4ms
# 194:	learn: 0.0510560	total: 1.25s	remaining: 32ms
# 195:	learn: 0.0508915	total: 1.25s	remaining: 25.6ms
# 196:	learn: 0.0506745	total: 1.26s	remaining: 19.2ms
# 197:	learn: 0.0504647	total: 1.26s	remaining: 12.8ms
# 198:	learn: 0.0501957	total: 1.27s	remaining: 6.39ms
# 199:	learn: 0.0499406	total: 1.28s	remaining: 0us
# 0:	learn: 0.6273721	total: 4.98ms	remaining: 990ms
# 1:	learn: 0.5831989	total: 10.3ms	remaining: 1.02s
# 2:	learn: 0.5494351	total: 15.7ms	remaining: 1.03s
# 3:	learn: 0.5055880	total: 21.3ms	remaining: 1.04s
# 4:	learn: 0.4794328	total: 26.8ms	remaining: 1.04s
# 5:	learn: 0.4411100	total: 32.1ms	remaining: 1.04s
# 6:	learn: 0.4185407	total: 37.2ms	remaining: 1.03s
# 7:	learn: 0.4018569	total: 43ms	remaining: 1.03s
# 8:	learn: 0.3718256	total: 48.7ms	remaining: 1.03s
# 9:	learn: 0.3475546	total: 54.3ms	remaining: 1.03s
# 10:	learn: 0.3337118	total: 60.9ms	remaining: 1.05s
# 11:	learn: 0.3185675	total: 66.9ms	remaining: 1.05s
# 12:	learn: 0.3044242	total: 72.7ms	remaining: 1.04s
# 13:	learn: 0.2927770	total: 78.8ms	remaining: 1.05s
# 14:	learn: 0.2778203	total: 84.3ms	remaining: 1.04s
# 15:	learn: 0.2662438	total: 90.2ms	remaining: 1.04s
# 16:	learn: 0.2552986	total: 96.1ms	remaining: 1.03s
# 17:	learn: 0.2458070	total: 102ms	remaining: 1.03s
# 18:	learn: 0.2380174	total: 108ms	remaining: 1.02s
# 19:	learn: 0.2296935	total: 114ms	remaining: 1.02s
# 20:	learn: 0.2242270	total: 119ms	remaining: 1.02s
# 21:	learn: 0.2193188	total: 125ms	remaining: 1.01s
# 22:	learn: 0.2105410	total: 131ms	remaining: 1.01s
# 23:	learn: 0.2031331	total: 136ms	remaining: 1s
# 24:	learn: 0.1968319	total: 142ms	remaining: 996ms
# 25:	learn: 0.1941250	total: 148ms	remaining: 989ms
# 26:	learn: 0.1889836	total: 154ms	remaining: 987ms
# 27:	learn: 0.1854784	total: 160ms	remaining: 980ms
# 28:	learn: 0.1810556	total: 165ms	remaining: 976ms
# 29:	learn: 0.1773045	total: 171ms	remaining: 970ms
# 30:	learn: 0.1734098	total: 177ms	remaining: 964ms
# 31:	learn: 0.1680247	total: 183ms	remaining: 959ms
# 32:	learn: 0.1646600	total: 188ms	remaining: 952ms
# 33:	learn: 0.1607868	total: 195ms	remaining: 951ms
# 34:	learn: 0.1583948	total: 200ms	remaining: 944ms
# 35:	learn: 0.1549074	total: 206ms	remaining: 940ms
# 36:	learn: 0.1523070	total: 212ms	remaining: 935ms
# 37:	learn: 0.1488694	total: 218ms	remaining: 931ms
# 38:	learn: 0.1460991	total: 224ms	remaining: 926ms
# 39:	learn: 0.1441599	total: 231ms	remaining: 923ms
# 40:	learn: 0.1429736	total: 236ms	remaining: 917ms
# 41:	learn: 0.1397998	total: 242ms	remaining: 910ms
# 42:	learn: 0.1385792	total: 247ms	remaining: 903ms
# 43:	learn: 0.1371208	total: 253ms	remaining: 898ms
# 44:	learn: 0.1347296	total: 258ms	remaining: 890ms
# 45:	learn: 0.1334169	total: 264ms	remaining: 885ms
# 46:	learn: 0.1318255	total: 270ms	remaining: 878ms
# 47:	learn: 0.1301465	total: 275ms	remaining: 871ms
# 48:	learn: 0.1285408	total: 281ms	remaining: 865ms
# 49:	learn: 0.1267106	total: 287ms	remaining: 860ms
# 50:	learn: 0.1256970	total: 292ms	remaining: 854ms
# 51:	learn: 0.1248357	total: 298ms	remaining: 848ms
# 52:	learn: 0.1230672	total: 304ms	remaining: 843ms
# 53:	learn: 0.1224442	total: 310ms	remaining: 838ms
# 54:	learn: 0.1216987	total: 316ms	remaining: 833ms
# 55:	learn: 0.1207579	total: 322ms	remaining: 827ms
# 56:	learn: 0.1199650	total: 328ms	remaining: 822ms
# 57:	learn: 0.1187458	total: 333ms	remaining: 815ms
# 58:	learn: 0.1179851	total: 338ms	remaining: 809ms
# 59:	learn: 0.1167211	total: 345ms	remaining: 804ms
# 60:	learn: 0.1154642	total: 350ms	remaining: 798ms
# 61:	learn: 0.1144449	total: 356ms	remaining: 792ms
# 62:	learn: 0.1134500	total: 362ms	remaining: 787ms
# 63:	learn: 0.1120929	total: 367ms	remaining: 781ms
# 64:	learn: 0.1113838	total: 373ms	remaining: 776ms
# 65:	learn: 0.1099107	total: 380ms	remaining: 771ms
# 66:	learn: 0.1086998	total: 386ms	remaining: 765ms
# 67:	learn: 0.1076635	total: 392ms	remaining: 760ms
# 68:	learn: 0.1064906	total: 398ms	remaining: 755ms
# 69:	learn: 0.1055192	total: 404ms	remaining: 751ms
# 70:	learn: 0.1045275	total: 410ms	remaining: 745ms
# 71:	learn: 0.1037249	total: 416ms	remaining: 740ms
# 72:	learn: 0.1028854	total: 422ms	remaining: 735ms
# 73:	learn: 0.1023758	total: 428ms	remaining: 729ms
# 74:	learn: 0.1011851	total: 434ms	remaining: 723ms
# 75:	learn: 0.1002906	total: 440ms	remaining: 717ms
# 76:	learn: 0.0994548	total: 445ms	remaining: 711ms
# 77:	learn: 0.0989517	total: 451ms	remaining: 705ms
# 78:	learn: 0.0983039	total: 456ms	remaining: 699ms
# 79:	learn: 0.0974984	total: 462ms	remaining: 694ms
# 80:	learn: 0.0967773	total: 468ms	remaining: 687ms
# 81:	learn: 0.0961031	total: 474ms	remaining: 681ms
# 82:	learn: 0.0956021	total: 479ms	remaining: 676ms
# 83:	learn: 0.0952719	total: 485ms	remaining: 669ms
# 84:	learn: 0.0944730	total: 491ms	remaining: 664ms
# 85:	learn: 0.0936475	total: 497ms	remaining: 659ms
# 86:	learn: 0.0927594	total: 503ms	remaining: 653ms
# 87:	learn: 0.0922366	total: 508ms	remaining: 647ms
# 88:	learn: 0.0916100	total: 514ms	remaining: 642ms
# 89:	learn: 0.0907523	total: 520ms	remaining: 636ms
# 90:	learn: 0.0902229	total: 526ms	remaining: 630ms
# 91:	learn: 0.0894447	total: 532ms	remaining: 625ms
# 92:	learn: 0.0891550	total: 538ms	remaining: 619ms
# 93:	learn: 0.0884796	total: 544ms	remaining: 613ms
# 94:	learn: 0.0878069	total: 550ms	remaining: 608ms
# 95:	learn: 0.0871024	total: 556ms	remaining: 602ms
# 96:	learn: 0.0865553	total: 562ms	remaining: 597ms
# 97:	learn: 0.0862064	total: 568ms	remaining: 591ms
# 98:	learn: 0.0856812	total: 574ms	remaining: 585ms
# 99:	learn: 0.0851357	total: 580ms	remaining: 580ms
# 100:	learn: 0.0846116	total: 587ms	remaining: 575ms
# 101:	learn: 0.0840423	total: 592ms	remaining: 569ms
# 102:	learn: 0.0837042	total: 598ms	remaining: 563ms
# 103:	learn: 0.0832815	total: 604ms	remaining: 558ms
# 104:	learn: 0.0826747	total: 611ms	remaining: 553ms
# 105:	learn: 0.0821023	total: 617ms	remaining: 547ms
# 106:	learn: 0.0817119	total: 623ms	remaining: 542ms
# 107:	learn: 0.0810790	total: 629ms	remaining: 536ms
# 108:	learn: 0.0807259	total: 636ms	remaining: 531ms
# 109:	learn: 0.0803498	total: 642ms	remaining: 525ms
# 110:	learn: 0.0796597	total: 647ms	remaining: 519ms
# 111:	learn: 0.0789612	total: 653ms	remaining: 513ms
# 112:	learn: 0.0785295	total: 658ms	remaining: 507ms
# 113:	learn: 0.0779840	total: 664ms	remaining: 501ms
# 114:	learn: 0.0774166	total: 670ms	remaining: 495ms
# 115:	learn: 0.0768538	total: 676ms	remaining: 489ms
# 116:	learn: 0.0766181	total: 682ms	remaining: 484ms
# 117:	learn: 0.0760793	total: 688ms	remaining: 478ms
# 118:	learn: 0.0754826	total: 694ms	remaining: 472ms
# 119:	learn: 0.0751085	total: 700ms	remaining: 466ms
# 120:	learn: 0.0746795	total: 705ms	remaining: 461ms
# 121:	learn: 0.0742054	total: 711ms	remaining: 455ms
# 122:	learn: 0.0737926	total: 717ms	remaining: 449ms
# 123:	learn: 0.0732297	total: 723ms	remaining: 443ms
# 124:	learn: 0.0728850	total: 729ms	remaining: 437ms
# 125:	learn: 0.0724044	total: 735ms	remaining: 431ms
# 126:	learn: 0.0719713	total: 741ms	remaining: 426ms
# 127:	learn: 0.0715841	total: 747ms	remaining: 420ms
# 128:	learn: 0.0711190	total: 753ms	remaining: 414ms
# 129:	learn: 0.0707335	total: 758ms	remaining: 408ms
# 130:	learn: 0.0703438	total: 764ms	remaining: 402ms
# 131:	learn: 0.0701280	total: 770ms	remaining: 396ms
# 132:	learn: 0.0697435	total: 776ms	remaining: 391ms
# 133:	learn: 0.0694523	total: 782ms	remaining: 385ms
# 134:	learn: 0.0689935	total: 788ms	remaining: 379ms
# 135:	learn: 0.0686102	total: 794ms	remaining: 374ms
# 136:	learn: 0.0683123	total: 800ms	remaining: 368ms
# 137:	learn: 0.0680600	total: 807ms	remaining: 362ms
# 138:	learn: 0.0677278	total: 813ms	remaining: 357ms
# 139:	learn: 0.0674003	total: 826ms	remaining: 354ms
# 140:	learn: 0.0671097	total: 835ms	remaining: 349ms
# 141:	learn: 0.0667879	total: 850ms	remaining: 347ms
# 142:	learn: 0.0664144	total: 867ms	remaining: 345ms
# 143:	learn: 0.0661482	total: 873ms	remaining: 340ms
# 144:	learn: 0.0658652	total: 882ms	remaining: 335ms
# 145:	learn: 0.0654905	total: 897ms	remaining: 332ms
# 146:	learn: 0.0650483	total: 911ms	remaining: 328ms
# 147:	learn: 0.0647305	total: 917ms	remaining: 322ms
# 148:	learn: 0.0644177	total: 923ms	remaining: 316ms
# 149:	learn: 0.0641150	total: 929ms	remaining: 310ms
# 150:	learn: 0.0637785	total: 943ms	remaining: 306ms
# 151:	learn: 0.0635055	total: 956ms	remaining: 302ms
# 152:	learn: 0.0630802	total: 963ms	remaining: 296ms
# 153:	learn: 0.0627982	total: 968ms	remaining: 289ms
# 154:	learn: 0.0624094	total: 974ms	remaining: 283ms
# 155:	learn: 0.0621086	total: 985ms	remaining: 278ms
# 156:	learn: 0.0618227	total: 992ms	remaining: 272ms
# 157:	learn: 0.0614368	total: 1s	remaining: 267ms
# 158:	learn: 0.0612449	total: 1.01s	remaining: 260ms
# 159:	learn: 0.0608447	total: 1.02s	remaining: 254ms
# 160:	learn: 0.0605385	total: 1.02s	remaining: 248ms
# 161:	learn: 0.0602839	total: 1.03s	remaining: 241ms
# 162:	learn: 0.0599749	total: 1.03s	remaining: 235ms
# 163:	learn: 0.0596207	total: 1.04s	remaining: 228ms
# 164:	learn: 0.0593785	total: 1.04s	remaining: 222ms
# 165:	learn: 0.0590050	total: 1.05s	remaining: 215ms
# 166:	learn: 0.0586147	total: 1.06s	remaining: 209ms
# 167:	learn: 0.0582586	total: 1.06s	remaining: 203ms
# 168:	learn: 0.0580613	total: 1.07s	remaining: 196ms
# 169:	learn: 0.0578341	total: 1.07s	remaining: 190ms
# 170:	learn: 0.0573532	total: 1.08s	remaining: 183ms
# 171:	learn: 0.0571262	total: 1.09s	remaining: 177ms
# 172:	learn: 0.0569708	total: 1.09s	remaining: 171ms
# 173:	learn: 0.0567066	total: 1.1s	remaining: 164ms
# 174:	learn: 0.0564721	total: 1.1s	remaining: 158ms
# 175:	learn: 0.0562058	total: 1.11s	remaining: 152ms
# 176:	learn: 0.0559436	total: 1.12s	remaining: 145ms
# 177:	learn: 0.0557333	total: 1.12s	remaining: 139ms
# 178:	learn: 0.0554819	total: 1.13s	remaining: 132ms
# 179:	learn: 0.0552492	total: 1.13s	remaining: 126ms
# 180:	learn: 0.0550365	total: 1.14s	remaining: 120ms
# 181:	learn: 0.0548204	total: 1.15s	remaining: 113ms
# 182:	learn: 0.0545503	total: 1.15s	remaining: 107ms
# 183:	learn: 0.0542824	total: 1.16s	remaining: 101ms
# 184:	learn: 0.0541109	total: 1.16s	remaining: 94.2ms
# 185:	learn: 0.0538764	total: 1.17s	remaining: 87.9ms
# 186:	learn: 0.0535155	total: 1.17s	remaining: 81.6ms
# 187:	learn: 0.0532808	total: 1.18s	remaining: 75.2ms
# 188:	learn: 0.0531455	total: 1.18s	remaining: 68.9ms
# 189:	learn: 0.0531014	total: 1.19s	remaining: 62.5ms
# 190:	learn: 0.0528512	total: 1.19s	remaining: 56.2ms
# 191:	learn: 0.0525878	total: 1.2s	remaining: 50ms
# 192:	learn: 0.0523293	total: 1.2s	remaining: 43.7ms
# 193:	learn: 0.0521451	total: 1.21s	remaining: 37.5ms
# 194:	learn: 0.0518633	total: 1.22s	remaining: 31.2ms
# 195:	learn: 0.0516773	total: 1.22s	remaining: 25ms
# 196:	learn: 0.0515088	total: 1.23s	remaining: 18.7ms
# 197:	learn: 0.0512528	total: 1.23s	remaining: 12.5ms
# 198:	learn: 0.0509233	total: 1.24s	remaining: 6.23ms
# 199:	learn: 0.0506911	total: 1.25s	remaining: 0us
# 0:	learn: 0.6479416	total: 4.41ms	remaining: 878ms
# 1:	learn: 0.6046600	total: 9.43ms	remaining: 933ms
# 2:	learn: 0.5680680	total: 14.3ms	remaining: 940ms
# 3:	learn: 0.5233672	total: 21.1ms	remaining: 1.04s
# 4:	learn: 0.4959956	total: 26.3ms	remaining: 1.02s
# 5:	learn: 0.4553885	total: 32ms	remaining: 1.03s
# 6:	learn: 0.4293787	total: 37.3ms	remaining: 1.03s
# 7:	learn: 0.3967061	total: 43.2ms	remaining: 1.04s
# 8:	learn: 0.3674526	total: 48.9ms	remaining: 1.04s
# 9:	learn: 0.3516021	total: 54.6ms	remaining: 1.04s
# 10:	learn: 0.3371866	total: 60ms	remaining: 1.03s
# 11:	learn: 0.3200473	total: 66ms	remaining: 1.03s
# 12:	learn: 0.3069977	total: 71.9ms	remaining: 1.03s
# 13:	learn: 0.2940800	total: 77.5ms	remaining: 1.03s
# 14:	learn: 0.2769869	total: 83ms	remaining: 1.02s
# 15:	learn: 0.2659077	total: 88.5ms	remaining: 1.02s
# 16:	learn: 0.2551633	total: 93.9ms	remaining: 1.01s
# 17:	learn: 0.2432261	total: 100ms	remaining: 1.01s
# 18:	learn: 0.2356343	total: 106ms	remaining: 1.01s
# 19:	learn: 0.2286868	total: 112ms	remaining: 1s
# 20:	learn: 0.2233926	total: 118ms	remaining: 1s
# 21:	learn: 0.2188776	total: 123ms	remaining: 996ms
# 22:	learn: 0.2101315	total: 128ms	remaining: 987ms
# 23:	learn: 0.2036493	total: 134ms	remaining: 986ms
# 24:	learn: 0.1970677	total: 140ms	remaining: 983ms
# 25:	learn: 0.1943630	total: 146ms	remaining: 980ms
# 26:	learn: 0.1896353	total: 152ms	remaining: 974ms
# 27:	learn: 0.1825503	total: 158ms	remaining: 970ms
# 28:	learn: 0.1786287	total: 163ms	remaining: 964ms
# 29:	learn: 0.1750322	total: 169ms	remaining: 959ms
# 30:	learn: 0.1716846	total: 176ms	remaining: 958ms
# 31:	learn: 0.1697261	total: 182ms	remaining: 954ms
# 32:	learn: 0.1666210	total: 188ms	remaining: 949ms
# 33:	learn: 0.1640130	total: 194ms	remaining: 946ms
# 34:	learn: 0.1606488	total: 200ms	remaining: 942ms
# 35:	learn: 0.1566289	total: 205ms	remaining: 936ms
# 36:	learn: 0.1535221	total: 212ms	remaining: 933ms
# 37:	learn: 0.1507812	total: 218ms	remaining: 931ms
# 38:	learn: 0.1481537	total: 225ms	remaining: 927ms
# 39:	learn: 0.1464921	total: 231ms	remaining: 924ms
# 40:	learn: 0.1429230	total: 237ms	remaining: 921ms
# 41:	learn: 0.1400442	total: 244ms	remaining: 918ms
# 42:	learn: 0.1385843	total: 251ms	remaining: 915ms
# 43:	learn: 0.1361947	total: 257ms	remaining: 911ms
# 44:	learn: 0.1339133	total: 263ms	remaining: 907ms
# 45:	learn: 0.1326365	total: 270ms	remaining: 902ms
# 46:	learn: 0.1310966	total: 276ms	remaining: 899ms
# 47:	learn: 0.1289213	total: 283ms	remaining: 895ms
# 48:	learn: 0.1274749	total: 289ms	remaining: 890ms
# 49:	learn: 0.1257482	total: 296ms	remaining: 887ms
# 50:	learn: 0.1245994	total: 302ms	remaining: 882ms
# 51:	learn: 0.1236227	total: 308ms	remaining: 876ms
# 52:	learn: 0.1225146	total: 314ms	remaining: 870ms
# 53:	learn: 0.1206666	total: 320ms	remaining: 864ms
# 54:	learn: 0.1200156	total: 325ms	remaining: 857ms
# 55:	learn: 0.1187217	total: 330ms	remaining: 849ms
# 56:	learn: 0.1178362	total: 336ms	remaining: 843ms
# 57:	learn: 0.1170323	total: 341ms	remaining: 836ms
# 58:	learn: 0.1159527	total: 347ms	remaining: 829ms
# 59:	learn: 0.1147532	total: 352ms	remaining: 822ms
# 60:	learn: 0.1135546	total: 358ms	remaining: 816ms
# 61:	learn: 0.1124808	total: 364ms	remaining: 810ms
# 62:	learn: 0.1114822	total: 370ms	remaining: 804ms
# 63:	learn: 0.1109409	total: 375ms	remaining: 797ms
# 64:	learn: 0.1104051	total: 380ms	remaining: 790ms
# 65:	learn: 0.1090187	total: 386ms	remaining: 785ms
# 66:	learn: 0.1082688	total: 392ms	remaining: 779ms
# 67:	learn: 0.1069514	total: 398ms	remaining: 773ms
# 68:	learn: 0.1062111	total: 404ms	remaining: 766ms
# 69:	learn: 0.1056463	total: 409ms	remaining: 760ms
# 70:	learn: 0.1048802	total: 415ms	remaining: 754ms
# 71:	learn: 0.1040653	total: 421ms	remaining: 748ms
# 72:	learn: 0.1032049	total: 427ms	remaining: 742ms
# 73:	learn: 0.1023515	total: 432ms	remaining: 736ms
# 74:	learn: 0.1013544	total: 437ms	remaining: 729ms
# 75:	learn: 0.1004085	total: 443ms	remaining: 723ms
# 76:	learn: 0.0996453	total: 449ms	remaining: 717ms
# 77:	learn: 0.0989153	total: 454ms	remaining: 711ms
# 78:	learn: 0.0981257	total: 460ms	remaining: 704ms
# 79:	learn: 0.0973169	total: 465ms	remaining: 698ms
# 80:	learn: 0.0965484	total: 471ms	remaining: 692ms
# 81:	learn: 0.0960127	total: 477ms	remaining: 686ms
# 82:	learn: 0.0955061	total: 482ms	remaining: 680ms
# 83:	learn: 0.0949601	total: 487ms	remaining: 673ms
# 84:	learn: 0.0943038	total: 493ms	remaining: 667ms
# 85:	learn: 0.0936986	total: 499ms	remaining: 661ms
# 86:	learn: 0.0931581	total: 504ms	remaining: 655ms
# 87:	learn: 0.0924476	total: 510ms	remaining: 649ms
# 88:	learn: 0.0920761	total: 515ms	remaining: 643ms
# 89:	learn: 0.0913560	total: 521ms	remaining: 637ms
# 90:	learn: 0.0908683	total: 526ms	remaining: 630ms
# 91:	learn: 0.0898671	total: 532ms	remaining: 625ms
# 92:	learn: 0.0893459	total: 538ms	remaining: 619ms
# 93:	learn: 0.0885728	total: 543ms	remaining: 613ms
# 94:	learn: 0.0880494	total: 549ms	remaining: 607ms
# 95:	learn: 0.0871917	total: 555ms	remaining: 601ms
# 96:	learn: 0.0868384	total: 560ms	remaining: 595ms
# 97:	learn: 0.0864795	total: 566ms	remaining: 589ms
# 98:	learn: 0.0860287	total: 572ms	remaining: 583ms
# 99:	learn: 0.0855914	total: 577ms	remaining: 577ms
# 100:	learn: 0.0851660	total: 583ms	remaining: 571ms
# 101:	learn: 0.0846924	total: 589ms	remaining: 566ms
# 102:	learn: 0.0843744	total: 595ms	remaining: 560ms
# 103:	learn: 0.0837938	total: 601ms	remaining: 555ms
# 104:	learn: 0.0833748	total: 607ms	remaining: 549ms
# 105:	learn: 0.0830535	total: 612ms	remaining: 543ms
# 106:	learn: 0.0826653	total: 618ms	remaining: 538ms
# 107:	learn: 0.0820181	total: 625ms	remaining: 532ms
# 108:	learn: 0.0816234	total: 630ms	remaining: 526ms
# 109:	learn: 0.0813781	total: 639ms	remaining: 523ms
# 110:	learn: 0.0808135	total: 650ms	remaining: 521ms
# 111:	learn: 0.0801853	total: 656ms	remaining: 515ms
# 112:	learn: 0.0797806	total: 666ms	remaining: 513ms
# 113:	learn: 0.0793983	total: 674ms	remaining: 509ms
# 114:	learn: 0.0787593	total: 686ms	remaining: 507ms
# 115:	learn: 0.0782910	total: 697ms	remaining: 504ms
# 116:	learn: 0.0775913	total: 704ms	remaining: 499ms
# 117:	learn: 0.0770268	total: 716ms	remaining: 497ms
# 118:	learn: 0.0763997	total: 722ms	remaining: 491ms
# 119:	learn: 0.0758750	total: 728ms	remaining: 485ms
# 120:	learn: 0.0753268	total: 733ms	remaining: 479ms
# 121:	learn: 0.0748151	total: 739ms	remaining: 472ms
# 122:	learn: 0.0743399	total: 749ms	remaining: 469ms
# 123:	learn: 0.0739503	total: 759ms	remaining: 465ms
# 124:	learn: 0.0735845	total: 765ms	remaining: 459ms
# 125:	learn: 0.0730647	total: 771ms	remaining: 453ms
# 126:	learn: 0.0726733	total: 778ms	remaining: 447ms
# 127:	learn: 0.0722592	total: 788ms	remaining: 443ms
# 128:	learn: 0.0719912	total: 794ms	remaining: 437ms
# 129:	learn: 0.0715723	total: 804ms	remaining: 433ms
# 130:	learn: 0.0710823	total: 820ms	remaining: 432ms
# 131:	learn: 0.0706696	total: 825ms	remaining: 425ms
# 132:	learn: 0.0704701	total: 831ms	remaining: 419ms
# 133:	learn: 0.0701644	total: 837ms	remaining: 412ms
# 134:	learn: 0.0697820	total: 847ms	remaining: 408ms
# 135:	learn: 0.0694165	total: 856ms	remaining: 403ms
# 136:	learn: 0.0691038	total: 861ms	remaining: 396ms
# 137:	learn: 0.0688116	total: 867ms	remaining: 389ms
# 138:	learn: 0.0684426	total: 872ms	remaining: 383ms
# 139:	learn: 0.0680952	total: 877ms	remaining: 376ms
# 140:	learn: 0.0677431	total: 884ms	remaining: 370ms
# 141:	learn: 0.0674262	total: 890ms	remaining: 363ms
# 142:	learn: 0.0670832	total: 895ms	remaining: 357ms
# 143:	learn: 0.0667484	total: 901ms	remaining: 350ms
# 144:	learn: 0.0663805	total: 906ms	remaining: 344ms
# 145:	learn: 0.0660970	total: 912ms	remaining: 337ms
# 146:	learn: 0.0658164	total: 918ms	remaining: 331ms
# 147:	learn: 0.0655258	total: 923ms	remaining: 324ms
# 148:	learn: 0.0653513	total: 929ms	remaining: 318ms
# 149:	learn: 0.0651039	total: 934ms	remaining: 311ms
# 150:	learn: 0.0646656	total: 940ms	remaining: 305ms
# 151:	learn: 0.0644900	total: 945ms	remaining: 299ms
# 152:	learn: 0.0639401	total: 950ms	remaining: 292ms
# 153:	learn: 0.0637095	total: 956ms	remaining: 286ms
# 154:	learn: 0.0632977	total: 961ms	remaining: 279ms
# 155:	learn: 0.0630057	total: 967ms	remaining: 273ms
# 156:	learn: 0.0626334	total: 972ms	remaining: 266ms
# 157:	learn: 0.0624325	total: 977ms	remaining: 260ms
# 158:	learn: 0.0620045	total: 983ms	remaining: 253ms
# 159:	learn: 0.0617878	total: 989ms	remaining: 247ms
# 160:	learn: 0.0614789	total: 995ms	remaining: 241ms
# 161:	learn: 0.0612024	total: 1000ms	remaining: 235ms
# 162:	learn: 0.0608324	total: 1s	remaining: 228ms
# 163:	learn: 0.0605360	total: 1.01s	remaining: 222ms
# 164:	learn: 0.0601091	total: 1.01s	remaining: 215ms
# 165:	learn: 0.0597308	total: 1.02s	remaining: 209ms
# 166:	learn: 0.0593530	total: 1.02s	remaining: 203ms
# 167:	learn: 0.0590928	total: 1.03s	remaining: 197ms
# 168:	learn: 0.0588069	total: 1.04s	remaining: 190ms
# 169:	learn: 0.0585423	total: 1.04s	remaining: 184ms
# 170:	learn: 0.0580979	total: 1.05s	remaining: 178ms
# 171:	learn: 0.0578285	total: 1.05s	remaining: 171ms
# 172:	learn: 0.0575598	total: 1.06s	remaining: 165ms
# 173:	learn: 0.0573262	total: 1.06s	remaining: 159ms
# 174:	learn: 0.0570852	total: 1.07s	remaining: 153ms
# 175:	learn: 0.0568024	total: 1.07s	remaining: 147ms
# 176:	learn: 0.0564658	total: 1.08s	remaining: 140ms
# 177:	learn: 0.0561441	total: 1.08s	remaining: 134ms
# 178:	learn: 0.0558863	total: 1.09s	remaining: 128ms
# 179:	learn: 0.0557239	total: 1.1s	remaining: 122ms
# 180:	learn: 0.0554268	total: 1.1s	remaining: 116ms
# 181:	learn: 0.0552003	total: 1.11s	remaining: 110ms
# 182:	learn: 0.0548649	total: 1.11s	remaining: 103ms
# 183:	learn: 0.0546188	total: 1.12s	remaining: 97.3ms
# 184:	learn: 0.0544742	total: 1.12s	remaining: 91.2ms
# 185:	learn: 0.0542396	total: 1.13s	remaining: 85.1ms
# 186:	learn: 0.0538862	total: 1.14s	remaining: 79ms
# 187:	learn: 0.0536613	total: 1.14s	remaining: 72.9ms
# 188:	learn: 0.0535264	total: 1.15s	remaining: 66.8ms
# 189:	learn: 0.0534697	total: 1.15s	remaining: 60.5ms
# 190:	learn: 0.0532348	total: 1.16s	remaining: 54.4ms
# 191:	learn: 0.0529433	total: 1.16s	remaining: 48.4ms
# 192:	learn: 0.0527601	total: 1.17s	remaining: 42.3ms
# 193:	learn: 0.0525511	total: 1.17s	remaining: 36.3ms
# 194:	learn: 0.0522739	total: 1.18s	remaining: 30.2ms
# 195:	learn: 0.0521413	total: 1.18s	remaining: 24.2ms
# 196:	learn: 0.0518912	total: 1.19s	remaining: 18.1ms
# 197:	learn: 0.0516467	total: 1.2s	remaining: 12.1ms
# 198:	learn: 0.0513357	total: 1.2s	remaining: 6.03ms
# 199:	learn: 0.0511481	total: 1.21s	remaining: 0us
# Best CatBoost Model - Cross-Validation Scores:
# CV Mean Accuracy: 0.9740
# CV Standard Deviation: 0.0380

# %%
disp = ConfusionMatrixDisplay(confusion_matrix(y_test, y_test_pred), display_labels=[0, 1])
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# #### ExtraTreesClassifier

# %%
extra = ExtraTreesClassifier()

start_time = time.time()
extra.fit(X_train, y_train)
training_time = time.time() - start_time
print(f"Training time: {training_time:.3f} seconds")
print("=" * 80)

y_train_pred = extra.predict(X_train)
train_table = evaluate_model(y_train, y_train_pred)

y_test_pred = extra.predict(X_test)
test_table = evaluate_model(y_test, y_test_pred)

table1_str = train_table.get_string(title="ExtraTrees Model - Training Metrics")
table2_str = test_table.get_string(title="ExtraTrees Model - Testing Metrics")

lines1 = table1_str.split('\n')
lines2 = table2_str.split('\n')

max_lines = max(len(lines1), len(lines2))
lines1 += [""] * (max_lines - len(lines1))
lines2 += [""] * (max_lines - len(lines2))

for l1, l2 in zip(lines1, lines2):
    print(f"{l1:<45} {l2}")
print("=" * 80)

cv_scores = cross_val_score(extra, X_train, y_train, cv=5, scoring='accuracy')
print("ExtraTrees Model - Cross-Validation Scores:")
print(f"CV Mean Accuracy: {cv_scores.mean():.3f}")
print(f"CV Standard Deviation: {cv_scores.std():.3f}")
print("=" * 80)
print()

clf_report = classification_report(y_test, y_test_pred)
print("Classification Report:")
print(clf_report)
# Out:
# Training time: 0.259 seconds
# ================================================================================
# +-------------------------------------+       +------------------------------------+
# | ExtraTrees Model - Training Metrics |       | ExtraTrees Model - Testing Metrics |
# +----------------------+--------------+       +---------------------+--------------+
# |        Metric        |    Value     |       |        Metric       |    Value     |
# +----------------------+--------------+       +---------------------+--------------+
# |       Accuracy       |     1.0      |       |       Accuracy      |    0.933     |
# |      Precision       |     1.0      |       |      Precision      |     0.19     |
# |        Recall        |     1.0      |       |        Recall       |    0.045     |
# |       F1 Score       |     1.0      |       |       F1 Score      |    0.073     |
# |         AUC          |     1.0      |       |         AUC         |    0.517     |
# +----------------------+--------------+       +---------------------+--------------+
# ================================================================================
# ExtraTrees Model - Cross-Validation Scores:
# CV Mean Accuracy: 0.973
# CV Standard Deviation: 0.038
# ================================================================================
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.97      1444
#            1       0.19      0.04      0.07        89
#
#     accuracy                           0.93      1533
#    macro avg       0.57      0.52      0.52      1533
# weighted avg       0.90      0.93      0.91      1533

# %%
disp = ConfusionMatrixDisplay(confusion_matrix(y_test, extra.predict(X_test)), display_labels=[0, 1])
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.show()

# %%
y_prob = extra.predict_proba(X_test)

roc_auc = roc_auc_score(y_test, y_prob[:, 1])

fpr = {}
tpr = {}
thresholds = {}

for i in range(len(extra.classes_)):
	fpr[i], tpr[i], thresholds[i] = roc_curve(y_test, y_prob[:, i], pos_label=i)

plt.figure()
for i in range(len(extra.classes_)):
	plt.plot(fpr[i], tpr[i], lw=2, label=f'Class {i} (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc='lower right')
plt.show()

print(f"AUC: {roc_auc:.2f}")
# Out:
# AUC: 0.75

# %%
extra_param_grid = {
    'n_estimators': [100, 200, 300],  
    'max_depth': [None, 10, 20, 30],  
    'min_samples_split': [2, 5, 10],  
    'min_samples_leaf': [1, 2, 4],    
    'max_features': ['auto', 'sqrt', 'log2'],  
    'bootstrap': [True, False]
}

extra_grid_search = GridSearchCV(extra, extra_param_grid, cv=5, scoring='accuracy', n_jobs=-1)
extra_grid_search.fit(X_train, y_train)
print("Best Hyperparameters for ExtraTrees:")
table_hyperparams = PrettyTable()
table_hyperparams.field_names = ["Parameter", "Value"]
for param, value in extra_grid_search.best_params_.items():
    table_hyperparams.add_row([param, value])
print(table_hyperparams)
print("Best Accuracy for ExtraTrees: {:.4f}".format(extra_grid_search.best_score_))
# Out:
# Best Hyperparameters for ExtraTrees:
# +-------------------+-------+
# |     Parameter     | Value |
# +-------------------+-------+
# |     bootstrap     |  True |
# |     max_depth     |  None |
# |    max_features   |  log2 |
# |  min_samples_leaf |   1   |
# | min_samples_split |   5   |
# |    n_estimators   |  200  |
# +-------------------+-------+
# Best Accuracy for ExtraTrees: 0.9765

# %%
best_extra_model = ExtraTreesClassifier(**extra_grid_search.best_params_)
best_extra_model.fit(X_train, y_train)
y_test_pred = best_extra_model.predict(X_test)
test_accuracy = accuracy_score(y_test, y_test_pred)
test_precision = precision_score(y_test, y_test_pred)
test_recall = recall_score(y_test, y_test_pred)
test_f1 = f1_score(y_test, y_test_pred)
test_auc = roc_auc_score(y_test, y_test_pred)
print("Best ExtraTrees Model - Testing Metrics:")

table_testing = PrettyTable()
table_testing.field_names = ["Metric", "Value"]
table_testing.add_row(["Accuracy", round(test_accuracy, 3)])
table_testing.add_row(["Precision", round(test_precision, 3)])
table_testing.add_row(["Recall", round(test_recall, 3)])
table_testing.add_row(["F1 Score", round(test_f1, 3)])
table_testing.add_row(["AUC", round(test_auc, 3)])
print(table_testing)
# Out:
# Best ExtraTrees Model - Testing Metrics:
# +-----------+-------+
# |   Metric  | Value |
# +-----------+-------+
# |  Accuracy |  0.94 |
# | Precision | 0.286 |
# |   Recall  | 0.022 |
# |  F1 Score | 0.042 |
# |    AUC    |  0.51 |
# +-----------+-------+

# %%
cv_scores = cross_val_score(best_extra_model, X_train, y_train, cv=5, scoring='accuracy')
print("Best ExtraTrees Model - Cross-Validation Scores:")
print("CV Mean Accuracy: {:.4f}".format(round(cv_scores.mean(), 3)))
print("CV Standard Deviation: {:.4f}".format(round(cv_scores.std(), 3)))
# Out:
# Best ExtraTrees Model - Cross-Validation Scores:
# CV Mean Accuracy: 0.9750
# CV Standard Deviation: 0.0410

# %%
disp = ConfusionMatrixDisplay(confusion_matrix(y_test, y_test_pred), display_labels=[0, 1])
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# #### StakingClassifier

# %%
base_models = [
    ('knn', best_knn_model),            
    ('logis', best_logis_model),      
    ('rf', best_rf_model),            
    ('svm', best_svm_model),            
    ('lgbm', best_lgbm_model),          
    ('xgb', best_xgb_model),            
    ('gradient', best_gradient_model),   
    ('cat', best_cat_model),             
    ('extra', best_extra_model)          
]

# %%
meta_model = LogisticRegression()
stacking_model = StackingClassifier(estimators=base_models, final_estimator=meta_model, cv=5, n_jobs=-1)

start_time = time.time()
stacking_model.fit(X_train, y_train)
training_time = time.time() - start_time
print(f"Stacking Model - Training time: {training_time:.3f} seconds")
print("=" * 80)

y_train_pred = stacking_model.predict(X_train)
train_table = evaluate_model(y_train, y_train_pred)

y_test_pred = stacking_model.predict(X_test)
test_table = evaluate_model(y_test, y_test_pred)

table1_str = train_table.get_string(title="Stacking Model - Training Metrics")
table2_str = test_table.get_string(title="Stacking Model - Testing Metrics")

lines1 = table1_str.split('\n')
lines2 = table2_str.split('\n')

max_lines = max(len(lines1), len(lines2))
lines1 += [""] * (max_lines - len(lines1))
lines2 += [""] * (max_lines - len(lines2))

for l1, l2 in zip(lines1, lines2):
    print(f"{l1:<45} {l2}")
print("=" * 80)

cv_scores = cross_val_score(stacking_model, X_train, y_train, cv=5, scoring='accuracy')
print("Stacking Model - Cross-Validation Scores:")
print(f"CV Mean Accuracy: {cv_scores.mean():.3f}")
print(f"CV Standard Deviation: {cv_scores.std():.3f}")
print("=" * 80)

clf_report = classification_report(y_test, y_test_pred)
print("Classification Report:")
print(clf_report)
# Out:
# Stacking Model - Training time: 14.660 seconds
# ================================================================================
# +-----------------------------------+         +----------------------------------+
# | Stacking Model - Training Metrics |         | Stacking Model - Testing Metrics |
# +---------------------+-------------+         +--------------------+-------------+
# |        Metric       |    Value    |         |       Metric       |    Value    |
# +---------------------+-------------+         +--------------------+-------------+
# |       Accuracy      |    0.992    |         |      Accuracy      |    0.938    |
# |      Precision      |    0.999    |         |     Precision      |     0.25    |
# |        Recall       |    0.984    |         |       Recall       |    0.034    |
# |       F1 Score      |    0.992    |         |      F1 Score      |    0.059    |
# |         AUC         |    0.992    |         |        AUC         |    0.514    |
# +---------------------+-------------+         +--------------------+-------------+
# ================================================================================
# Stacking Model - Cross-Validation Scores:
# CV Mean Accuracy: 0.974
# CV Standard Deviation: 0.039
# ================================================================================
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.97      1444
#            1       0.25      0.03      0.06        89
#
#     accuracy                           0.94      1533
#    macro avg       0.60      0.51      0.51      1533
# weighted avg       0.90      0.94      0.92      1533

# %%
disp = ConfusionMatrixDisplay(confusion_matrix(y_test, stacking_model.predict(X_test)), display_labels=[0, 1])
disp.plot(cmap=plt.cm.Blues)
plt.title("Stacking Model - Confusion Matrix")
plt.show()

# %%
y_prob = stacking_model.predict_proba(X_test)
roc_auc = roc_auc_score(y_test, y_prob[:, 1])

fpr = {}
tpr = {}
thresholds = {}

for i in range(2):  
    fpr[i], tpr[i], thresholds[i] = roc_curve(y_test, y_prob[:, i], pos_label=i)

plt.figure()
for i in range(2):
    plt.plot(fpr[i], tpr[i], lw=2, label=f'Class {i} (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Stacking Model - Receiver Operating Characteristic (ROC)')
plt.legend(loc='lower right')
plt.show()

print(f"AUC: {roc_auc:.2f}")
# Out:
# AUC: 0.80

# %% [markdown]
# ### Save model

# %%
joblib.dump(best_knn_model, 'knn.pkl')
joblib.dump(best_logis_model, 'logistic.pkl')
joblib.dump(best_decision_model, 'decision.pkl')
joblib.dump(best_rf_model, 'randomforest.pkl')
joblib.dump(best_svm_model , 'svc.pkl')
joblib.dump(best_lgbm_model , 'lgbm.pkl')
joblib.dump(best_xgb_model , 'xgboost.pkl')
joblib.dump(best_gradient_model , 'gradient.pkl')
joblib.dump(best_cat_model  , 'catboost.pkl')
joblib.dump(best_extra_model  , 'extratree.pkl')
joblib.dump(stacking_model, 'stacking.pkl')
# Out:
# ['stacking.pkl']
